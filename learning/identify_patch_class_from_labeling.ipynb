# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

import sys
import os

sys.path.append(os.environ['REPO_DIR'] + '/utilities')
from utilities2015 import *
from metadata import *
from data_manager import *

from learning_utilities import *

import matplotlib.pyplot as plt
# %matplotlib inline

from joblib import Parallel, delayed
import time
# Out:
# Setting environment for Gordon
# No vtk
# Cannot import mxnet.

# %%
# for stack in ['MD594', 'MD585', 'MD589']:
for stack in ['MD635']:
    label_gridIndices = locate_annotated_patches_v2(stack=stack, 
                                                    annotation_rootdir=annotation_midbrainIncluded_v2_rootdir)
    
    annotation_grid_indices_fn = '/home/yuncong/csd395/CSHL_labelings_v3/%(stack)s/%(stack)s_annotation_grid_indices.h5' % dict(stack=stack)
    label_gridIndices.to_hdf(annotation_grid_indices_fn, 'grid_indices')
# Out:
# Cannot import mxnet.
# Analyzing section 75..
# 0: 28 patches in VCA
# 237 patches in VCA_surround_noclass
# 29311 patches in VCA_negative
# 63782 patches in bg
# Analyzing section 76..
# 0: 52 patches in VCA
# 284 patches in VCA_surround_noclass
# 29350 patches in VCA_negative
# 63719 patches in bg
# Analyzing section 77..
# 0: 102 patches in VCA
# 342 patches in VCA_surround_noclass
# 29128 patches in VCA_negative
# 63891 patches in bg
# Analyzing section 78..
# 0: 150 patches in VCA
# 450 patches in VCA_surround_noclass
# 29628 patches in VCA_negative
# 63343 patches in bg
# Analyzing section 79..
# 0: 190 patches in VCA
# 477 patches in VCA_surround_noclass
# 30099 patches in VCA_negative
# 62832 patches in bg
# Analyzing section 80..
# 0: 260 patches in VCA
# 505 patches in VCA_surround_noclass
# 30431 patches in VCA_negative
# 62430 patches in bg
# Analyzing section 81..
# 0: 307 patches in VCA
# 559 patches in VCA_surround_noclass
# 30688 patches in VCA_negative
# 62126 patches in bg
# Analyzing section 82..
# 0: 382 patches in VCA
# 468 patches in VCA_surround_noclass
# 27014 patches in VCA_negative
# 65786 patches in bg
# Analyzing section 83..
# 0: 452 patches in VCA
# 597 patches in VCA_surround_noclass
# 30571 patches in VCA_negative
# 62098 patches in bg
# Analyzing section 84..
# 0: 538 patches in VCA
# 632 patches in VCA_surround_noclass
# 30933 patches in VCA_negative
# 61650 patches in bg
# Analyzing section 85..
# 0: 625 patches in VCA
# 687 patches in VCA_surround_noclass
# 30911 patches in VCA_negative
# 61585 patches in bg
# Analyzing section 86..
# 0: 645 patches in VCA
# 1: 42 patches in VCP
# 698 patches in VCA_surround_noclass
# 42 patches in VCA_surround_VCP
# 31239 patches in VCA_negative
# 182 patches in VCP_surround_noclass
# 140 patches in VCP_surround_VCA
# 31842 patches in VCP_negative
# 61237 patches in bg
# Analyzing section 87..
# 0: 680 patches in VCA
# 1: 59 patches in VCP
# 791 patches in VCA_surround_noclass
# 59 patches in VCA_surround_VCP
# 31448 patches in VCA_negative
# 218 patches in VCP_surround_noclass
# 145 patches in VCP_surround_VCA
# 32069 patches in VCP_negative
# 60993 patches in bg
# Analyzing section 88..
# 0: 707 patches in VCA
# 1: 78 patches in VCP
# 846 patches in VCA_surround_noclass
# 78 patches in VCA_surround_VCP
# 31587 patches in VCA_negative
# 285 patches in VCP_surround_noclass
# 137 patches in VCP_surround_VCA
# 32216 patches in VCP_negative
# 60827 patches in bg
# Analyzing section 89..
# 0: 733 patches in VCA
# 1: 115 patches in VCP
# 862 patches in VCA_surround_noclass
# 102 patches in VCA_surround_VCP
# 31907 patches in VCA_negative
# 328 patches in VCP_surround_noclass
# 134 patches in VCP_surround_VCA
# 32525 patches in VCP_negative
# 60481 patches in bg
# Analyzing section 90..
# 0: 272 patches in VCP
# 1: 780 patches in VCA
# 272 patches in VCP_surround_noclass
# 221 patches in VCP_surround_VCA
# 32532 patches in VCP_negative
# 786 patches in VCA_surround_noclass
# 207 patches in VCA_surround_VCP
# 32024 patches in VCA_negative
# 60317 patches in bg
# Analyzing section 91..
# 0: 102 patches in DC
# 1: 760 patches in VCA
# 2: 281 patches in VCP
# 558 patches in DC_surround_noclass
# 39 patches in DC_surround_VCP
# 118 patches in DC_surround_VCA
# 33073 patches in DC_negative
# 780 patches in VCA_surround_noclass
# 200 patches in VCA_surround_VCP
# 90 patches in VCA_surround_DC
# 32415 patches in VCA_negative
# 352 patches in VCP_surround_noclass
# 212 patches in VCP_surround_VCA
# 18 patches in VCP_surround_DC
# 32894 patches in VCP_negative
# 59946 patches in bg
# Analyzing section 92..
# 0: 293 patches in VCP
# 1: 154 patches in DC
# 2: 755 patches in VCA
# 413 patches in VCP_surround_noclass
# 209 patches in VCP_surround_VCA
# 34 patches in VCP_surround_DC
# 33672 patches in VCP_negative
# 591 patches in DC_surround_noclass
# 38 patches in DC_surround_VCP
# 103 patches in DC_surround_VCA
# 33811 patches in DC_negative
# 868 patches in VCA_surround_noclass
# 198 patches in VCA_surround_VCP
# 106 patches in VCA_surround_DC
# 33210 patches in VCA_negative
# 59156 patches in bg
# Analyzing section 93..
# Analyzing section 94..
# 0: 754 patches in VCA
# 1: 299 patches in DC
# 2: 325 patches in VCP
# 928 patches in VCA_surround_noclass
# 195 patches in VCA_surround_VCP
# 97 patches in VCA_surround_DC
# 32934 patches in VCA_negative
# 696 patches in DC_surround_noclass
# 48 patches in DC_surround_VCP
# 81 patches in DC_surround_VCA
# 33389 patches in DC_negative
# 469 patches in VCP_surround_noclass
# 202 patches in VCP_surround_VCA
# 63 patches in VCP_surround_DC
# 33363 patches in VCP_negative
# 59433 patches in bg
# Analyzing section 95..
# 0: 372 patches in DC
# 1: 752 patches in VCA
# 2: 346 patches in VCP
# 798 patches in DC_surround_noclass
# 55 patches in DC_surround_VCP
# 72 patches in DC_surround_VCA
# 34056 patches in DC_negative
# 995 patches in VCA_surround_noclass
# 208 patches in VCA_surround_VCP
# 94 patches in VCA_surround_DC
# 33676 patches in VCA_negative
# 534 patches in VCP_surround_noclass
# 205 patches in VCP_surround_VCA
# 72 patches in VCP_surround_DC
# 34082 patches in VCP_negative
# 58693 patches in bg
# Analyzing section 96..
# 0: 398 patches in DC
# 1: 364 patches in VCP
# 2: 661 patches in VCA
# 793 patches in DC_surround_noclass
# 57 patches in DC_surround_VCP
# 64 patches in DC_surround_VCA
# 34798 patches in DC_negative
# 578 patches in VCP_surround_noclass
# 164 patches in VCP_surround_VCA
# 74 patches in VCP_surround_DC
# 34832 patches in VCP_negative
# 974 patches in VCA_surround_noclass
# 157 patches in VCA_surround_VCP
# 73 patches in VCA_surround_DC
# 34535 patches in VCA_negative
# 57925 patches in bg
# Analyzing section 97..
# 0: 429 patches in DC
# 1: 579 patches in VCA
# 2: 385 patches in VCP
# 803 patches in DC_surround_noclass
# 60 patches in DC_surround_VCP
# 67 patches in DC_surround_VCA
# 35294 patches in DC_negative
# 914 patches in VCA_surround_noclass
# 129 patches in VCA_surround_VCP
# 76 patches in VCA_surround_DC
# 35144 patches in VCA_negative
# 646 patches in VCP_surround_noclass
# 144 patches in VCP_surround_VCA
# 79 patches in VCP_surround_DC
# 35338 patches in VCP_negative
# 57398 patches in bg
# Analyzing section 98..
# 0: 416 patches in VCP
# 1: 457 patches in DC
# 2: 475 patches in VCA
# 703 patches in VCP_surround_noclass
# 116 patches in VCP_surround_VCA
# 87 patches in VCP_surround_DC
# 35804 patches in VCP_negative
# 821 patches in DC_surround_noclass
# 71 patches in DC_surround_VCP
# 66 patches in DC_surround_VCA
# 35763 patches in DC_negative
# 848 patches in VCA_surround_noclass
# 107 patches in VCA_surround_VCP
# 66 patches in VCA_surround_DC
# 35745 patches in VCA_negative
# 56901 patches in bg
# Analyzing section 99..
# 0: 495 patches in DC
# 1: 445 patches in VCP
# 2: 398 patches in VCA
# 834 patches in DC_surround_noclass
# 83 patches in DC_surround_VCP
# 69 patches in DC_surround_VCA
# 35869 patches in DC_negative
# 733 patches in VCP_surround_noclass
# 94 patches in VCP_surround_VCA
# 102 patches in VCP_surround_DC
# 35919 patches in VCP_negative
# 787 patches in VCA_surround_noclass
# 101 patches in VCA_surround_VCP
# 68 patches in VCA_surround_DC
# 35966 patches in VCA_negative
# 56757 patches in bg
# Analyzing section 100..
# 0: 468 patches in DC
# 1: 482 patches in VCP
# 2: 302 patches in VCA
# 842 patches in DC_surround_noclass
# 69 patches in DC_surround_VCP
# 54 patches in DC_surround_VCA
# 36240 patches in DC_negative
# 825 patches in VCP_surround_noclass
# 69 patches in VCP_surround_VCA
# 85 patches in VCP_surround_DC
# 36226 patches in VCP_negative
# 797 patches in VCA_surround_noclass
# 104 patches in VCA_surround_VCP
# 55 patches in VCA_surround_DC
# 36406 patches in VCA_negative
# 56413 patches in bg
# Analyzing section 101..
# 0: 447 patches in DC
# 1: 479 patches in VCP
# 2: 254 patches in VCA
# 833 patches in DC_surround_noclass
# 70 patches in DC_surround_VCP
# 52 patches in DC_surround_VCA
# 36418 patches in DC_negative
# 847 patches in VCP_surround_noclass
# 51 patches in VCP_surround_VCA
# 88 patches in VCP_surround_DC
# 36386 patches in VCP_negative
# 723 patches in VCA_surround_noclass
# 70 patches in VCA_surround_VCP
# 48 patches in VCA_surround_DC
# 36611 patches in VCA_negative
# 56256 patches in bg
# Analyzing section 102..
# 0: 422 patches in DC
# 1: 482 patches in VCP
# 2: 207 patches in VCA
# 836 patches in DC_surround_noclass
# 68 patches in DC_surround_VCP
# 46 patches in DC_surround_VCA
# 36934 patches in DC_negative
# 894 patches in VCP_surround_noclass
# 38 patches in VCP_surround_VCA
# 89 patches in VCP_surround_DC
# 36874 patches in VCP_negative
# 689 patches in VCA_surround_noclass
# 50 patches in VCA_surround_VCP
# 42 patches in VCA_surround_DC
# 37149 patches in VCA_negative
# 55765 patches in bg
# Analyzing section 103..
# 0: 489 patches in VCP
# 1: 406 patches in DC
# 2: 162 patches in VCA
# 893 patches in VCP_surround_noclass
# 25 patches in VCP_surround_VCA
# 104 patches in VCP_surround_DC
# 37233 patches in VCP_negative
# 829 patches in DC_surround_noclass
# 83 patches in DC_surround_VCP
# 40 patches in DC_surround_VCA
# 37316 patches in DC_negative
# 624 patches in VCA_surround_noclass
# 34 patches in VCA_surround_VCP
# 42 patches in VCA_surround_DC
# 37560 patches in VCA_negative
# 55399 patches in bg
# Analyzing section 104..
# 0: 125 patches in VCA
# 1: 386 patches in DC
# 2: 487 patches in VCP
# 585 patches in VCA_surround_noclass
# 18 patches in VCA_surround_VCP
# 37 patches in VCA_surround_DC
# 37836 patches in VCA_negative
# 838 patches in DC_surround_noclass
# 88 patches in DC_surround_VCP
# 30 patches in DC_surround_VCA
# 37575 patches in DC_negative
# 902 patches in VCP_surround_noclass
# 14 patches in VCP_surround_VCA
# 115 patches in VCP_surround_DC
# 37474 patches in VCP_negative
# 55160 patches in bg
# Analyzing section 105..
# 0: 506 patches in VCP
# 1: 368 patches in DC
# 2: 97 patches in VCA
# 916 patches in VCP_surround_noclass
# 8 patches in VCP_surround_VCA
# 127 patches in VCP_surround_DC
# 44305 patches in VCP_negative
# 864 patches in DC_surround_noclass
# 99 patches in DC_surround_VCP
# 26 patches in DC_surround_VCA
# 44443 patches in DC_negative
# 544 patches in VCA_surround_noclass
# 14 patches in VCA_surround_VCP
# 34 patches in VCA_surround_DC
# 44714 patches in VCA_negative
# 48310 patches in bg
# Analyzing section 106..
# 0: 314 patches in DC
# 918 patches in DC_surround_noclass
# 36400 patches in DC_negative
# 56407 patches in bg
# Analyzing section 107..
# 0: 260 patches in DC
# 1: 314 patches in VCP
# 2: 33 patches in VCA
# 3: 60 patches in Pr5
# 799 patches in DC_surround_noclass
# 53 patches in DC_surround_VCP
# 38308 patches in DC_negative
# 969 patches in VCP_surround_noclass
# 107 patches in VCP_surround_DC
# 38254 patches in VCP_negative
# 414 patches in VCA_surround_noclass
# 10 patches in VCA_surround_Pr5
# 38535 patches in VCA_negative
# 505 patches in Pr5_surround_noclass
# 14 patches in Pr5_surround_VCA
# 38508 patches in Pr5_negative
# 54553 patches in bg
# Analyzing section 108..
# 0: 221 patches in DC
# 1: 97 patches in Pr5
# 798 patches in DC_surround_noclass
# 38441 patches in DC_negative
# 598 patches in Pr5_surround_noclass
# 38565 patches in Pr5_negative
# 54459 patches in bg
# Analyzing section 109..
# 0: 185 patches in DC
# 1: 147 patches in Pr5
# 751 patches in DC_surround_noclass
# 38830 patches in DC_negative
# 682 patches in Pr5_surround_noclass
# 38868 patches in Pr5_negative
# 54106 patches in bg
# Analyzing section 110..
# 0: 223 patches in Pr5
# 1: 146 patches in DC
# 781 patches in Pr5_surround_noclass
# 39294 patches in Pr5_negative
# 738 patches in DC_surround_noclass
# 39371 patches in DC_negative
# 53604 patches in bg
# Analyzing section 111..
# 0: 134 patches in DC
# 1: 296 patches in Pr5
# 693 patches in DC_surround_noclass
# 46295 patches in DC_negative
# 860 patches in Pr5_surround_noclass
# 46133 patches in Pr5_negative
# 46692 patches in bg
# Analyzing section 112..
# 0: 398 patches in Pr5
# 1: 126 patches in DC
# 954 patches in Pr5_surround_noclass
# 39970 patches in Pr5_negative
# 662 patches in DC_surround_noclass
# 40242 patches in DC_negative
# 52753 patches in bg
# Analyzing section 113..
# 0: 118 patches in DC
# 1: 513 patches in Pr5
# 643 patches in DC_surround_noclass
# 39733 patches in DC_negative
# 1056 patches in Pr5_surround_noclass
# 39338 patches in Pr5_negative
# 53270 patches in bg
# Analyzing section 114..
# 0: 106 patches in Sp5C
# 1: 118 patches in DC
# 686 patches in Sp5C_surround_noclass
# 38800 patches in Sp5C_negative
# 641 patches in DC_surround_noclass
# 38788 patches in DC_negative
# 54215 patches in bg
# Analyzing section 115..
# 0: 102 patches in DC
# 1: 159 patches in Sp5C
# 615 patches in DC_surround_noclass
# 40094 patches in DC_negative
# 724 patches in Sp5C_surround_noclass
# 40037 patches in Sp5C_negative
# 52925 patches in bg
# Analyzing section 116..
# 0: 96 patches in DC
# 1: 243 patches in Sp5C
# 634 patches in DC_surround_noclass
# 40346 patches in DC_negative
# 782 patches in Sp5C_surround_noclass
# 40199 patches in Sp5C_negative
# 52679 patches in bg
# Analyzing section 117..
# 0: 81 patches in DC
# 1: 297 patches in Sp5C
# 597 patches in DC_surround_noclass
# 40623 patches in DC_negative
# 831 patches in Sp5C_surround_noclass
# 40407 patches in Sp5C_negative
# 52417 patches in bg
# Analyzing section 118..
# 0: 77 patches in DC
# 1: 349 patches in Sp5C
# 564 patches in DC_surround_noclass
# 40582 patches in DC_negative
# 871 patches in Sp5C_surround_noclass
# 40310 patches in Sp5C_negative
# 52462 patches in bg
# Analyzing section 119..
# 0: 70 patches in DC
# 1: 435 patches in Sp5C
# 556 patches in DC_surround_noclass
# 40820 patches in DC_negative
# 923 patches in Sp5C_surround_noclass
# 40455 patches in Sp5C_negative
# 52231 patches in bg
# Analyzing section 120..
# 0: 69 patches in DC
# 1: 510 patches in Sp5C
# 564 patches in DC_surround_noclass
# 41054 patches in DC_negative
# 977 patches in Sp5C_surround_noclass
# 40613 patches in Sp5C_negative
# 51998 patches in bg
# Analyzing section 121..
# 0: 253 patches in SNR
# 1: 66 patches in DC
# 857 patches in SNR_surround_noclass
# 40864 patches in SNR_negative
# 542 patches in DC_surround_noclass
# 41051 patches in DC_negative
# 52004 patches in bg
# Analyzing section 122..
# 0: 261 patches in SNR
# 1: 66 patches in DC
# 868 patches in SNR_surround_noclass
# 43034 patches in SNR_negative
# 530 patches in DC_surround_noclass
# 43229 patches in DC_negative
# 49826 patches in bg
# Analyzing section 123..
# 0: 67 patches in DC
# 1: 280 patches in SNR
# 530 patches in DC_surround_noclass
# 41599 patches in DC_negative
# 892 patches in SNR_surround_noclass
# 41386 patches in SNR_negative
# 51455 patches in bg
# Analyzing section 124..
# 0: 295 patches in SNR
# 1: 66 patches in DC
# 920 patches in SNR_surround_noclass
# 41370 patches in SNR_negative
# 528 patches in DC_surround_noclass
# 41599 patches in DC_negative
# 51456 patches in bg
# Analyzing section 125..
# 0: 325 patches in SNR
# 1: 68 patches in DC
# 974 patches in SNR_surround_noclass
# 39150 patches in SNR_negative
# 555 patches in DC_surround_noclass
# 39407 patches in DC_negative
# 53646 patches in bg
# Analyzing section 126..
# 0: 355 patches in SNR
# 1: 61 patches in DC
# 984 patches in SNR_surround_noclass
# 38905 patches in SNR_negative
# 512 patches in DC_surround_noclass
# 39199 patches in DC_negative
# 53861 patches in bg
# Analyzing section 127..
# 0: 400 patches in SNR
# 1: 57 patches in DC
# 1012 patches in SNR_surround_noclass
# 41671 patches in SNR_negative
# 501 patches in DC_surround_noclass
# 42014 patches in DC_negative
# 51050 patches in bg
# Analyzing section 128..
# 0: 449 patches in SNR
# 1: 50 patches in DC
# 1048 patches in SNR_surround_noclass
# 41829 patches in SNR_negative
# 497 patches in DC_surround_noclass
# 42228 patches in DC_negative
# 50843 patches in bg
# Analyzing section 129..
# 0: 486 patches in SNR
# 1: 47 patches in DC
# 1098 patches in SNR_surround_noclass
# 42237 patches in SNR_negative
# 488 patches in DC_surround_noclass
# 42676 patches in DC_negative
# 50398 patches in bg
# Analyzing section 130..
# 0: 45 patches in DC
# 1: 546 patches in SNR
# 503 patches in DC_surround_noclass
# 42385 patches in DC_negative
# 1159 patches in SNR_surround_noclass
# 41884 patches in SNR_negative
# 50691 patches in bg
# Analyzing section 131..
# 0: 33 patches in DC
# 1: 563 patches in SNR
# 461 patches in DC_surround_noclass
# 45598 patches in DC_negative
# 1140 patches in SNR_surround_noclass
# 45068 patches in SNR_negative
# 47490 patches in bg
# Analyzing section 132..
# 0: 574 patches in SNR
# 1: 24 patches in DC
# 1162 patches in SNR_surround_noclass
# 42449 patches in SNR_negative
# 443 patches in DC_surround_noclass
# 42999 patches in DC_negative
# 50098 patches in bg
# Analyzing section 133..
# 0: 598 patches in SNR
# 1: 16 patches in DC
# 1193 patches in SNR_surround_noclass
# 42268 patches in SNR_negative
# 426 patches in DC_surround_noclass
# 42850 patches in DC_negative
# 50255 patches in bg
# Analyzing section 134..
# 0: 616 patches in SNR
# 1: 9 patches in DC
# 1198 patches in SNR_surround_noclass
# 42396 patches in SNR_negative
# 399 patches in DC_surround_noclass
# 43003 patches in DC_negative
# 50109 patches in bg
# Analyzing section 135..
# 0: 649 patches in SNR
# 1: 4 patches in DC
# 2: 149 patches in VLL
# 1256 patches in SNR_surround_noclass
# 41102 patches in SNR_negative
# 410 patches in DC_surround_noclass
# 41747 patches in DC_negative
# 678 patches in VLL_surround_noclass
# 41602 patches in VLL_negative
# 51370 patches in bg
# Analyzing section 136..
# 0: 134 patches in VLL
# 1: 675 patches in SNR
# 2: 77 patches in 7n
# 642 patches in VLL_surround_noclass
# 43612 patches in VLL_negative
# 1265 patches in SNR_surround_noclass
# 43071 patches in SNR_negative
# 519 patches in 7n_surround_noclass
# 43669 patches in 7n_negative
# 49375 patches in bg
# Analyzing section 137..
# 0: 78 patches in 7n
# 1: 121 patches in VLL
# 2: 109 patches in 5N
# 3: 724 patches in SNR
# 525 patches in 7n_surround_noclass
# 43848 patches in 7n_negative
# 612 patches in VLL_surround_noclass
# 3 patches in VLL_surround_SNR
# 43805 patches in VLL_negative
# 559 patches in 5N_surround_noclass
# 43817 patches in 5N_negative
# 1305 patches in SNR_surround_noclass
# 4 patches in SNR_surround_VLL
# 43202 patches in SNR_negative
# 49195 patches in bg
# Analyzing section 138..
# 0: 770 patches in SNR
# 1: 134 patches in 5N
# 2: 79 patches in 7n
# 3: 115 patches in VLL
# 1340 patches in SNR_surround_noclass
# 8 patches in SNR_surround_VLL
# 43230 patches in SNR_negative
# 656 patches in 5N_surround_noclass
# 43866 patches in 5N_negative
# 548 patches in 7n_surround_noclass
# 43921 patches in 7n_negative
# 587 patches in VLL_surround_noclass
# 8 patches in VLL_surround_SNR
# 43885 patches in VLL_negative
# 49121 patches in bg
# Analyzing section 139..
# 0: 85 patches in 7n
# 1: 826 patches in SNR
# 2: 74 patches in 7N
# 3: 106 patches in VLL
# 4: 172 patches in 5N
# 554 patches in 7n_surround_noclass
# 43554 patches in 7n_negative
# 1408 patches in SNR_surround_noclass
# 13 patches in SNR_surround_VLL
# 42813 patches in SNR_negative
# 454 patches in 7N_surround_noclass
# 43565 patches in 7N_negative
# 568 patches in VLL_surround_noclass
# 13 patches in VLL_surround_SNR
# 43533 patches in VLL_negative
# 698 patches in 5N_surround_noclass
# 43467 patches in 5N_negative
# 49482 patches in bg
# Analyzing section 140..
# 0: 101 patches in 7N
# 1: 93 patches in 7n
# 2: 145 patches in VLL
# 3: 783 patches in SNR
# 4: 252 patches in 5N
# 319 patches in 7N_surround_noclass
# 33740 patches in 7N_negative
# 609 patches in 7n_surround_noclass
# 33703 patches in 7n_negative
# 642 patches in VLL_surround_noclass
# 13 patches in VLL_surround_SNR
# 33651 patches in VLL_negative
# 1347 patches in SNR_surround_noclass
# 15 patches in SNR_surround_VLL
# 33013 patches in SNR_negative
# 781 patches in 5N_surround_noclass
# 33544 patches in 5N_negative
# 59325 patches in bg
# Analyzing section 141..
# 0: 132 patches in 7N
# 1: 277 patches in 5N
# 2: 94 patches in 7n
# 3: 764 patches in SNR
# 4: 179 patches in VLL
# 625 patches in 7N_surround_noclass
# 44421 patches in 7N_negative
# 824 patches in 5N_surround_noclass
# 44276 patches in 5N_negative
# 575 patches in 7n_surround_noclass
# 44459 patches in 7n_negative
# 1333 patches in SNR_surround_noclass
# 15 patches in SNR_surround_VLL
# 43789 patches in SNR_negative
# 713 patches in VLL_surround_noclass
# 16 patches in VLL_surround_SNR
# 44374 patches in VLL_negative
# 48568 patches in bg
# Analyzing section 142..
# 0: 186 patches in 7N
# 1: 752 patches in SNR
# 2: 95 patches in 7n
# 3: 226 patches in VLL
# 4: 335 patches in 5N
# 604 patches in 7N_surround_noclass
# 44129 patches in 7N_negative
# 1294 patches in SNR_surround_noclass
# 21 patches in SNR_surround_VLL
# 43563 patches in SNR_negative
# 576 patches in 7n_surround_noclass
# 44220 patches in 7n_negative
# 816 patches in VLL_surround_noclass
# 21 patches in VLL_surround_SNR
# 44089 patches in VLL_negative
# 875 patches in 5N_surround_noclass
# 43980 patches in 5N_negative
# 48806 patches in bg
# Analyzing section 143..
# 0: 735 patches in SNR
# 1: 396 patches in 5N
# 2: 106 patches in 7n
# 3: 230 patches in 7N
# 4: 262 patches in VLL
# 1274 patches in SNR_surround_noclass
# 23 patches in SNR_surround_VLL
# 43957 patches in SNR_negative
# 949 patches in 5N_surround_noclass
# 44296 patches in 5N_negative
# 595 patches in 7n_surround_noclass
# 44586 patches in 7n_negative
# 666 patches in 7N_surround_noclass
# 44462 patches in 7N_negative
# 906 patches in VLL_surround_noclass
# 24 patches in VLL_surround_SNR
# 44430 patches in VLL_negative
# 48429 patches in bg
# Analyzing section 144..
# 0: 95 patches in 7n
# 1: 703 patches in SNR
# 2: 296 patches in 7N
# 3: 296 patches in VLL
# 4: 352 patches in 5N
# 575 patches in 7n_surround_noclass
# 44607 patches in 7n_negative
# 1259 patches in SNR_surround_noclass
# 30 patches in SNR_surround_VLL
# 43999 patches in SNR_negative
# 695 patches in 7N_surround_noclass
# 44406 patches in 7N_negative
# 1013 patches in VLL_surround_noclass
# 29 patches in VLL_surround_SNR
# 44406 patches in VLL_negative
# 903 patches in 5N_surround_noclass
# 44350 patches in 5N_negative
# 48419 patches in bg
# Analyzing section 145..
# 0: 15 patches in SNC
# 1: 363 patches in 7N
# 2: 344 patches in VLL
# 3: 335 patches in 5N
# 4: 698 patches in SNR
# 5: 102 patches in 7n
# 481 patches in SNC_surround_noclass
# 245 patches in SNC_surround_SNR
# 43588 patches in SNC_negative
# 721 patches in 7N_surround_noclass
# 10 patches in 7N_surround_7n
# 43240 patches in 7N_negative
# 1126 patches in VLL_surround_noclass
# 38 patches in VLL_surround_SNR
# 43259 patches in VLL_negative
# 887 patches in 5N_surround_noclass
# 43268 patches in 5N_negative
# 1242 patches in SNR_surround_noclass
# 15 patches in SNR_surround_SNC
# 38 patches in SNR_surround_VLL
# 42905 patches in SNR_negative
# 579 patches in 7n_surround_noclass
# 14 patches in 7n_surround_7N
# 43501 patches in 7n_negative
# 49518 patches in bg
# Analyzing section 146..
# 0: 94 patches in 7n
# 1: 370 patches in 7N
# 2: 342 patches in 5N
# 3: 363 patches in VLL
# 4: 15 patches in SNC
# 5: 684 patches in SNR
# 559 patches in 7n_surround_noclass
# 9 patches in 7n_surround_7N
# 44939 patches in 7n_negative
# 765 patches in 7N_surround_noclass
# 12 patches in 7N_surround_7n
# 44663 patches in 7N_negative
# 874 patches in 5N_surround_noclass
# 44691 patches in 5N_negative
# 1097 patches in VLL_surround_noclass
# 23 patches in VLL_surround_SNR
# 44670 patches in VLL_negative
# 444 patches in SNC_surround_noclass
# 218 patches in SNC_surround_SNR
# 45018 patches in SNC_negative
# 1233 patches in SNR_surround_noclass
# 15 patches in SNR_surround_SNC
# 23 patches in SNR_surround_VLL
# 44349 patches in SNR_negative
# 48088 patches in bg
# Analyzing section 147..
# 0: 385 patches in 7N
# 1: 94 patches in 7n
# 2: 679 patches in SNR
# 3: 16 patches in SNC
# 4: 385 patches in VLL
# 5: 355 patches in 5N
# 781 patches in 7N_surround_noclass
# 14 patches in 7N_surround_7n
# 45492 patches in 7N_negative
# 545 patches in 7n_surround_noclass
# 13 patches in 7n_surround_7N
# 45783 patches in 7n_negative
# 1248 patches in SNR_surround_noclass
# 16 patches in SNR_surround_SNC
# 19 patches in SNR_surround_VLL
# 45198 patches in SNR_negative
# 452 patches in SNC_surround_noclass
# 211 patches in SNC_surround_SNR
# 45861 patches in SNC_negative
# 1096 patches in VLL_surround_noclass
# 18 patches in VLL_surround_SNR
# 45492 patches in VLL_negative
# 894 patches in 5N_surround_noclass
# 45522 patches in 5N_negative
# 47244 patches in bg
# Analyzing section 148..
# 0: 95 patches in 7n
# 1: 400 patches in 7N
# 2: 673 patches in SNR
# 3: 18 patches in SNC
# 4: 367 patches in 5N
# 5: 405 patches in VLL
# 545 patches in 7n_surround_noclass
# 15 patches in 7n_surround_7N
# 43975 patches in 7n_negative
# 788 patches in 7N_surround_noclass
# 16 patches in 7N_surround_7n
# 43670 patches in 7N_negative
# 1246 patches in SNR_surround_noclass
# 18 patches in SNR_surround_SNC
# 16 patches in SNR_surround_VLL
# 43397 patches in SNR_negative
# 444 patches in SNC_surround_noclass
# 196 patches in SNC_surround_SNR
# 44052 patches in SNC_negative
# 903 patches in 5N_surround_noclass
# 43703 patches in 5N_negative
# 1090 patches in VLL_surround_noclass
# 13 patches in VLL_surround_SNR
# 43665 patches in VLL_negative
# 49051 patches in bg
# Analyzing section 149..
# 0: 91 patches in 7n
# 1: 418 patches in 7N
# 2: 663 patches in SNR
# 3: 17 patches in SNC
# 4: 385 patches in 5N
# 5: 420 patches in VLL
# 542 patches in 7n_surround_noclass
# 17 patches in 7n_surround_7N
# 44635 patches in 7n_negative
# 831 patches in 7N_surround_noclass
# 19 patches in 7N_surround_7n
# 44308 patches in 7N_negative
# 1277 patches in SNR_surround_noclass
# 17 patches in SNR_surround_SNC
# 8 patches in SNR_surround_VLL
# 44063 patches in SNR_negative
# 445 patches in SNC_surround_noclass
# 180 patches in SNC_surround_SNR
# 44709 patches in SNC_negative
# 916 patches in 5N_surround_noclass
# 44341 patches in 5N_negative
# 1065 patches in VLL_surround_noclass
# 9 patches in VLL_surround_SNR
# 44306 patches in VLL_negative
# 48395 patches in bg
# Analyzing section 150..
# 0: 412 patches in 5N
# 1: 446 patches in VLL
# 2: 2057 patches in IC
# 3: 446 patches in 7N
# 4: 2091 patches in SC
# 5: 100 patches in 7n
# 6: 22 patches in SNC
# 7: 678 patches in SNR
# 948 patches in 5N_surround_noclass
# 48314 patches in 5N_negative
# 1089 patches in VLL_surround_noclass
# 7 patches in VLL_surround_SNR
# 48280 patches in VLL_negative
# 1358 patches in IC_surround_noclass
# 201 patches in IC_surround_SC
# 46669 patches in IC_negative
# 810 patches in 7N_surround_noclass
# 26 patches in 7N_surround_7n
# 48280 patches in 7N_negative
# 1706 patches in SC_surround_noclass
# 240 patches in SC_surround_IC
# 46635 patches in SC_negative
# 545 patches in 7n_surround_noclass
# 25 patches in 7n_surround_7N
# 48626 patches in 7n_negative
# 485 patches in SNC_surround_noclass
# 190 patches in SNC_surround_SNR
# 48704 patches in SNC_negative
# 1307 patches in SNR_surround_noclass
# 6 patches in SNR_surround_VLL
# 22 patches in SNR_surround_SNC
# 48048 patches in SNR_negative
# 44395 patches in bg
# Analyzing section 151..
# 0: 436 patches in 7N
# 1: 90 patches in 7n
# 2: 2036 patches in SC
# 3: 2112 patches in IC
# 4: 29 patches in SNC
# 5: 642 patches in SNR
# 825 patches in 7N_surround_noclass
# 10 patches in 7N_surround_7n
# 44493 patches in 7N_negative
# 556 patches in 7n_surround_noclass
# 11 patches in 7n_surround_7N
# 44839 patches in 7n_negative
# 1664 patches in SC_surround_noclass
# 233 patches in SC_surround_IC
# 42893 patches in SC_negative
# 1360 patches in IC_surround_noclass
# 201 patches in IC_surround_SC
# 42817 patches in IC_negative
# 462 patches in SNC_surround_noclass
# 180 patches in SNC_surround_SNR
# 44900 patches in SNC_negative
# 1266 patches in SNR_surround_noclass
# 29 patches in SNR_surround_SNC
# 44287 patches in SNR_negative
# 48192 patches in bg
# Analyzing section 152..
# 0: 2174 patches in IC
# 1: 2004 patches in SC
# 2: 97 patches in 7n
# 3: 635 patches in SNR
# 4: 439 patches in 7N
# 5: 40 patches in SNC
# 1408 patches in IC_surround_noclass
# 206 patches in IC_surround_SC
# 44953 patches in IC_negative
# 1642 patches in SC_surround_noclass
# 242 patches in SC_surround_IC
# 45123 patches in SC_negative
# 557 patches in 7n_surround_noclass
# 4 patches in 7n_surround_7N
# 47030 patches in 7n_negative
# 1245 patches in SNR_surround_noclass
# 40 patches in SNR_surround_SNC
# 46492 patches in SNR_negative
# 840 patches in 7N_surround_noclass
# 3 patches in 7N_surround_7n
# 46688 patches in 7N_negative
# 462 patches in SNC_surround_noclass
# 184 patches in SNC_surround_SNR
# 47087 patches in SNC_negative
# 45994 patches in bg
# Analyzing section 153..
# 0: 94 patches in 7n
# 1: 622 patches in SNR
# 2: 1986 patches in SC
# 3: 2264 patches in IC
# 4: 52 patches in SNC
# 5: 431 patches in 7N
# 574 patches in 7n_surround_noclass
# 46444 patches in 7n_negative
# 1219 patches in SNR_surround_noclass
# 52 patches in SNR_surround_SNC
# 45916 patches in SNR_negative
# 1581 patches in SC_surround_noclass
# 253 patches in SC_surround_IC
# 44552 patches in SC_negative
# 1429 patches in IC_surround_noclass
# 221 patches in IC_surround_SC
# 44274 patches in IC_negative
# 459 patches in SNC_surround_noclass
# 185 patches in SNC_surround_SNR
# 46486 patches in SNC_negative
# 834 patches in 7N_surround_noclass
# 46107 patches in 7N_negative
# 46583 patches in bg
# Analyzing section 154..
# 0: 2340 patches in IC
# 1: 1952 patches in SC
# 2: 98 patches in 7n
# 3: 425 patches in 7N
# 4: 64 patches in SNC
# 5: 610 patches in SNR
# 1466 patches in IC_surround_noclass
# 223 patches in IC_surround_SC
# 44019 patches in IC_negative
# 1570 patches in SC_surround_noclass
# 259 patches in SC_surround_IC
# 44407 patches in SC_negative
# 578 patches in 7n_surround_noclass
# 46261 patches in 7n_negative
# 822 patches in 7N_surround_noclass
# 45934 patches in 7N_negative
# 463 patches in SNC_surround_noclass
# 190 patches in SNC_surround_SNR
# 46295 patches in SNC_negative
# 1208 patches in SNR_surround_noclass
# 64 patches in SNR_surround_SNC
# 45749 patches in SNR_negative
# 46762 patches in bg
# Analyzing section 155..
# 0: 322 patches in 5N
# 1: 616 patches in SNR
# 2: 2425 patches in IC
# 3: 80 patches in SNC
# 4: 433 patches in 7N
# 5: 108 patches in 7n
# 6: 1958 patches in SC
# 7: 411 patches in VLL
# 891 patches in 5N_surround_noclass
# 46951 patches in 5N_negative
# 1207 patches in SNR_surround_noclass
# 80 patches in SNR_surround_SNC
# 1 patches in SNR_surround_VLL
# 46657 patches in SNR_negative
# 1505 patches in IC_surround_noclass
# 242 patches in IC_surround_SC
# 44848 patches in IC_negative
# 485 patches in SNC_surround_noclass
# 217 patches in SNC_surround_SNR
# 47193 patches in SNC_negative
# 827 patches in 7N_surround_noclass
# 46840 patches in 7N_negative
# 599 patches in 7n_surround_noclass
# 47165 patches in 7n_negative
# 1553 patches in SC_surround_noclass
# 280 patches in SC_surround_IC
# 45315 patches in SC_negative
# 1125 patches in VLL_surround_noclass
# 46862 patches in VLL_negative
# 45848 patches in bg
# Analyzing section 156..
# 0: 101 patches in 7n
# 1: 2019 patches in SC
# 2: 2303 patches in IC
# 3: 65 patches in SNC
# 4: 599 patches in SNR
# 5: 405 patches in 7N
# 591 patches in 7n_surround_noclass
# 45151 patches in 7n_negative
# 1573 patches in SC_surround_noclass
# 274 patches in SC_surround_IC
# 43233 patches in SC_negative
# 1442 patches in IC_surround_noclass
# 239 patches in IC_surround_SC
# 42949 patches in IC_negative
# 450 patches in SNC_surround_noclass
# 204 patches in SNC_surround_SNR
# 45187 patches in SNC_negative
# 1194 patches in SNR_surround_noclass
# 65 patches in SNR_surround_SNC
# 44653 patches in SNR_negative
# 928 patches in 7N_surround_noclass
# 44847 patches in 7N_negative
# 47869 patches in bg
# Analyzing section 157..
# 0: 101 patches in 7n
# 1: 2099 patches in SC
# 2: 60 patches in SNC
# 3: 607 patches in SNR
# 4: 391 patches in 7N
# 5: 2218 patches in IC
# 594 patches in 7n_surround_noclass
# 48404 patches in 7n_negative
# 1581 patches in SC_surround_noclass
# 276 patches in SC_surround_IC
# 46406 patches in SC_negative
# 437 patches in SNC_surround_noclass
# 214 patches in SNC_surround_SNR
# 48445 patches in SNC_negative
# 1191 patches in SNR_surround_noclass
# 60 patches in SNR_surround_SNC
# 47898 patches in SNR_negative
# 856 patches in 7N_surround_noclass
# 48114 patches in 7N_negative
# 1433 patches in IC_surround_noclass
# 242 patches in IC_surround_SC
# 46287 patches in IC_negative
# 44616 patches in bg
# Analyzing section 158..
# 0: 370 patches in 7N
# 1: 102 patches in 7n
# 2: 2188 patches in SC
# 3: 2125 patches in IC
# 4: 611 patches in SNR
# 5: 50 patches in SNC
# 874 patches in 7N_surround_noclass
# 49784 patches in 7N_negative
# 598 patches in 7n_surround_noclass
# 50052 patches in 7n_negative
# 1620 patches in SC_surround_noclass
# 285 patches in SC_surround_IC
# 47966 patches in SC_negative
# 1364 patches in IC_surround_noclass
# 253 patches in IC_surround_SC
# 48029 patches in IC_negative
# 1204 patches in SNR_surround_noclass
# 50 patches in SNR_surround_SNC
# 49543 patches in SNR_negative
# 415 patches in SNC_surround_noclass
# 217 patches in SNC_surround_SNR
# 50104 patches in SNC_negative
# 42967 patches in bg
# Analyzing section 159..
# 0: 350 patches in 7N
# 1: 44 patches in SNC
# 2: 2046 patches in IC
# 3: 614 patches in SNR
# 4: 95 patches in 7n
# 5: 2269 patches in SC
# 873 patches in 7N_surround_noclass
# 50370 patches in 7N_negative
# 408 patches in SNC_surround_noclass
# 216 patches in SNC_surround_SNR
# 50676 patches in SNC_negative
# 1329 patches in IC_surround_noclass
# 258 patches in IC_surround_SC
# 48674 patches in IC_negative
# 1208 patches in SNR_surround_noclass
# 44 patches in SNR_surround_SNC
# 50106 patches in SNR_negative
# 605 patches in 7n_surround_noclass
# 50625 patches in 7n_negative
# 1633 patches in SC_surround_noclass
# 294 patches in SC_surround_IC
# 48451 patches in SC_negative
# 42401 patches in bg
# Analyzing section 160..
# 0: 43 patches in SNC
# 1: 2365 patches in SC
# 2: 1956 patches in IC
# 3: 626 patches in SNR
# 4: 339 patches in 7N
# 5: 105 patches in 7n
# 410 patches in SNC_surround_noclass
# 236 patches in SNC_surround_SNR
# 49810 patches in SNC_negative
# 1677 patches in SC_surround_noclass
# 302 patches in SC_surround_IC
# 47488 patches in SC_negative
# 1334 patches in IC_surround_noclass
# 268 patches in IC_surround_SC
# 47897 patches in IC_negative
# 1225 patches in SNR_surround_noclass
# 43 patches in SNR_surround_SNC
# 49227 patches in SNR_negative
# 891 patches in 7N_surround_noclass
# 49514 patches in 7N_negative
# 625 patches in 7n_surround_noclass
# 49748 patches in 7n_negative
# 43268 patches in bg
# Analyzing section 161..
# 0: 315 patches in 7N
# 1: 98 patches in 7n
# 2: 34 patches in SNC
# 3: 2433 patches in SC
# 4: 1885 patches in IC
# 5: 577 patches in SNR
# 863 patches in 7N_surround_noclass
# 50450 patches in 7N_negative
# 593 patches in 7n_surround_noclass
# 50667 patches in 7n_negative
# 393 patches in SNC_surround_noclass
# 214 patches in SNC_surround_SNR
# 50731 patches in SNC_negative
# 1705 patches in SC_surround_noclass
# 307 patches in SC_surround_IC
# 48332 patches in SC_negative
# 1288 patches in IC_surround_noclass
# 272 patches in IC_surround_SC
# 48880 patches in IC_negative
# 1185 patches in SNR_surround_noclass
# 34 patches in SNR_surround_SNC
# 50188 patches in SNR_negative
# 42356 patches in bg
# Analyzing section 162..
# 0: 304 patches in 7N
# 1: 543 patches in SNR
# 2: 2526 patches in SC
# 3: 93 patches in 7n
# 4: 1807 patches in IC
# 5: 28 patches in SNC
# 6: 39 patches in Pn
# 853 patches in 7N_surround_noclass
# 51728 patches in 7N_negative
# 1158 patches in SNR_surround_noclass
# 28 patches in SNR_surround_SNC
# 51489 patches in SNR_negative
# 1740 patches in SC_surround_noclass
# 309 patches in SC_surround_IC
# 49506 patches in SC_negative
# 580 patches in 7n_surround_noclass
# 51939 patches in 7n_negative
# 1220 patches in IC_surround_noclass
# 276 patches in IC_surround_SC
# 50225 patches in IC_negative
# 376 patches in SNC_surround_noclass
# 197 patches in SNC_surround_SNR
# 52004 patches in SNC_negative
# 592 patches in Pn_surround_noclass
# 51993 patches in Pn_negative
# 41089 patches in bg
# Analyzing section 163..
# 0: 85 patches in 7n
# 1: 499 patches in SNR
# 2: 59 patches in Pn
# 3: 282 patches in 7N
# 4: 25 patches in SNC
# 5: 2619 patches in SC
# 6: 1715 patches in IC
# 559 patches in 7n_surround_noclass
# 51746 patches in 7n_negative
# 1116 patches in SNR_surround_noclass
# 25 patches in SNR_surround_SNC
# 51332 patches in SNR_negative
# 609 patches in Pn_surround_noclass
# 51772 patches in Pn_negative
# 841 patches in 7N_surround_noclass
# 51549 patches in 7N_negative
# 360 patches in SNC_surround_noclass
# 184 patches in SNC_surround_SNR
# 51806 patches in SNC_negative
# 1772 patches in SC_surround_noclass
# 296 patches in SC_surround_IC
# 49212 patches in SC_negative
# 1184 patches in IC_surround_noclass
# 267 patches in IC_surround_SC
# 50116 patches in IC_negative
# 41290 patches in bg
# Analyzing section 164..
# 0: 2710 patches in SC
# 1: 1651 patches in IC
# 2: 83 patches in 7n
# 3: 77 patches in Pn
# 4: 465 patches in SNR
# 5: 260 patches in 7N
# 6: 19 patches in SNC
# 1801 patches in SC_surround_noclass
# 308 patches in SC_surround_IC
# 49437 patches in SC_negative
# 1141 patches in IC_surround_noclass
# 279 patches in IC_surround_SC
# 50496 patches in IC_negative
# 545 patches in 7n_surround_noclass
# 52064 patches in 7n_negative
# 627 patches in Pn_surround_noclass
# 52070 patches in Pn_negative
# 1084 patches in SNR_surround_noclass
# 19 patches in SNR_surround_SNC
# 51682 patches in SNR_negative
# 816 patches in 7N_surround_noclass
# 51887 patches in 7N_negative
# 346 patches in SNC_surround_noclass
# 176 patches in SNC_surround_SNR
# 52128 patches in SNC_negative
# 40974 patches in bg
# Analyzing section 165..
# 0: 2818 patches in SC
# 1: 1569 patches in IC
# 2: 81 patches in 7n
# 3: 113 patches in Pn
# 4: 15 patches in SNC
# 5: 435 patches in SNR
# 6: 256 patches in 7N
# 1826 patches in SC_surround_noclass
# 301 patches in SC_surround_IC
# 50090 patches in SC_negative
# 1046 patches in IC_surround_noclass
# 278 patches in IC_surround_SC
# 51339 patches in IC_negative
# 563 patches in 7n_surround_noclass
# 52827 patches in 7n_negative
# 702 patches in Pn_surround_noclass
# 52795 patches in Pn_negative
# 350 patches in SNC_surround_noclass
# 174 patches in SNC_surround_SNR
# 52893 patches in SNC_negative
# 1069 patches in SNR_surround_noclass
# 15 patches in SNR_surround_SNC
# 52473 patches in SNR_negative
# 808 patches in 7N_surround_noclass
# 52652 patches in 7N_negative
# 40213 patches in bg
# Analyzing section 166..
# 0: 74 patches in 7n
# 1: 254 patches in 7N
# 2: 2908 patches in SC
# 3: 1493 patches in IC
# 4: 128 patches in Pn
# 5: 21 patches in SNC
# 6: 405 patches in SNR
# 535 patches in 7n_surround_noclass
# 53160 patches in 7n_negative
# 804 patches in 7N_surround_noclass
# 52980 patches in 7N_negative
# 1868 patches in SC_surround_noclass
# 296 patches in SC_surround_IC
# 50326 patches in SC_negative
# 1040 patches in IC_surround_noclass
# 279 patches in IC_surround_SC
# 51741 patches in IC_negative
# 705 patches in Pn_surround_noclass
# 53106 patches in Pn_negative
# 355 patches in SNC_surround_noclass
# 166 patches in SNC_surround_SNR
# 53213 patches in SNC_negative
# 1023 patches in SNR_surround_noclass
# 21 patches in SNR_surround_SNC
# 52829 patches in SNR_negative
# 39887 patches in bg
# Analyzing section 167..
# 0: 3001 patches in SC
# 1: 83 patches in 7n
# 2: 1422 patches in IC
# 3: 165 patches in Pn
# 4: 260 patches in 7N
# 5: 31 patches in SNC
# 6: 378 patches in SNR
# 1919 patches in SC_surround_noclass
# 285 patches in SC_surround_IC
# 49782 patches in SC_negative
# 538 patches in 7n_surround_noclass
# 52700 patches in 7n_negative
# 1028 patches in IC_surround_noclass
# 262 patches in IC_surround_SC
# 51361 patches in IC_negative
# 743 patches in Pn_surround_noclass
# 52618 patches in Pn_negative
# 810 patches in 7N_surround_noclass
# 52523 patches in 7N_negative
# 380 patches in SNC_surround_noclass
# 175 patches in SNC_surround_SNR
# 52752 patches in SNC_negative
# 986 patches in SNR_surround_noclass
# 31 patches in SNR_surround_SNC
# 52405 patches in SNR_negative
# 40338 patches in bg
# Analyzing section 168..
# 0: 196 patches in Pn
# 1: 3090 patches in SC
# 2: 1352 patches in IC
# 3: 83 patches in 7n
# 4: 268 patches in 7N
# 5: 360 patches in SNR
# 6: 37 patches in SNC
# 764 patches in Pn_surround_noclass
# 52827 patches in Pn_negative
# 1895 patches in SC_surround_noclass
# 277 patches in SC_surround_IC
# 49933 patches in SC_negative
# 984 patches in IC_surround_noclass
# 258 patches in IC_surround_SC
# 51671 patches in IC_negative
# 545 patches in 7n_surround_noclass
# 52940 patches in 7n_negative
# 810 patches in 7N_surround_noclass
# 52755 patches in 7N_negative
# 963 patches in SNR_surround_noclass
# 37 patches in SNR_surround_SNC
# 52663 patches in SNR_negative
# 398 patches in SNC_surround_noclass
# 184 patches in SNC_surround_SNR
# 52986 patches in SNC_negative
# 40098 patches in bg
# Analyzing section 169..
# 0: 3191 patches in SC
# 1: 1272 patches in IC
# 2: 338 patches in SNR
# 3: 232 patches in Pn
# 4: 84 patches in 7n
# 5: 49 patches in SNC
# 6: 280 patches in 7N
# 2013 patches in SC_surround_noclass
# 264 patches in SC_surround_IC
# 50147 patches in SC_negative
# 1017 patches in IC_surround_noclass
# 248 patches in IC_surround_SC
# 52066 patches in IC_negative
# 926 patches in SNR_surround_noclass
# 49 patches in SNR_surround_SNC
# 53000 patches in SNR_negative
# 781 patches in Pn_surround_noclass
# 53106 patches in Pn_negative
# 543 patches in 7n_surround_noclass
# 53254 patches in 7n_negative
# 432 patches in SNC_surround_noclass
# 194 patches in SNC_surround_SNR
# 53289 patches in SNC_negative
# 799 patches in 7N_surround_noclass
# 53058 patches in 7N_negative
# 39783 patches in bg
# Analyzing section 170..
# 0: 1227 patches in IC
# 1: 199 patches in LC
# 2: 289 patches in 7N
# 3: 60 patches in SNC
# 4: 100 patches in 7n
# 5: 270 patches in Pn
# 6: 328 patches in SNR
# 7: 3323 patches in SC
# 920 patches in IC_surround_noclass
# 258 patches in IC_surround_SC
# 51964 patches in IC_negative
# 879 patches in LC_surround_noclass
# 52992 patches in LC_negative
# 797 patches in 7N_surround_noclass
# 52902 patches in 7N_negative
# 481 patches in SNC_surround_noclass
# 208 patches in SNC_surround_SNR
# 53131 patches in SNC_negative
# 562 patches in 7n_surround_noclass
# 53091 patches in 7n_negative
# 805 patches in Pn_surround_noclass
# 52921 patches in Pn_negative
# 923 patches in SNR_surround_noclass
# 60 patches in SNR_surround_SNC
# 52863 patches in SNR_negative
# 1999 patches in SC_surround_noclass
# 271 patches in SC_surround_IC
# 49868 patches in SC_negative
# 39930 patches in bg
# Analyzing section 171..
# 0: 1196 patches in IC
# 1: 273 patches in Pn
# 2: 87 patches in 7n
# 3: 3169 patches in SC
# 4: 192 patches in LC
# 5: 291 patches in 7N
# 911 patches in IC_surround_noclass
# 243 patches in IC_surround_SC
# 52606 patches in IC_negative
# 799 patches in Pn_surround_noclass
# 53529 patches in Pn_negative
# 543 patches in 7n_surround_noclass
# 53715 patches in 7n_negative
# 1979 patches in SC_surround_noclass
# 253 patches in SC_surround_IC
# 50633 patches in SC_negative
# 790 patches in LC_surround_noclass
# 53610 patches in LC_negative
# 787 patches in 7N_surround_noclass
# 53511 patches in 7N_negative
# 39319 patches in bg
# Analyzing section 172..
# 0: 286 patches in Pn
# 1: 1168 patches in IC
# 2: 3011 patches in SC
# 3: 87 patches in 7n
# 4: 294 patches in 7N
# 5: 192 patches in LC
# 783 patches in Pn_surround_noclass
# 53515 patches in Pn_negative
# 917 patches in IC_surround_noclass
# 237 patches in IC_surround_SC
# 52633 patches in IC_negative
# 1857 patches in SC_surround_noclass
# 245 patches in SC_surround_IC
# 50790 patches in SC_negative
# 543 patches in 7n_surround_noclass
# 53714 patches in 7n_negative
# 759 patches in 7N_surround_noclass
# 53507 patches in 7N_negative
# 757 patches in LC_surround_noclass
# 53609 patches in LC_negative
# 39320 patches in bg
# Analyzing section 173..
# 0: 1147 patches in IC
# 1: 86 patches in 7n
# 2: 2896 patches in SC
# 3: 289 patches in Pn
# 4: 300 patches in 7N
# 5: 193 patches in LC
# 912 patches in IC_surround_noclass
# 224 patches in IC_surround_SC
# 53110 patches in IC_negative
# 540 patches in 7n_surround_noclass
# 54171 patches in 7n_negative
# 1805 patches in SC_surround_noclass
# 234 patches in SC_surround_IC
# 51361 patches in SC_negative
# 775 patches in Pn_surround_noclass
# 53968 patches in Pn_negative
# 757 patches in 7N_surround_noclass
# 53957 patches in 7N_negative
# 772 patches in LC_surround_noclass
# 54064 patches in LC_negative
# 38864 patches in bg
# Analyzing section 174..
# 0: 1125 patches in IC
# 1: 259 patches in LC
# 2: 297 patches in Pn
# 3: 2750 patches in SC
# 4: 310 patches in 7N
# 5: 84 patches in 7n
# 912 patches in IC_surround_noclass
# 217 patches in IC_surround_SC
# 53781 patches in IC_negative
# 869 patches in LC_surround_noclass
# 54647 patches in LC_negative
# 780 patches in Pn_surround_noclass
# 54609 patches in Pn_negative
# 1750 patches in SC_surround_noclass
# 227 patches in SC_surround_IC
# 52156 patches in SC_negative
# 717 patches in 7N_surround_noclass
# 54596 patches in 7N_negative
# 537 patches in 7n_surround_noclass
# 54822 patches in 7n_negative
# 38215 patches in bg
# Analyzing section 175..
# 0: 2643 patches in SC
# 1: 195 patches in LC
# 2: 314 patches in Pn
# 3: 1117 patches in IC
# 4: 320 patches in 7N
# 5: 94 patches in 7n
# 1702 patches in SC_surround_noclass
# 232 patches in SC_surround_IC
# 52436 patches in SC_negative
# 768 patches in LC_surround_noclass
# 54884 patches in LC_negative
# 795 patches in Pn_surround_noclass
# 54765 patches in Pn_negative
# 925 patches in IC_surround_noclass
# 219 patches in IC_surround_SC
# 53962 patches in IC_negative
# 834 patches in 7N_surround_noclass
# 54759 patches in 7N_negative
# 550 patches in 7n_surround_noclass
# 54985 patches in 7n_negative
# 38042 patches in bg
# Analyzing section 176..
# 0: 327 patches in Pn
# 1: 2633 patches in SC
# 2: 78 patches in 7n
# 3: 1045 patches in IC
# 4: 292 patches in 7N
# 5: 151 patches in LC
# 786 patches in Pn_surround_noclass
# 55037 patches in Pn_negative
# 1829 patches in SC_surround_noclass
# 210 patches in SC_surround_IC
# 52731 patches in SC_negative
# 528 patches in 7n_surround_noclass
# 55286 patches in 7n_negative
# 943 patches in IC_surround_noclass
# 197 patches in IC_surround_SC
# 54319 patches in IC_negative
# 697 patches in 7N_surround_noclass
# 55072 patches in 7N_negative
# 728 patches in LC_surround_noclass
# 55213 patches in LC_negative
# 37757 patches in bg
# Analyzing section 177..
# 0: 2635 patches in SC
# 1: 1002 patches in IC
# 2: 76 patches in 7n
# 3: 339 patches in Pn
# 4: 270 patches in 7N
# 1851 patches in SC_surround_noclass
# 205 patches in SC_surround_IC
# 53333 patches in SC_negative
# 928 patches in IC_surround_noclass
# 191 patches in IC_surround_SC
# 54966 patches in IC_negative
# 524 patches in 7n_surround_noclass
# 55892 patches in 7n_negative
# 798 patches in Pn_surround_noclass
# 55629 patches in Pn_negative
# 746 patches in 7N_surround_noclass
# 55698 patches in 7N_negative
# 37153 patches in bg
# Analyzing section 178..
# 0: 2648 patches in SC
# 1: 958 patches in IC
# 2: 361 patches in Pn
# 3: 74 patches in 7n
# 4: 254 patches in 7N
# 1752 patches in SC_surround_noclass
# 203 patches in SC_surround_IC
# 53052 patches in SC_negative
# 868 patches in IC_surround_noclass
# 191 patches in IC_surround_SC
# 54742 patches in IC_negative
# 805 patches in Pn_surround_noclass
# 55339 patches in Pn_negative
# 517 patches in 7n_surround_noclass
# 55626 patches in 7n_negative
# 697 patches in 7N_surround_noclass
# 55446 patches in 7N_negative
# 37421 patches in bg
# Analyzing section 179..
# 0: 2641 patches in SC
# 1: 381 patches in Pn
# 2: 234 patches in 7N
# 3: 70 patches in 7n
# 4: 907 patches in IC
# 1786 patches in SC_surround_noclass
# 193 patches in SC_surround_IC
# 53302 patches in SC_negative
# 800 patches in Pn_surround_noclass
# 55562 patches in Pn_negative
# 665 patches in 7N_surround_noclass
# 55709 patches in 7N_negative
# 514 patches in 7n_surround_noclass
# 55873 patches in 7n_negative
# 850 patches in IC_surround_noclass
# 177 patches in IC_surround_SC
# 55036 patches in IC_negative
# 37178 patches in bg
# Analyzing section 180..
# 0: 220 patches in 7N
# 1: 71 patches in 7n
# 2: 409 patches in Pn
# 3: 874 patches in IC
# 4: 2659 patches in SC
# 644 patches in 7N_surround_noclass
# 55851 patches in 7N_negative
# 512 patches in 7n_surround_noclass
# 56000 patches in 7n_negative
# 755 patches in Pn_surround_noclass
# 55662 patches in Pn_negative
# 834 patches in IC_surround_noclass
# 179 patches in IC_surround_SC
# 55197 patches in IC_negative
# 1812 patches in SC_surround_noclass
# 201 patches in SC_surround_IC
# 53412 patches in SC_negative
# 37050 patches in bg
# Analyzing section 181..
# 0: 2667 patches in SC
# 1: 813 patches in IC
# 2: 394 patches in Pn
# 3: 68 patches in 7n
# 1817 patches in SC_surround_noclass
# 187 patches in SC_surround_IC
# 53522 patches in SC_negative
# 821 patches in IC_surround_noclass
# 169 patches in IC_surround_SC
# 55376 patches in IC_negative
# 813 patches in Pn_surround_noclass
# 55795 patches in Pn_negative
# 503 patches in 7n_surround_noclass
# 56121 patches in 7n_negative
# 36932 patches in bg
# Analyzing section 182..
# 0: 772 patches in IC
# 1: 2673 patches in SC
# 2: 65 patches in 7n
# 3: 394 patches in Pn
# 810 patches in IC_surround_noclass
# 160 patches in IC_surround_SC
# 55708 patches in IC_negative
# 1836 patches in SC_surround_noclass
# 176 patches in SC_surround_IC
# 53807 patches in SC_negative
# 506 patches in 7n_surround_noclass
# 56415 patches in 7n_negative
# 819 patches in Pn_surround_noclass
# 56086 patches in Pn_negative
# 36641 patches in bg
# Analyzing section 183..
# 0: 391 patches in Pn
# 1: 728 patches in IC
# 2: 64 patches in 7n
# 3: 2693 patches in SC
# 801 patches in Pn_surround_noclass
# 56007 patches in Pn_negative
# 794 patches in IC_surround_noclass
# 157 patches in IC_surround_SC
# 55670 patches in IC_negative
# 503 patches in 7n_surround_noclass
# 56334 patches in 7n_negative
# 1843 patches in SC_surround_noclass
# 172 patches in SC_surround_IC
# 53705 patches in SC_negative
# 36723 patches in bg
# Analyzing section 184..
# 0: 691 patches in IC
# 1: 2700 patches in SC
# 2: 391 patches in Pn
# 3: 63 patches in 7n
# 786 patches in IC_surround_noclass
# 157 patches in IC_surround_SC
# 55699 patches in IC_negative
# 1871 patches in SC_surround_noclass
# 173 patches in SC_surround_IC
# ...
# 5 patches in AP_surround_12N
# 56124 patches in AP_negative
# 36929 patches in bg
# Analyzing section 223..
# 0: 60 patches in AP
# 1: 586 patches in RtTg
# 2: 25 patches in 10N
# 3: 267 patches in 12N
# 4: 550 patches in IC
# 5: 2676 patches in SC
# 520 patches in AP_surround_noclass
# 3 patches in AP_surround_12N
# 56152 patches in AP_negative
# 1321 patches in RtTg_surround_noclass
# 55626 patches in RtTg_negative
# 476 patches in 10N_surround_noclass
# 95 patches in 10N_surround_12N
# 56187 patches in 10N_negative
# 964 patches in 12N_surround_noclass
# 25 patches in 12N_surround_10N
# 3 patches in 12N_surround_AP
# 55945 patches in 12N_negative
# 782 patches in IC_surround_noclass
# 143 patches in IC_surround_SC
# 55662 patches in IC_negative
# 1972 patches in SC_surround_noclass
# 162 patches in SC_surround_IC
# 53536 patches in SC_negative
# 36909 patches in bg
# Analyzing section 224..
# 0: 33 patches in 10N
# 1: 48 patches in AP
# 2: 575 patches in RtTg
# 3: 2696 patches in SC
# 4: 280 patches in 12N
# 5: 574 patches in IC
# 451 patches in 10N_surround_noclass
# 125 patches in 10N_surround_12N
# 3 patches in 10N_surround_AP
# 56425 patches in 10N_negative
# 521 patches in AP_surround_noclass
# 3 patches in AP_surround_12N
# 56410 patches in AP_negative
# 1325 patches in RtTg_surround_noclass
# 55883 patches in RtTg_negative
# 1993 patches in SC_surround_noclass
# 157 patches in SC_surround_IC
# 53762 patches in SC_negative
# 965 patches in 12N_surround_noclass
# 33 patches in 12N_surround_10N
# 2 patches in 12N_surround_AP
# 56178 patches in 12N_negative
# 802 patches in IC_surround_noclass
# 144 patches in IC_surround_SC
# 55884 patches in IC_negative
# 36663 patches in bg
# Analyzing section 225..
# 0: 2751 patches in SC
# 1: 297 patches in 12N
# 2: 155 patches in Pn
# 3: 609 patches in IC
# 4: 46 patches in AP
# 5: 35 patches in 10N
# 6: 575 patches in RtTg
# 2025 patches in SC_surround_noclass
# 178 patches in SC_surround_IC
# 53766 patches in SC_negative
# 983 patches in 12N_surround_noclass
# 35 patches in 12N_surround_10N
# 5 patches in 12N_surround_AP
# 56220 patches in 12N_negative
# 604 patches in Pn_surround_noclass
# 184 patches in Pn_surround_RtTg
# 56362 patches in Pn_negative
# 815 patches in IC_surround_noclass
# 156 patches in IC_surround_SC
# 55908 patches in IC_negative
# 531 patches in AP_surround_noclass
# 7 patches in AP_surround_12N
# 56471 patches in AP_negative
# 467 patches in 10N_surround_noclass
# 162 patches in 10N_surround_12N
# 15 patches in 10N_surround_AP
# 56482 patches in 10N_negative
# 1179 patches in RtTg_surround_noclass
# 155 patches in RtTg_surround_Pn
# 55942 patches in RtTg_negative
# 36604 patches in bg
# Analyzing section 226..
# 0: 617 patches in IC
# 1: 564 patches in RtTg
# 2: 39 patches in 10N
# 3: 295 patches in 12N
# 4: 30 patches in AP
# 5: 202 patches in Pn
# 6: 2764 patches in SC
# 811 patches in IC_surround_noclass
# 149 patches in IC_surround_SC
# 55987 patches in IC_negative
# 1131 patches in RtTg_surround_noclass
# 185 patches in RtTg_surround_Pn
# 56040 patches in RtTg_negative
# 461 patches in 10N_surround_noclass
# 182 patches in 10N_surround_12N
# 9 patches in 10N_surround_AP
# 56565 patches in 10N_negative
# 956 patches in 12N_surround_noclass
# 39 patches in 12N_surround_10N
# 1 patches in 12N_surround_AP
# 56309 patches in 12N_negative
# 486 patches in AP_surround_noclass
# 4 patches in AP_surround_10N
# 3 patches in AP_surround_12N
# 56574 patches in AP_negative
# 651 patches in Pn_surround_noclass
# 175 patches in Pn_surround_RtTg
# 56402 patches in Pn_negative
# 2028 patches in SC_surround_noclass
# 162 patches in SC_surround_IC
# 53840 patches in SC_negative
# 36517 patches in bg
# Analyzing section 227..
# 0: 2795 patches in SC
# 1: 634 patches in IC
# 2: 561 patches in RtTg
# 3: 302 patches in 12N
# 4: 274 patches in Pn
# 5: 52 patches in 10N
# 6: 22 patches in AP
# 2046 patches in SC_surround_noclass
# 173 patches in SC_surround_IC
# 54316 patches in SC_negative
# 816 patches in IC_surround_noclass
# 154 patches in IC_surround_SC
# 56477 patches in IC_negative
# 1108 patches in RtTg_surround_noclass
# 200 patches in RtTg_surround_Pn
# 56550 patches in RtTg_negative
# 931 patches in 12N_surround_noclass
# 52 patches in 12N_surround_10N
# 4 patches in 12N_surround_AP
# 56809 patches in 12N_negative
# 675 patches in Pn_surround_noclass
# 166 patches in Pn_surround_RtTg
# 56837 patches in Pn_negative
# 478 patches in 10N_surround_noclass
# 211 patches in 10N_surround_12N
# 17 patches in 10N_surround_AP
# 57059 patches in 10N_negative
# 427 patches in AP_surround_noclass
# 11 patches in AP_surround_10N
# 3 patches in AP_surround_12N
# 57089 patches in AP_negative
# 36010 patches in bg
# Analyzing section 228..
# 0: 337 patches in Pn
# 1: 2832 patches in SC
# 2: 11 patches in AP
# 3: 652 patches in IC
# 4: 307 patches in 12N
# 5: 52 patches in 10N
# 6: 567 patches in RtTg
# 772 patches in Pn_surround_noclass
# 167 patches in Pn_surround_RtTg
# 57058 patches in Pn_negative
# 2056 patches in SC_surround_noclass
# 176 patches in SC_surround_IC
# 54563 patches in SC_negative
# 406 patches in AP_surround_noclass
# 9 patches in AP_surround_10N
# 57384 patches in AP_negative
# 811 patches in IC_surround_noclass
# 155 patches in IC_surround_SC
# 56743 patches in IC_negative
# 935 patches in 12N_surround_noclass
# 52 patches in 12N_surround_10N
# 57088 patches in 12N_negative
# 513 patches in 10N_surround_noclass
# 235 patches in 10N_surround_12N
# 11 patches in 10N_surround_AP
# 57343 patches in 10N_negative
# 1113 patches in RtTg_surround_noclass
# 204 patches in RtTg_surround_Pn
# 56828 patches in RtTg_negative
# 35726 patches in bg
# Analyzing section 229..
# 0: 418 patches in Pn
# 1: 63 patches in 10N
# 2: 562 patches in RtTg
# 3: 673 patches in IC
# 4: 319 patches in 12N
# 5: 2862 patches in SC
# 6: 5 patches in AP
# 789 patches in Pn_surround_noclass
# 163 patches in Pn_surround_RtTg
# 56915 patches in Pn_negative
# 555 patches in 10N_surround_noclass
# 256 patches in 10N_surround_12N
# 5 patches in 10N_surround_AP
# 57270 patches in 10N_negative
# 1129 patches in RtTg_surround_noclass
# 209 patches in RtTg_surround_Pn
# 56771 patches in RtTg_negative
# 816 patches in IC_surround_noclass
# 163 patches in IC_surround_SC
# 56660 patches in IC_negative
# 926 patches in 12N_surround_noclass
# 63 patches in 12N_surround_10N
# 57014 patches in 12N_negative
# 2095 patches in SC_surround_noclass
# 181 patches in SC_surround_IC
# 54471 patches in SC_negative
# 396 patches in AP_surround_noclass
# 20 patches in AP_surround_10N
# 1 patches in AP_surround_12N
# 57328 patches in AP_negative
# 35788 patches in bg
# Analyzing section 230..
# 0: 500 patches in Pn
# 1: 335 patches in 12N
# 2: 700 patches in IC
# 3: 70 patches in 10N
# 4: 575 patches in RtTg
# 5: 2918 patches in SC
# 717 patches in Pn_surround_noclass
# 163 patches in Pn_surround_RtTg
# 56362 patches in Pn_negative
# 943 patches in 12N_surround_noclass
# 70 patches in 12N_surround_10N
# 56527 patches in 12N_negative
# 821 patches in IC_surround_noclass
# 182 patches in IC_surround_SC
# 56162 patches in IC_negative
# 660 patches in 10N_surround_noclass
# 264 patches in 10N_surround_12N
# 56792 patches in 10N_negative
# 1137 patches in RtTg_surround_noclass
# 213 patches in RtTg_surround_Pn
# 56287 patches in RtTg_negative
# 2129 patches in SC_surround_noclass
# 204 patches in SC_surround_IC
# 53944 patches in SC_negative
# 36259 patches in bg
# Analyzing section 231..
# 0: 2879 patches in SC
# 1: 558 patches in RtTg
# 2: 502 patches in Pn
# 3: 67 patches in 10N
# 4: 723 patches in IC
# 5: 302 patches in 12N
# 2136 patches in SC_surround_noclass
# 175 patches in SC_surround_IC
# 54570 patches in SC_negative
# 1066 patches in RtTg_surround_noclass
# 201 patches in RtTg_surround_Pn
# 56891 patches in RtTg_negative
# 732 patches in Pn_surround_noclass
# 149 patches in Pn_surround_RtTg
# 56947 patches in Pn_negative
# 562 patches in 10N_surround_noclass
# 239 patches in 10N_surround_12N
# 57382 patches in 10N_negative
# 856 patches in IC_surround_noclass
# 159 patches in IC_surround_SC
# 56726 patches in IC_negative
# 910 patches in 12N_surround_noclass
# 67 patches in 12N_surround_10N
# 57147 patches in 12N_negative
# 35672 patches in bg
# Analyzing section 232..
# Analyzing section 233..
# 0: 298 patches in 12N
# 1: 528 patches in RtTg
# 2: 59 patches in 10N
# 3: 2863 patches in SC
# 4: 529 patches in Pn
# 5: 809 patches in IC
# 877 patches in 12N_surround_noclass
# 59 patches in 12N_surround_10N
# 57244 patches in 12N_negative
# 926 patches in RtTg_surround_noclass
# 188 patches in RtTg_surround_Pn
# 57014 patches in RtTg_negative
# 460 patches in 10N_surround_noclass
# 210 patches in 10N_surround_12N
# 57483 patches in 10N_negative
# 2186 patches in SC_surround_noclass
# 150 patches in SC_surround_IC
# 54679 patches in SC_negative
# 736 patches in Pn_surround_noclass
# 144 patches in Pn_surround_RtTg
# 57013 patches in Pn_negative
# 930 patches in IC_surround_noclass
# 141 patches in IC_surround_SC
# 56733 patches in IC_negative
# 35579 patches in bg
# Analyzing section 234..
# 0: 53 patches in 10N
# 1: 542 patches in Pn
# 2: 865 patches in IC
# 3: 16 patches in 6N
# 4: 496 patches in RtTg
# 5: 287 patches in 12N
# 6: 2855 patches in SC
# 420 patches in 10N_surround_noclass
# 180 patches in 10N_surround_12N
# 56929 patches in 10N_negative
# 687 patches in Pn_surround_noclass
# 140 patches in Pn_surround_RtTg
# 56440 patches in Pn_negative
# 979 patches in IC_surround_noclass
# 137 patches in IC_surround_SC
# 56117 patches in IC_negative
# 356 patches in 6N_surround_noclass
# 56966 patches in 6N_negative
# 874 patches in RtTg_surround_noclass
# 184 patches in RtTg_surround_Pn
# 56486 patches in RtTg_negative
# 863 patches in 12N_surround_noclass
# 53 patches in 12N_surround_10N
# 56695 patches in 12N_negative
# 2197 patches in SC_surround_noclass
# 141 patches in SC_surround_IC
# 54127 patches in SC_negative
# 36139 patches in bg
# Analyzing section 235..
# 0: 919 patches in IC
# 1: 53 patches in 10N
# 2: 475 patches in RtTg
# 3: 289 patches in 12N
# 4: 569 patches in Pn
# 5: 2867 patches in SC
# 6: 29 patches in 6N
# 1033 patches in IC_surround_noclass
# 134 patches in IC_surround_SC
# 56351 patches in IC_negative
# 390 patches in 10N_surround_noclass
# 164 patches in 10N_surround_12N
# 57217 patches in 10N_negative
# 867 patches in RtTg_surround_noclass
# 191 patches in RtTg_surround_Pn
# 56795 patches in RtTg_negative
# 869 patches in 12N_surround_noclass
# 53 patches in 12N_surround_10N
# 56981 patches in 12N_negative
# 719 patches in Pn_surround_noclass
# 148 patches in Pn_surround_RtTg
# 56701 patches in Pn_negative
# 2212 patches in SC_surround_noclass
# 142 patches in SC_surround_IC
# 54403 patches in SC_negative
# 409 patches in 6N_surround_noclass
# 57241 patches in 6N_negative
# 35851 patches in bg
# Analyzing section 236..
# 0: 2937 patches in SC
# 1: 245 patches in 12N
# 2: 558 patches in Pn
# 3: 25 patches in 6N
# 4: 45 patches in 10N
# 5: 927 patches in IC
# 6: 470 patches in RtTg
# 2212 patches in SC_surround_noclass
# 146 patches in SC_surround_IC
# 54229 patches in SC_negative
# 813 patches in 12N_surround_noclass
# 45 patches in 12N_surround_10N
# 56921 patches in 12N_negative
# 704 patches in Pn_surround_noclass
# 129 patches in Pn_surround_RtTg
# 56608 patches in Pn_negative
# 402 patches in 6N_surround_noclass
# 57141 patches in 6N_negative
# 415 patches in 10N_surround_noclass
# 171 patches in 10N_surround_12N
# 57121 patches in 10N_negative
# 993 patches in IC_surround_noclass
# 140 patches in IC_surround_SC
# 56239 patches in IC_negative
# 854 patches in RtTg_surround_noclass
# 171 patches in RtTg_surround_Pn
# 56696 patches in RtTg_negative
# 35955 patches in bg
# Analyzing section 237..
# 0: 473 patches in RtTg
# 1: 27 patches in 6N
# 2: 946 patches in IC
# 3: 552 patches in Pn
# 4: 222 patches in 12N
# 5: 40 patches in 10N
# 6: 3001 patches in SC
# 866 patches in RtTg_surround_noclass
# 153 patches in RtTg_surround_Pn
# 56898 patches in RtTg_negative
# 406 patches in 6N_surround_noclass
# 57344 patches in 6N_negative
# 956 patches in IC_surround_noclass
# 143 patches in IC_surround_SC
# 56425 patches in IC_negative
# 713 patches in Pn_surround_noclass
# 114 patches in Pn_surround_RtTg
# 56819 patches in Pn_negative
# 784 patches in 12N_surround_noclass
# 40 patches in 12N_surround_10N
# 57149 patches in 12N_negative
# 448 patches in 10N_surround_noclass
# 179 patches in 10N_surround_12N
# 57331 patches in 10N_negative
# 2289 patches in SC_surround_noclass
# 151 patches in SC_surround_IC
# 54370 patches in SC_negative
# 35750 patches in bg
# Analyzing section 238..
# 0: 26 patches in 6N
# 1: 477 patches in RtTg
# 2: 31 patches in 10N
# 3: 3085 patches in SC
# 4: 192 patches in 12N
# 5: 968 patches in IC
# 6: 547 patches in Pn
# 407 patches in 6N_surround_noclass
# 56919 patches in 6N_negative
# 864 patches in RtTg_surround_noclass
# 136 patches in RtTg_surround_Pn
# 56468 patches in RtTg_negative
# 506 patches in 10N_surround_noclass
# 170 patches in 10N_surround_12N
# 56914 patches in 10N_negative
# 2319 patches in SC_surround_noclass
# 168 patches in SC_surround_IC
# 53860 patches in SC_negative
# 755 patches in 12N_surround_noclass
# 31 patches in 12N_surround_10N
# 56753 patches in 12N_negative
# 961 patches in IC_surround_noclass
# 152 patches in IC_surround_SC
# 55977 patches in IC_negative
# 722 patches in Pn_surround_noclass
# 108 patches in Pn_surround_RtTg
# 56398 patches in Pn_negative
# 36176 patches in bg
# Analyzing section 239..
# 0: 170 patches in 12N
# 1: 981 patches in IC
# 2: 2 patches in 7n
# 3: 30 patches in 6N
# 4: 3168 patches in SC
# 5: 28 patches in 10N
# 6: 548 patches in Pn
# 7: 479 patches in RtTg
# 752 patches in 12N_surround_noclass
# 28 patches in 12N_surround_10N
# 56798 patches in 12N_negative
# 923 patches in IC_surround_noclass
# 167 patches in IC_surround_SC
# 55987 patches in IC_negative
# 251 patches in 7n_surround_noclass
# 30 patches in 7n_surround_6N
# 56966 patches in 7n_negative
# 407 patches in 6N_surround_noclass
# 2 patches in 6N_surround_7n
# 56938 patches in 6N_negative
# 2217 patches in SC_surround_noclass
# 180 patches in SC_surround_IC
# 53800 patches in SC_negative
# 599 patches in 10N_surround_noclass
# 162 patches in 10N_surround_12N
# 56940 patches in 10N_negative
# 717 patches in Pn_surround_noclass
# 93 patches in Pn_surround_RtTg
# 56420 patches in Pn_negative
# 868 patches in RtTg_surround_noclass
# 128 patches in RtTg_surround_Pn
# 56489 patches in RtTg_negative
# 36153 patches in bg
# Analyzing section 240..
# 0: 34 patches in 6N
# 1: 32 patches in 10N
# 2: 74 patches in 12N
# 3: 90 patches in Tz
# 4: 3268 patches in SC
# 5: 550 patches in Pn
# 6: 7 patches in 7n
# 7: 1013 patches in IC
# 8: 486 patches in RtTg
# 424 patches in 6N_surround_noclass
# 7 patches in 6N_surround_7n
# 56801 patches in 6N_negative
# 576 patches in 10N_surround_noclass
# 74 patches in 10N_surround_12N
# 56803 patches in 10N_negative
# 580 patches in 12N_surround_noclass
# 32 patches in 12N_surround_10N
# 56761 patches in 12N_negative
# 683 patches in Tz_surround_noclass
# 22 patches in Tz_surround_RtTg
# 56745 patches in Tz_negative
# 2268 patches in SC_surround_noclass
# 203 patches in SC_surround_IC
# 53567 patches in SC_negative
# 736 patches in Pn_surround_noclass
# 88 patches in Pn_surround_RtTg
# 56285 patches in Pn_negative
# 318 patches in 7n_surround_noclass
# 34 patches in 7n_surround_6N
# 56828 patches in 7n_negative
# 902 patches in IC_surround_noclass
# 190 patches in IC_surround_SC
# 55822 patches in IC_negative
# 886 patches in RtTg_surround_noclass
# 15 patches in RtTg_surround_Tz
# 118 patches in RtTg_surround_Pn
# 56349 patches in RtTg_negative
# 36286 patches in bg
# /oasis/projects/nsf/csd395/yuncong/brain_virtualenv/lib/python2.7/site-packages/pandas/core/generic.py:1101: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->[75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 206, 207, 208, 209, 210, 211, 212, 213, 214, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 233, 234, 235, 236, 237, 238, 239, 240]]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
label_gridIndices = read_hdf(annotation_grid_indices_fn, 'grid_indices')
