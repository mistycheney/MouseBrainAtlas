# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append(os.path.join(os.environ['REPO_DIR'], 'utilities'))
from utilities2015 import *

stack = 'MD589'
username = 'yuncong'

first_bs_sec, last_bs_sec = section_range_lookup[stack]

dm = DataManager(stack=stack, labeling_dir='/home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped')

# if username == 'yuncong':
#     dm = DataManager(stack=stack, labeling_dir='/home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped')
# elif username == 'autoAnnotate':
#     dm = DataManager(stack=stack, labeling_dir='/home/yuncong/csd395/CSHL_autoAnnotations_snake')

# %%
f = open(os.path.join(dm.root_labelings_dir, stack+'_'+username+'_latestAnnotationFilenames.txt'), 'w')

for sec in range(first_bs_sec, last_bs_sec + 1):

    dm.set_slice(sec)
    
    ret = dm.load_review_result_path(username, 'latest', suffix='consolidated')
    if ret is not None:
        fn = ret[0]
        print fn
        f.write(fn + '\n')
        
f.close()
# Out:
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0110/MD589_0110_yuncong_02222016165037_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0111/MD589_0111_yuncong_01032016152005_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0113/MD589_0113_yuncong_01032016152007_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0115/MD589_0115_yuncong_01032016152008_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0117/MD589_0117_yuncong_01032016152008_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0119/MD589_0119_yuncong_01032016152008_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0121/MD589_0121_yuncong_01032016152009_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0123/MD589_0123_yuncong_01032016152009_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0125/MD589_0125_yuncong_01032016152420_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0127/MD589_0127_yuncong_01112016024152_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0129/MD589_0129_yuncong_01112016024152_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0131/MD589_0131_yuncong_01112016024152_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0133/MD589_0133_yuncong_01112016024152_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0135/MD589_0135_yuncong_01112016024152_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0137/MD589_0137_yuncong_01112016024152_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0139/MD589_0139_yuncong_01112016024152_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0141/MD589_0141_yuncong_01112016023008_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0143/MD589_0143_yuncong_01112016022744_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0145/MD589_0145_yuncong_01112016023214_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0147/MD589_0147_yuncong_01112016022620_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0149/MD589_0149_yuncong_02222016170150_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0150/MD589_0150_yuncong_02222016170142_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0151/MD589_0151_yuncong_02222016170130_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0152/MD589_0152_yuncong_02222016170247_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0153/MD589_0153_yuncong_01032016154808_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0154/MD589_0154_yuncong_02222016171239_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0155/MD589_0155_yuncong_02042016235732_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0156/MD589_0156_yuncong_02222016171057_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0157/MD589_0157_yuncong_01032016154808_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0158/MD589_0158_yuncong_02222016171132_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0159/MD589_0159_yuncong_02222016172919_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0160/MD589_0160_yuncong_02222016172919_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0161/MD589_0161_yuncong_02222016172919_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0162/MD589_0162_yuncong_02222016172919_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0163/MD589_0163_yuncong_02222016172919_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0164/MD589_0164_yuncong_02222016172919_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0165/MD589_0165_yuncong_02222016172919_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0166/MD589_0166_yuncong_02222016173954_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0167/MD589_0167_yuncong_02222016174127_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0168/MD589_0168_yuncong_02222016174510_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0169/MD589_0169_yuncong_02222016174713_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0170/MD589_0170_yuncong_02222016175433_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0171/MD589_0171_yuncong_02222016175742_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0172/MD589_0172_yuncong_02222016180714_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0173/MD589_0173_yuncong_02222016180714_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0174/MD589_0174_yuncong_02222016180714_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0175/MD589_0175_yuncong_02222016180843_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0176/MD589_0176_yuncong_02222016181039_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0177/MD589_0177_yuncong_02222016180957_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0178/MD589_0178_yuncong_02222016180932_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0179/MD589_0179_yuncong_01032016154931_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0180/MD589_0180_yuncong_02222016181702_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0181/MD589_0181_yuncong_01032016155006_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0182/MD589_0182_yuncong_02222016181551_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0183/MD589_0183_yuncong_02222016181921_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0184/MD589_0184_yuncong_02222016181859_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0185/MD589_0185_yuncong_01032016155007_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0186/MD589_0186_yuncong_02222016182039_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0187/MD589_0187_yuncong_02222016184120_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0188/MD589_0188_yuncong_02222016184053_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0189/MD589_0189_yuncong_02222016184044_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0190/MD589_0190_yuncong_02222016184029_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0191/MD589_0191_yuncong_01122016195826_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0192/MD589_0192_yuncong_02222016184249_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0193/MD589_0193_yuncong_02222016184250_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0194/MD589_0194_yuncong_03032016023919_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0195/MD589_0195_yuncong_02222016184250_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0196/MD589_0196_yuncong_02222016184250_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0197/MD589_0197_yuncong_02222016185317_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0198/MD589_0198_yuncong_02222016185317_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0199/MD589_0199_yuncong_02222016185317_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0200/MD589_0200_yuncong_02222016185317_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0201/MD589_0201_yuncong_02222016185317_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0202/MD589_0202_yuncong_03032016024118_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0203/MD589_0203_yuncong_02222016185318_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0204/MD589_0204_yuncong_03032016040424_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0205/MD589_0205_yuncong_01122016193838_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0206/MD589_0206_yuncong_03032016040455_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0207/MD589_0207_yuncong_01122016193718_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0208/MD589_0208_yuncong_03032016041300_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0209/MD589_0209_yuncong_01122016193718_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0210/MD589_0210_yuncong_03032016041453_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0211/MD589_0211_yuncong_01122016193718_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0212/MD589_0212_yuncong_03032016041529_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0213/MD589_0213_yuncong_01122016193718_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0214/MD589_0214_yuncong_03032016042319_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0215/MD589_0215_yuncong_01122016185735_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0216/MD589_0216_yuncong_03032016042451_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0217/MD589_0217_yuncong_01122016185631_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0218/MD589_0218_yuncong_03032016043409_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0219/MD589_0219_yuncong_01122016185526_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0220/MD589_0220_yuncong_03032016043328_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0221/MD589_0221_yuncong_03032016043247_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0222/MD589_0222_yuncong_03032016043348_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0223/MD589_0223_yuncong_01122016183920_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0224/MD589_0224_yuncong_03032016043653_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0225/MD589_0225_yuncong_03032016043846_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0226/MD589_0226_yuncong_03032016043920_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0227/MD589_0227_yuncong_03032016043935_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0228/MD589_0228_yuncong_03032016044027_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0229/MD589_0229_yuncong_01122016183038_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0230/MD589_0230_yuncong_03032016044218_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0231/MD589_0231_yuncong_01122016182831_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0232/MD589_0232_yuncong_03032016044417_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0233/MD589_0233_yuncong_01122016181927_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0234/MD589_0234_yuncong_03032016044807_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0235/MD589_0235_yuncong_01122016181927_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0236/MD589_0236_yuncong_03032016044734_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0237/MD589_0237_yuncong_01122016181927_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0238/MD589_0238_yuncong_03032016044925_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0239/MD589_0239_yuncong_01122016181927_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0240/MD589_0240_yuncong_03032016045335_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0241/MD589_0241_yuncong_01122016181927_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0242/MD589_0242_yuncong_03032016045153_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0243/MD589_0243_yuncong_01122016181927_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0244/MD589_0244_yuncong_03032016045508_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0245/MD589_0245_yuncong_01122016181927_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0246/MD589_0246_yuncong_03032016045831_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0247/MD589_0247_yuncong_03032016045924_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0248/MD589_0248_yuncong_03032016050239_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0249/MD589_0249_yuncong_03032016050248_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0250/MD589_0250_yuncong_03032016050301_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0251/MD589_0251_yuncong_03032016050311_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0252/MD589_0252_yuncong_03032016050219_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0253/MD589_0253_yuncong_01102016185931_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0254/MD589_0254_yuncong_03032016050453_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0255/MD589_0255_yuncong_01112016133211_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0256/MD589_0256_yuncong_03032016050653_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0257/MD589_0257_yuncong_03032016051134_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0258/MD589_0258_yuncong_03032016051122_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0259/MD589_0259_yuncong_03032016051041_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0260/MD589_0260_yuncong_03032016051110_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0261/MD589_0261_yuncong_03032016051102_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0262/MD589_0262_yuncong_03032016051306_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0263/MD589_0263_yuncong_03032016051050_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0264/MD589_0264_yuncong_03032016051526_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0265/MD589_0265_yuncong_03032016051734_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0266/MD589_0266_yuncong_03032016051715_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0267/MD589_0267_yuncong_03032016052545_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0268/MD589_0268_yuncong_03032016052406_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0269/MD589_0269_yuncong_03032016052433_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0270/MD589_0270_yuncong_03032016052446_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0271/MD589_0271_yuncong_03032016052457_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0272/MD589_0272_yuncong_03032016052505_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0273/MD589_0273_yuncong_03032016052531_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0274/MD589_0274_yuncong_03032016052825_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0275/MD589_0275_yuncong_03032016052837_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0276/MD589_0276_yuncong_03032016052918_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0277/MD589_0277_yuncong_03032016052955_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0278/MD589_0278_yuncong_03032016053007_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0279/MD589_0279_yuncong_01102016234850_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0280/MD589_0280_yuncong_03032016025416_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0281/MD589_0281_yuncong_01102016234925_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0282/MD589_0282_yuncong_03032016025511_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0283/MD589_0283_yuncong_01102016234959_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0284/MD589_0284_yuncong_03032016025755_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0285/MD589_0285_yuncong_01112016001309_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0286/MD589_0286_yuncong_03032016025854_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0287/MD589_0287_yuncong_01112016001610_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0288/MD589_0288_yuncong_03032016030038_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0289/MD589_0289_yuncong_01112016001433_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0290/MD589_0290_yuncong_03032016030220_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0291/MD589_0291_yuncong_01112016001412_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0292/MD589_0292_yuncong_03032016030334_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0293/MD589_0293_yuncong_01112016001345_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0294/MD589_0294_yuncong_03032016030811_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0295/MD589_0295_yuncong_03032016030902_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0296/MD589_0296_yuncong_03032016031101_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0297/MD589_0297_yuncong_01112016003050_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0298/MD589_0298_yuncong_03032016031026_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0299/MD589_0299_yuncong_01112016003338_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0300/MD589_0300_yuncong_01112016003813_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0301/MD589_0301_yuncong_03032016031250_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0302/MD589_0302_yuncong_01112016004145_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0303/MD589_0303_yuncong_03032016031714_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0304/MD589_0304_yuncong_01112016004944_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0305/MD589_0305_yuncong_03032016031726_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0306/MD589_0306_yuncong_01112016011521_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0307/MD589_0307_yuncong_03032016031701_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0308/MD589_0308_yuncong_01112016011501_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0309/MD589_0309_yuncong_03032016031844_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0310/MD589_0310_yuncong_01112016012801_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0311/MD589_0311_yuncong_03032016032138_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0312/MD589_0312_yuncong_03032016032125_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0313/MD589_0313_yuncong_03032016032056_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0314/MD589_0314_yuncong_01112016012634_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0315/MD589_0315_yuncong_03032016053304_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0316/MD589_0316_yuncong_01112016012523_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0318/MD589_0318_yuncong_01112016020406_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0320/MD589_0320_yuncong_01112016022046_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0322/MD589_0322_yuncong_01112016022046_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0323/MD589_0323_yuncong_01112016022046_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0325/MD589_0325_yuncong_01112016022046_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0327/MD589_0327_yuncong_01112016022046_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0329/MD589_0329_yuncong_01112016022045_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0331/MD589_0331_yuncong_01112016022045_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0333/MD589_0333_yuncong_01112016014702_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0335/MD589_0335_yuncong_01112016014527_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0337/MD589_0337_yuncong_01112016014320_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0339/MD589_0339_yuncong_01112016014335_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0341/MD589_0341_yuncong_01112016014351_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0343/MD589_0343_yuncong_01112016015053_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0345/MD589_0345_yuncong_01112016015144_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0347/MD589_0347_yuncong_01112016015252_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0349/MD589_0349_yuncong_01112016015417_consolidated.pkl
# /home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD589/0351/MD589_0351_yuncong_01112016015507_consolidated.pkl

# %%
# Correct missing "subtype" field

# %%
from enum import Enum

class PolygonType(Enum):
    CLOSED = 'closed'
    OPEN = 'open'
    TEXTURE = 'textured'
    TEXTURE_WITH_CONTOUR = 'texture with contour'
    DIRECTION = 'directionality'

# %%
autoAnnotations_rootdir = '/oasis/projects/nsf/csd395/yuncong/CSHL_autoAnnotations_snake'

# %%
for sec in range(first_bs_sec, last_bs_sec + 1):
        
    dm.set_slice(sec)
    
    res = dm.load_proposal_review_result(username, 'latest', suffix='consolidated')
    
    if res is None:
        continue
    
    print sec
    usr, ts, _, anns = res
    
    new_anns = []
    
    for ann in anns:
        new_ann = ann.copy()
        new_ann['subtype'] = PolygonType.CLOSED
        new_anns.append(new_ann)
    
    autoAnnotations_dir = autoAnnotations_rootdir + '/' + stack + '/' + '%04d'%sec
    autoAnnotation_filepath = autoAnnotations_dir + '/%(stack)s_%(sec)04d_autoAnnotate_%(timestamp)s_consolidated.pkl' % \
                        {'stack': stack, 'sec': sec, 'timestamp': ts}
    pickle.dump(new_anns, open(autoAnnotation_filepath, 'w'))
# Out:
# username autoAnnotate does not have any annotations for current section 69
# username autoAnnotate does not have any annotations for current section 70
# username autoAnnotate does not have any annotations for current section 71
# username autoAnnotate does not have any annotations for current section 72
# username autoAnnotate does not have any annotations for current section 73
# username autoAnnotate does not have any annotations for current section 74
# username autoAnnotate does not have any annotations for current section 75
# username autoAnnotate does not have any annotations for current section 76
# username autoAnnotate does not have any annotations for current section 77
# username autoAnnotate does not have any annotations for current section 78
# username autoAnnotate does not have any annotations for current section 79
# username autoAnnotate does not have any annotations for current section 80
# username autoAnnotate does not have any annotations for current section 81
# username autoAnnotate does not have any annotations for current section 82
# username autoAnnotate does not have any annotations for current section 83
# username autoAnnotate does not have any annotations for current section 84
# username autoAnnotate does not have any annotations for current section 85
# username autoAnnotate does not have any annotations for current section 86
# username autoAnnotate does not have any annotations for current section 87
# username autoAnnotate does not have any annotations for current section 88
# username autoAnnotate does not have any annotations for current section 89
# username autoAnnotate does not have any annotations for current section 90
# username autoAnnotate does not have any annotations for current section 91
# username autoAnnotate does not have any annotations for current section 92
# username autoAnnotate does not have any annotations for current section 93
# username autoAnnotate does not have any annotations for current section 94
# username autoAnnotate does not have any annotations for current section 95
# username autoAnnotate does not have any annotations for current section 96
# username autoAnnotate does not have any annotations for current section 97
# username autoAnnotate does not have any annotations for current section 98
# username autoAnnotate does not have any annotations for current section 99
# username autoAnnotate does not have any annotations for current section 100
# username autoAnnotate does not have any annotations for current section 101
# username autoAnnotate does not have any annotations for current section 102
# username autoAnnotate does not have any annotations for current section 103
# username autoAnnotate does not have any annotations for current section 104
# username autoAnnotate does not have any annotations for current section 105
# username autoAnnotate does not have any annotations for current section 106
# username autoAnnotate does not have any annotations for current section 107
# username autoAnnotate does not have any annotations for current section 108
# username autoAnnotate does not have any annotations for current section 109
# username autoAnnotate does not have any annotations for current section 110
# username autoAnnotate does not have any annotations for current section 111
# username autoAnnotate does not have any annotations for current section 112
# username autoAnnotate does not have any annotations for current section 113
# username autoAnnotate does not have any annotations for current section 114
# username autoAnnotate does not have any annotations for current section 115
# username autoAnnotate does not have any annotations for current section 116
# username autoAnnotate does not have any annotations for current section 117
# username autoAnnotate does not have any annotations for current section 118
# username autoAnnotate does not have any annotations for current section 119
# username autoAnnotate does not have any annotations for current section 120
# username autoAnnotate does not have any annotations for current section 121
# username autoAnnotate does not have any annotations for current section 122
# username autoAnnotate does not have any annotations for current section 123
# username autoAnnotate does not have any annotations for current section 124
# username autoAnnotate does not have any annotations for current section 125
# username autoAnnotate does not have any annotations for current section 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# username autoAnnotate does not have any annotations for current section 295
# username autoAnnotate does not have any annotations for current section 296
# username autoAnnotate does not have any annotations for current section 297
# username autoAnnotate does not have any annotations for current section 298
# username autoAnnotate does not have any annotations for current section 299
# username autoAnnotate does not have any annotations for current section 300
# username autoAnnotate does not have any annotations for current section 301
# username autoAnnotate does not have any annotations for current section 302
# username autoAnnotate does not have any annotations for current section 303
# username autoAnnotate does not have any annotations for current section 304
# username autoAnnotate does not have any annotations for current section 305
# username autoAnnotate does not have any annotations for current section 306
# username autoAnnotate does not have any annotations for current section 307
# username autoAnnotate does not have any annotations for current section 308
# username autoAnnotate does not have any annotations for current section 309
# username autoAnnotate does not have any annotations for current section 310
# username autoAnnotate does not have any annotations for current section 311
# username autoAnnotate does not have any annotations for current section 312
# username autoAnnotate does not have any annotations for current section 313
# username autoAnnotate does not have any annotations for current section 314
# username autoAnnotate does not have any annotations for current section 315
# username autoAnnotate does not have any annotations for current section 316
# username autoAnnotate does not have any annotations for current section 317
# username autoAnnotate does not have any annotations for current section 318
# username autoAnnotate does not have any annotations for current section 319
# username autoAnnotate does not have any annotations for current section 320
# username autoAnnotate does not have any annotations for current section 321
# username autoAnnotate does not have any annotations for current section 322
# username autoAnnotate does not have any annotations for current section 323
# username autoAnnotate does not have any annotations for current section 324
# username autoAnnotate does not have any annotations for current section 325
# username autoAnnotate does not have any annotations for current section 326
# username autoAnnotate does not have any annotations for current section 327
# username autoAnnotate does not have any annotations for current section 328
# username autoAnnotate does not have any annotations for current section 329
# username autoAnnotate does not have any annotations for current section 330
# username autoAnnotate does not have any annotations for current section 331
# username autoAnnotate does not have any annotations for current section 332
# username autoAnnotate does not have any annotations for current section 333
# username autoAnnotate does not have any annotations for current section 334
# username autoAnnotate does not have any annotations for current section 335
# username autoAnnotate does not have any annotations for current section 336
# username autoAnnotate does not have any annotations for current section 337
# username autoAnnotate does not have any annotations for current section 338
# username autoAnnotate does not have any annotations for current section 339
# username autoAnnotate does not have any annotations for current section 340
# username autoAnnotate does not have any annotations for current section 341
# username autoAnnotate does not have any annotations for current section 342
# username autoAnnotate does not have any annotations for current section 343
# username autoAnnotate does not have any annotations for current section 344
# username autoAnnotate does not have any annotations for current section 345
# username autoAnnotate does not have any annotations for current section 346
# username autoAnnotate does not have any annotations for current section 347
# username autoAnnotate does not have any annotations for current section 348
# username autoAnnotate does not have any annotations for current section 349
# username autoAnnotate does not have any annotations for current section 350

# %%
# Correct for labelPos

# %%
for sec in range(first_bs_sec, last_bs_sec + 1):
        
    dm.set_slice(sec)
    
    res = dm.load_proposal_review_result(username, 'latest', suffix='consolidated')
    
    if res is None:
        continue
    
    print sec
    usr, ts, _, anns = res
    
    new_anns = []
    
    for ann in anns:
        new_ann = ann.copy()
        new_ann['labelPos'] = ann['labelPos'] * 8
        new_anns.append(new_ann)
    
    autoAnnotations_dir = autoAnnotations_rootdir + '/' + stack + '/' + '%04d'%sec
    autoAnnotation_filepath = autoAnnotations_dir + '/%(stack)s_%(sec)04d_autoAnnotate_%(timestamp)s_consolidated.pkl' % \
                        {'stack': stack, 'sec': sec, 'timestamp': ts}
    pickle.dump(new_anns, open(autoAnnotation_filepath, 'w'))
# Out:
# username autoAnnotate does not have any annotations for current section 69
# username autoAnnotate does not have any annotations for current section 70
# username autoAnnotate does not have any annotations for current section 71
# username autoAnnotate does not have any annotations for current section 72
# username autoAnnotate does not have any annotations for current section 73
# username autoAnnotate does not have any annotations for current section 74
# username autoAnnotate does not have any annotations for current section 75
# username autoAnnotate does not have any annotations for current section 76
# username autoAnnotate does not have any annotations for current section 77
# username autoAnnotate does not have any annotations for current section 78
# username autoAnnotate does not have any annotations for current section 79
# username autoAnnotate does not have any annotations for current section 80
# username autoAnnotate does not have any annotations for current section 81
# username autoAnnotate does not have any annotations for current section 82
# username autoAnnotate does not have any annotations for current section 83
# username autoAnnotate does not have any annotations for current section 84
# username autoAnnotate does not have any annotations for current section 85
# username autoAnnotate does not have any annotations for current section 86
# username autoAnnotate does not have any annotations for current section 87
# username autoAnnotate does not have any annotations for current section 88
# username autoAnnotate does not have any annotations for current section 89
# username autoAnnotate does not have any annotations for current section 90
# username autoAnnotate does not have any annotations for current section 91
# username autoAnnotate does not have any annotations for current section 92
# username autoAnnotate does not have any annotations for current section 93
# username autoAnnotate does not have any annotations for current section 94
# username autoAnnotate does not have any annotations for current section 95
# username autoAnnotate does not have any annotations for current section 96
# username autoAnnotate does not have any annotations for current section 97
# username autoAnnotate does not have any annotations for current section 98
# username autoAnnotate does not have any annotations for current section 99
# username autoAnnotate does not have any annotations for current section 100
# username autoAnnotate does not have any annotations for current section 101
# username autoAnnotate does not have any annotations for current section 102
# username autoAnnotate does not have any annotations for current section 103
# username autoAnnotate does not have any annotations for current section 104
# username autoAnnotate does not have any annotations for current section 105
# username autoAnnotate does not have any annotations for current section 106
# username autoAnnotate does not have any annotations for current section 107
# username autoAnnotate does not have any annotations for current section 108
# username autoAnnotate does not have any annotations for current section 109
# username autoAnnotate does not have any annotations for current section 110
# username autoAnnotate does not have any annotations for current section 111
# username autoAnnotate does not have any annotations for current section 112
# username autoAnnotate does not have any annotations for current section 113
# username autoAnnotate does not have any annotations for current section 114
# username autoAnnotate does not have any annotations for current section 115
# username autoAnnotate does not have any annotations for current section 116
# username autoAnnotate does not have any annotations for current section 117
# username autoAnnotate does not have any annotations for current section 118
# username autoAnnotate does not have any annotations for current section 119
# username autoAnnotate does not have any annotations for current section 120
# username autoAnnotate does not have any annotations for current section 121
# username autoAnnotate does not have any annotations for current section 122
# username autoAnnotate does not have any annotations for current section 123
# username autoAnnotate does not have any annotations for current section 124
# username autoAnnotate does not have any annotations for current section 125
# username autoAnnotate does not have any annotations for current section 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# username autoAnnotate does not have any annotations for current section 295
# username autoAnnotate does not have any annotations for current section 296
# username autoAnnotate does not have any annotations for current section 297
# username autoAnnotate does not have any annotations for current section 298
# username autoAnnotate does not have any annotations for current section 299
# username autoAnnotate does not have any annotations for current section 300
# username autoAnnotate does not have any annotations for current section 301
# username autoAnnotate does not have any annotations for current section 302
# username autoAnnotate does not have any annotations for current section 303
# username autoAnnotate does not have any annotations for current section 304
# username autoAnnotate does not have any annotations for current section 305
# username autoAnnotate does not have any annotations for current section 306
# username autoAnnotate does not have any annotations for current section 307
# username autoAnnotate does not have any annotations for current section 308
# username autoAnnotate does not have any annotations for current section 309
# username autoAnnotate does not have any annotations for current section 310
# username autoAnnotate does not have any annotations for current section 311
# username autoAnnotate does not have any annotations for current section 312
# username autoAnnotate does not have any annotations for current section 313
# username autoAnnotate does not have any annotations for current section 314
# username autoAnnotate does not have any annotations for current section 315
# username autoAnnotate does not have any annotations for current section 316
# username autoAnnotate does not have any annotations for current section 317
# username autoAnnotate does not have any annotations for current section 318
# username autoAnnotate does not have any annotations for current section 319
# username autoAnnotate does not have any annotations for current section 320
# username autoAnnotate does not have any annotations for current section 321
# username autoAnnotate does not have any annotations for current section 322
# username autoAnnotate does not have any annotations for current section 323
# username autoAnnotate does not have any annotations for current section 324
# username autoAnnotate does not have any annotations for current section 325
# username autoAnnotate does not have any annotations for current section 326
# username autoAnnotate does not have any annotations for current section 327
# username autoAnnotate does not have any annotations for current section 328
# username autoAnnotate does not have any annotations for current section 329
# username autoAnnotate does not have any annotations for current section 330
# username autoAnnotate does not have any annotations for current section 331
# username autoAnnotate does not have any annotations for current section 332
# username autoAnnotate does not have any annotations for current section 333
# username autoAnnotate does not have any annotations for current section 334
# username autoAnnotate does not have any annotations for current section 335
# username autoAnnotate does not have any annotations for current section 336
# username autoAnnotate does not have any annotations for current section 337
# username autoAnnotate does not have any annotations for current section 338
# username autoAnnotate does not have any annotations for current section 339
# username autoAnnotate does not have any annotations for current section 340
# username autoAnnotate does not have any annotations for current section 341
# username autoAnnotate does not have any annotations for current section 342
# username autoAnnotate does not have any annotations for current section 343
# username autoAnnotate does not have any annotations for current section 344
# username autoAnnotate does not have any annotations for current section 345
# username autoAnnotate does not have any annotations for current section 346
# username autoAnnotate does not have any annotations for current section 347
# username autoAnnotate does not have any annotations for current section 348
# username autoAnnotate does not have any annotations for current section 349
# username autoAnnotate does not have any annotations for current section 350
