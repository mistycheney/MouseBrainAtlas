# %%
# %reload_ext autoreload
# %autoreload 2

import os
import sys
import time
import cv2

sys.path.append(os.path.join(os.environ['REPO_DIR'], 'utilities'))
from utilities2015 import *

from collections import defaultdict

from enum import Enum
    
class PolygonType(Enum):
    CLOSED = 'closed'
    OPEN = 'open'
    TEXTURE = 'textured'
    TEXTURE_WITH_CONTOUR = 'texture with contour'
    DIRECTION = 'directionality'

# %%
# stack = 'MD589'
stack = 'MD594'

first, last = section_range_lookup[stack]

# %%
label_polygons = defaultdict(lambda: {})

for sec in range(first, last+1):
    
    dm = DataManager(stack=stack, section=sec)
    
    res = dm.load_proposal_review_result(None, 'latest', 'consolidated')
    
    if res is None:
        continue

    print sec

    usr, ts, suffix, result = res
    
    for props in result:
        label_polygons[props['label']][sec] = np.array(props['vertices']).astype(np.int)
    
label_polygons.default_factory = None
# Out:
# 96
# 98
# 100
# 102
# 104
# 106
# 108
# 110
# 112
# 114
# 116
# 118
# 120
# 122
# 124
# 126
# 128
# 130
# 132
# 134
# 136
# 138
# 140
# 142
# 144
# 146
# 148
# 150
# 153
# 154
# 158
# 160
# 162
# 164
# 166
# 168
# 170
# 172
# 174
# 176
# 178
# 180
# 182
# 184
# 186
# 188
# 190
# 192
# 194
# 196
# 198
# 200
# 202
# 204
# 206
# 208
# 210
# 212
# 214
# 216
# 218
# 220
# 222
# 224
# 226
# 228
# 230
# 232
# 234
# 236
# 238
# 239
# 240
# 242
# 244
# 246
# 248
# 250
# 252
# 254
# 256
# 258
# 260
# 262
# 264
# 266
# 268
# 270
# 272
# 274
# 276
# 278
# 280
# 282
# 284
# 286
# 288
# 290
# 292
# 294
# 296
# 298
# 300
# 302
# 304
# 306
# 308
# 310
# 312
# 314
# 316
# 318
# 320
# 322
# 324
# 326
# 328
# 330
# 332
# 334
# 336
# 338
# 340
# 342
# 344
# 346
# 348
# 350
# 352
# 354
# 356
# 358
# 360
# 362

# %%
import pandas as pd

label_polygons_df = pd.DataFrame(label_polygons)
label_polygons_df.to_hdf('/home/yuncong/Brain/database/'+stack+'_label_polygons.h5', 'label_polygons')
# Out:
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/pandas/core/generic.py:939: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->['10N', '12N', '3N', '4N', '5N', '6N', '7N', '7n', '8n', 'AP', 'Amb', 'Bo', 'CereNuc', 'Cu', 'DC', 'DCDp', 'DCFu', 'DCMo', 'DR', 'DTg', 'Gr', 'GrC', 'IO', 'LC', 'LDTg', 'LPB', 'LRt', 'LSO', 'LVe', 'MVeMC', 'Pn', 'Pr5', 'Pr5DM', 'Pr5VL', 'PrVd', 'PrVv', 'R', 'RtTg', 'Sol', 'Sp5C', 'Sp5I', 'Sp5O', 'SpVe', 'SuVe', 'Tz', 'UDF', 'VCA', 'VCAGr', 'VCP', 'VCPO', 'VLL', 'VTg', 'asc7', 'dtgx', 'icp', 'mcp', 'mlf', 'pyx', 'scp', 'sp5', 'vtgx']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
