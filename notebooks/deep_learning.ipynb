# %%
import sys
sys.path.append('/home/yuncong/project/caffe/python')

# %%
import caffe

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
caffe_root = '/home/yuncong/project/caffe/'

# %%
MODEL_FILE = caffe_root + 'models/bvlc_reference_caffenet/deploy.prototxt'
PRETRAINED = caffe_root + 'models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel'
IMAGE_FILE = caffe_root + 'examples/images/cat.jpg'

# %%
import os
if not os.path.isfile(PRETRAINED):
    print("Downloading pre-trained CaffeNet model...")
    # !/home/yuncong/project/caffe/scripts/download_model_binary.py /home/yuncong/project/caffe/models/bvlc_reference_caffenet
# Out:
# Downloading pre-trained CaffeNet model...
# ...0%, 0 MB, 2256 KB/s, 0 seconds passed
# ...0%, 0 MB, 3569 KB/s, 0 seconds passed
# ...0%, 0 MB, 6638 KB/s, 0 seconds passed
# ...0%, 2 MB, 13804 KB/s, 0 seconds passed
# ...2%, 5 MB, 24461 KB/s, 0 seconds passed
# ...3%, 9 MB, 33768 KB/s, 0 seconds passed
# ...5%, 13 MB, 42058 KB/s, 0 seconds passed
# ...7%, 18 MB, 50278 KB/s, 0 seconds passed
# ...10%, 24 MB, 57682 KB/s, 0 seconds passed
# ...12%, 29 MB, 63678 KB/s, 0 seconds passed
# ...15%, 35 MB, 68482 KB/s, 0 seconds passed
# ...17%, 40 MB, 71542 KB/s, 0 seconds passed
# ...19%, 44 MB, 73160 KB/s, 0 seconds passed
# ...21%, 49 MB, 74694 KB/s, 0 seconds passed
# ...23%, 54 MB, 76024 KB/s, 0 seconds passed
# ...25%, 59 MB, 77286 KB/s, 0 seconds passed
# ...27%, 63 MB, 78509 KB/s, 0 seconds passed
# ...29%, 68 MB, 79216 KB/s, 0 seconds passed
# ...31%, 73 MB, 80247 KB/s, 0 seconds passed
# ...33%, 78 MB, 81196 KB/s, 0 seconds passed
# ...35%, 83 MB, 82091 KB/s, 1 seconds passed
# ...37%, 88 MB, 82949 KB/s, 1 seconds passed
# ...40%, 93 MB, 83782 KB/s, 1 seconds passed
# ...42%, 98 MB, 84418 KB/s, 1 seconds passed
# ...44%, 102 MB, 85055 KB/s, 1 seconds passed
# ...46%, 107 MB, 85520 KB/s, 1 seconds passed
# ...48%, 112 MB, 85867 KB/s, 1 seconds passed
# ...50%, 117 MB, 86574 KB/s, 1 seconds passed
# ...52%, 122 MB, 87114 KB/s, 1 seconds passed
# ...55%, 128 MB, 87732 KB/s, 1 seconds passed
# ...57%, 133 MB, 88314 KB/s, 1 seconds passed
# ...59%, 138 MB, 88865 KB/s, 1 seconds passed
# ...61%, 143 MB, 89348 KB/s, 1 seconds passed
# ...64%, 148 MB, 89814 KB/s, 1 seconds passed
# ...66%, 154 MB, 90363 KB/s, 1 seconds passed
# ...68%, 159 MB, 90865 KB/s, 1 seconds passed
# ...70%, 164 MB, 90888 KB/s, 1 seconds passed
# ...72%, 169 MB, 91480 KB/s, 1 seconds passed
# ...75%, 174 MB, 91709 KB/s, 1 seconds passed
# ...77%, 180 MB, 92133 KB/s, 2 seconds passed
# ...79%, 185 MB, 92601 KB/s, 2 seconds passed
# ...82%, 191 MB, 92959 KB/s, 2 seconds passed
# ...84%, 196 MB, 93284 KB/s, 2 seconds passed
# ...86%, 201 MB, 93552 KB/s, 2 seconds passed
# ...89%, 207 MB, 93952 KB/s, 2 seconds passed
# ...91%, 212 MB, 94015 KB/s, 2 seconds passed
# ...93%, 217 MB, 94489 KB/s, 2 seconds passed
# ...96%, 223 MB, 94878 KB/s, 2 seconds passed
# ...98%, 229 MB, 95226 KB/s, 2 seconds passed
# ...100%, 232 MB, 95351 KB/s, 2 seconds passed

# %%
caffe.set_mode_cpu()
net = caffe.Classifier(MODEL_FILE, PRETRAINED,
                       mean=np.load(caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy').mean(1).mean(1),
                       channel_swap=(2,1,0),
                       raw_scale=255,
                       image_dims=(256, 256))

# %%
input_image = caffe.io.load_image(IMAGE_FILE)
plt.imshow(input_image)

# %%
prediction = net.predict([input_image])  # predict takes any number of images, and formats them for the Caffe net automatically
print 'prediction shape:', prediction[0].shape
plt.plot(prediction[0])
print 'predicted class:', prediction[0].argmax()
# Out:
# prediction shape: (1000,)
# predicted class: 281

# %%
prediction = net.predict([input_image], oversample=False)
print 'prediction shape:', prediction[0].shape
plt.plot(prediction[0])
print 'predicted class:', prediction[0].argmax()
# Out:
# prediction shape: (1000,)
# predicted class:
#  281
