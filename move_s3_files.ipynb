# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys
import time

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

sys.path.append(os.path.join(os.environ['REPO_DIR'], 'utilities'))
from utilities2015 import *
from metadata import *
from data_manager import *
from learning_utilities import *
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# Setting environment for AWS compute node
# No vtk
# Cannot import mxnet.

# %%
for stack in all_stacks:
    for fn in metadata_cache['valid_filenames'][stack]:
        dirname = 'CSHL_patch_scores/%(stack)s/%(fn)s_lossless_alignedTo_%(anchor_fn)s_cropped' % {'fn':fn, 'anchor_fn': metadata_cache['anchor_fn'][stack], 'stack':stack}
        execute_command("aws s3 rm --recursive \"s3://mousebrainatlas-data/%s\" " % dirname)
# Out:
# aws s3 rm --recursive "s3://mousebrainatlas-data/CSHL_patch_scores/MD585/MD585-N16-2015.07.16-20.32.33_MD585_2_0047_lossless_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropped"
# aws s3 rm --recursive "s3://mousebrainatlas-data/CSHL_patch_scores/MD585/MD585-IHC16-2015.08.19-13.14.51_MD585_3_0048_lossless_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropped"
# aws s3 rm --recursive "s3://mousebrainatlas-data/CSHL_patch_scores/MD585/MD585-N17-2015.07.16-20.35.23_MD585_1_0049_lossless_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropped"
# aws s3 rm --recursive "s3://mousebrainatlas-data/CSHL_patch_scores/MD585/MD585-IHC17-2015.07.16-15.32.03_MD585_1_0049_lossless_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropped"
# aws s3 rm --recursive "s3://mousebrainatlas-data/CSHL_patch_scores/MD585/MD585-N17-2015.07.16-20.35.23_MD585_2_0050_lossless_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropped"
# ...

# %%
for stack in ['MD662']:
    for fn in metadata_cache['valid_filenames'][stack]:
        from_fp = 'CSHL_patch_features/inception-bn-blue/MD662/MD662_prep2_gray_win1/%(fn)s_prep2_gray_win1_inception-bn-blue_patch_locations.txt' % {'fn':fn}
        to_fp = 'CSHL_patch_locations/MD662/MD662_prep2_gray_win1/%(fn)s_prep2_gray_win1_patchLocations.txt' % {'fn':fn}
        execute_command("aws s3 cp \"s3://mousebrainatlas-data/%s\" \"s3://mousebrainatlas-data/%s\"" % (relative_to_local(from_fp), relative_to_local(to_fp)))
# Out:
# aws s3 cp "s3://mousebrainatlas-data/CSHL_patch_features/inception-bn-blue/MD662/MD662_prep2_gray_win1/MD662&661-F35-2017.06.05-17.08.18_MD662_1_0103_prep2_gray_win1_inception-bn-blue_patch_locations.txt" "s3://mousebrainatlas-data/CSHL_patch_locations/MD662/MD662_prep2_gray_win1/MD662&661-F35-2017.06.05-17.08.18_MD662_1_0103_prep2_gray_win1_patchLocations.txt"
# aws s3 cp "s3://mousebrainatlas-data/CSHL_patch_features/inception-bn-blue/MD662/MD662_prep2_gray_win1/MD662&661-F35-2017.06.05-17.08.18_MD662_2_0104_prep2_gray_win1_inception-bn-blue_patch_locations.txt" "s3://mousebrainatlas-data/CSHL_patch_locations/MD662/MD662_prep2_gray_win1/MD662&661-F35-2017.06.05-17.08.18_MD662_2_0104_prep2_gray_win1_patchLocations.txt"
# ...

# %%
all_stacks
# Out:
# ['MD585',
#  'MD589',
#  'MD590',
#  'MD591',
#  'MD592',
#  'MD593',
#  'MD594',
#  'MD595',
#  'MD598',
#  'MD599',
#  'MD602',
#  'MD603',
#  'MD635',
#  'MD653',
#  'MD652',
#  'MD642',
#  'MD657',
#  'MD658',
#  'MD661',
#  'MD662']

# %%
for stack in [
'MD585',
 'MD589',
 'MD590',
 'MD591',
 'MD592',
 'MD593',
 'MD594',
 'MD595',
 'MD598',
 'MD599',
 'MD602',
 'MD603']:
    
    for fn in metadata_cache['valid_filenames'][stack]:
        from_fp = '/shared/CSHL_data_processed/%(stack)s/%(stack)s_lossless_alignedTo_%(anchor)s_cropped_compressed/%(fn)s_lossless_alignedTo_%(anchor)s_cropped_compressed.jpg' % {'fn':fn, 'stack':stack, 'anchor':metadata_cache['anchor_fn'][stack]}
        to_fp = DataManager.get_image_filepath_v2(stack=stack, prep_id=2, fn=fn, version='jpeg', ext='jpg')
        execute_command("aws s3 cp \"s3://mousebrainatlas-data/%s\" \"s3://mousebrainatlas-data/%s\"" % (relative_to_local(from_fp), relative_to_local(to_fp)))
# Out:
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD585/MD585_lossless_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropped_compressed/MD585-N16-2015.07.16-20.32.33_MD585_2_0047_lossless_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropped_compressed.jpg" "s3://mousebrainatlas-data/CSHL_data_processed/MD585/MD585_prep2_lossless_jpeg/MD585-N16-2015.07.16-20.32.33_MD585_2_0047_prep2_lossless_jpeg.jpg"
# aws s3 cp "s3://mousebrainatlas-data/CSHL_data_processed/MD585/MD585_lossless_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropped_compressed/MD585-IHC16-2015.08.19-13.14.51_MD585_3_0048_lossless_alignedTo_MD585-N47-2015.07.16-22.50.52_MD585_3_0141_cropped_compressed.jpg" "s3://mousebrainatlas-data/CSHL_data_processed/MD585/MD585_prep2_lossless_jpeg/MD585-IHC16-2015.08.19-13.14.51_MD585_3_0048_prep2_lossless_jpeg.jpg"
# ...
