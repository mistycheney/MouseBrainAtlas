# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

import sys
import os

sys.path.append(os.environ['REPO_DIR'] + '/utilities')
from utilities2015 import *
from metadata import *
from data_manager import *

from annotation_utilities import *

import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.path import Path

import time
# Out:
# Setting environment for Gordon

# %%
username = 'yuncong'
stack = 'MD594'

# %%
label_polygons = load_label_polygons_if_exists(stack, username, force=True, annotation_rootdir=annotation_midbrainIncluded_rootdir)
# Out:
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0093/ does not exist.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0094/ does not exist.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0095/ does not exist.
# Label GrC on Section 96 is not recognized.
# Label VCA on Section 96 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0097/ does not exist.
# Label GrC on Section 98 is not recognized.
# Label VCA on Section 98 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0099/ does not exist.
# Label VCA on Section 100 is not recognized.
# Label GrC on Section 100 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0101/ does not exist.
# Label VCA on Section 102 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0103/ does not exist.
# Label VCA on Section 104 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0105/ does not exist.
# Label VCA on Section 106 is not recognized.
# Label VCP on Section 106 is not recognized.
# Label DC on Section 106 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0107/ does not exist.
# Label DC on Section 108 is not recognized.
# Label VCA on Section 108 is not recognized.
# Label VCP on Section 108 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0109/ does not exist.
# Label VCP on Section 110 is not recognized.
# Label VCA on Section 110 is not recognized.
# Label VCAGr on Section 110 is not recognized.
# Label DC on Section 110 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0111/ does not exist.
# Label VCAGr on Section 112 is not recognized.
# Label VCP on Section 112 is not recognized.
# Label DC on Section 112 is not recognized.
# Label VCA on Section 112 is not recognized.
# Label VCPO on Section 112 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0113/ does not exist.
# Label VCP on Section 114 is not recognized.
# Label DC on Section 114 is not recognized.
# Label VCA on Section 114 is not recognized.
# Label VCPO on Section 114 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0115/ does not exist.
# Label VCPO on Section 116 is not recognized.
# Label VCP on Section 116 is not recognized.
# Label VCA on Section 116 is not recognized.
# Label DC on Section 116 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0117/ does not exist.
# Label VCA on Section 118 is not recognized.
# Label VCP on Section 118 is not recognized.
# Label mcp on Section 118 is not recognized.
# Label DCMo on Section 118 is not recognized.
# Label DCFu on Section 118 is not recognized.
# Label VCPO on Section 118 is not recognized.
# Label DCDp on Section 118 is not recognized.
# Label DC on Section 118 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0119/ does not exist.
# Label VCPO on Section 120 is not recognized.
# Label DCMo on Section 120 is not recognized.
# Label DCFu on Section 120 is not recognized.
# Label 8n on Section 120 is not recognized.
# Label mcp on Section 120 is not recognized.
# Label DCDp on Section 120 is not recognized.
# Label VCP on Section 120 is not recognized.
# Label DC on Section 120 is not recognized.
# Label VCA on Section 120 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0121/ does not exist.
# Label VCP on Section 122 is not recognized.
# Label 8n on Section 122 is not recognized.
# Label VCA on Section 122 is not recognized.
# Label DC on Section 122 is not recognized.
# Label mcp on Section 122 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0123/ does not exist.
# Label DC on Section 124 is not recognized.
# Label Pr5 on Section 124 is not recognized.
# Label VCP on Section 124 is not recognized.
# Label VCA on Section 124 is not recognized.
# Label 8n on Section 124 is not recognized.
# Label icp on Section 124 is not recognized.
# Label mcp on Section 124 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0125/ does not exist.
# Label Sp5I on Section 126 is not recognized.
# Label 8n on Section 126 is not recognized.
# Label DC on Section 126 is not recognized.
# Label mcp on Section 126 is not recognized.
# Label DCFu on Section 126 is not recognized.
# Label Sp5C on Section 126 is not recognized.
# Label DCMo on Section 126 is not recognized.
# Label icp on Section 126 is not recognized.
# Label Pr5 on Section 126 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0127/ does not exist.
# Label mcp on Section 128 is not recognized.
# Label Pr5 on Section 128 is not recognized.
# Label icp on Section 128 is not recognized.
# Label 8n on Section 128 is not recognized.
# Label DC on Section 128 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0129/ does not exist.
# Label 8n on Section 130 is not recognized.
# Label icp on Section 130 is not recognized.
# Label Sp5O on Section 130 is not recognized.
# Label PrVv on Section 130 is not recognized.
# Label DC on Section 130 is not recognized.
# Label PrVd on Section 130 is not recognized.
# Label Sp5I on Section 130 is not recognized.
# Label CereNuc on Section 130 is not recognized.
# Label Sp5O on Section 130 is not recognized.
# Label Sp5C on Section 130 is not recognized.
# Label mcp on Section 130 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0131/ does not exist.
# Label Sp5O on Section 132 is not recognized.
# Label DC on Section 132 is not recognized.
# Label Sp5I on Section 132 is not recognized.
# Label Sp5C on Section 132 is not recognized.
# Label icp on Section 132 is not recognized.
# Label Pr5 on Section 132 is not recognized.
# Label 8n on Section 132 is not recognized.
# Label Sp5O on Section 132 is not recognized.
# Label mcp on Section 132 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0133/ does not exist.
# Label icp on Section 134 is not recognized.
# Label CereNuc on Section 134 is not recognized.
# Label 8n on Section 134 is not recognized.
# Label DC on Section 134 is not recognized.
# Label Sp5O on Section 134 is not recognized.
# Label PrVd on Section 134 is not recognized.
# Label Sp5I on Section 134 is not recognized.
# Label PrVv on Section 134 is not recognized.
# Label Sp5O on Section 134 is not recognized.
# Label Sp5C on Section 134 is not recognized.
# Label Sp5O on Section 134 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0135/ does not exist.
# Label 8n on Section 136 is not recognized.
# Label DC on Section 136 is not recognized.
# Label icp on Section 136 is not recognized.
# Label Pr5DM on Section 136 is not recognized.
# Label Sp5O on Section 136 is not recognized.
# Label Sp5I on Section 136 is not recognized.
# Label Pr5VL on Section 136 is not recognized.
# Label Sp5C on Section 136 is not recognized.
# Label icp on Section 138 is not recognized.
# Label 8n on Section 138 is not recognized.
# Label Sp5I on Section 138 is not recognized.
# Label DC on Section 138 is not recognized.
# Label Sp5O on Section 138 is not recognized.
# Label Sp5C on Section 138 is not recognized.
# Label Pr5 on Section 138 is not recognized.
# Label DC on Section 140 is not recognized.
# Label icp on Section 140 is not recognized.
# Label 8n on Section 140 is not recognized.
# Label DC on Section 142 is not recognized.
# Label icp on Section 142 is not recognized.
# Label 8n on Section 142 is not recognized.
# Label UDF on Section 143 is not recognized.
# Label UDFtr on Section 143 is not recognized.
# Label UDFtr on Section 143 is not recognized.
# Label UDFtr on Section 143 is not recognized.
# Label UDFtr on Section 143 is not recognized.
# Label UDFtr on Section 143 is not recognized.
# Label UDF on Section 144 is not recognized.
# Label UDFtr on Section 144 is not recognized.
# Label LPB on Section 144 is not recognized.
# Label 8n on Section 144 is not recognized.
# Label UDFtr on Section 144 is not recognized.
# Label icp on Section 144 is not recognized.
# Label DC on Section 144 is not recognized.
# Label UDFtr on Section 144 is not recognized.
# Label UDFtr on Section 144 is not recognized.
# Label UDFtr on Section 144 is not recognized.
# Label UDFtr on Section 144 is not recognized.
# Label DC on Section 145 is not recognized.
# Label LPB on Section 145 is not recognized.
# Label 8n on Section 146 is not recognized.
# Label UDFtr on Section 146 is not recognized.
# Label UDFtr on Section 146 is not recognized.
# Label LPB on Section 146 is not recognized.
# Label UDFtr on Section 146 is not recognized.
# Label UDFtr on Section 146 is not recognized.
# Label DC on Section 146 is not recognized.
# Label UDFtr on Section 146 is not recognized.
# Label icp on Section 146 is not recognized.
# Label UDFtr on Section 146 is not recognized.
# Label UDFtr on Section 147 is not recognized.
# Label UDFtr on Section 147 is not recognized.
# Label UDFtr on Section 147 is not recognized.
# Label UDFtr on Section 147 is not recognized.
# Label UDFtr on Section 147 is not recognized.
# Label LPB on Section 147 is not recognized.
# Label UDFtr on Section 147 is not recognized.
# Label UDFtr on Section 147 is not recognized.
# Label UDFtr on Section 148 is not recognized.
# Label 8n on Section 148 is not recognized.
# Label UDF on Section 148 is not recognized.
# Label UDFtr on Section 148 is not recognized.
# Label DC on Section 148 is not recognized.
# Label LPB on Section 148 is not recognized.
# Label UDFtr on Section 148 is not recognized.
# Label icp on Section 148 is not recognized.
# Label UDFtr on Section 148 is not recognized.
# Label UDF on Section 149 is not recognized.
# Label UDFtr on Section 149 is not recognized.
# Label UDFtr on Section 149 is not recognized.
# Label UDFtr on Section 149 is not recognized.
# Label DC on Section 149 is not recognized.
# Label UDFtr on Section 150 is not recognized.
# Label UDFtr on Section 150 is not recognized.
# Label icp on Section 150 is not recognized.
# Label 8n on Section 150 is not recognized.
# Label UDFtr on Section 150 is not recognized.
# Label DC on Section 150 is not recognized.
# Label LPB on Section 150 is not recognized.
# Label UDF on Section 150 is not recognized.
# Label DC on Section 151 is not recognized.
# Label UDFtr on Section 151 is not recognized.
# Label UDFtr on Section 151 is not recognized.
# Label UDF on Section 151 is not recognized.
# Label DC on Section 152 is not recognized.
# Label UDFtr on Section 152 is not recognized.
# Label UDFtr on Section 152 is not recognized.
# Label UDFtr on Section 152 is not recognized.
# Label scp on Section 153 is not recognized.
# Label UDFtr on Section 153 is not recognized.
# Label UDFtr on Section 153 is not recognized.
# Label DC on Section 153 is not recognized.
# Label UDFtr on Section 153 is not recognized.
# Label scp on Section 154 is not recognized.
# Label scp on Section 158 is not recognized.
# Label LSO on Section 160 is not recognized.
# Label scp on Section 162 is not recognized.
# Label scp on Section 164 is not recognized.
# Label LVe on Section 164 is not recognized.
# Label SuVe on Section 164 is not recognized.
# Label SuVe on Section 166 is not recognized.
# Label scp on Section 166 is not recognized.
# Label LVe on Section 166 is not recognized.
# Label LVe on Section 168 is not recognized.
# Label scp on Section 168 is not recognized.
# Label SuVe on Section 168 is not recognized.
# Label scp on Section 170 is not recognized.
# Label SuVe on Section 170 is not recognized.
# Label LVe on Section 170 is not recognized.
# Label SuVe on Section 172 is not recognized.
# Label scp on Section 172 is not recognized.
# Label scp on Section 174 is not recognized.
# Label scp on Section 176 is not recognized.
# Label scp on Section 178 is not recognized.
# Label scp on Section 180 is not recognized.
# Label scp on Section 182 is not recognized.
# Label Gr on Section 184 is not recognized.
# Label Gr on Section 186 is not recognized.
# Label Gr on Section 188 is not recognized.
# Label Gr on Section 190 is not recognized.
# Label Gr on Section 192 is not recognized.
# Label Gr on Section 194 is not recognized.
# Label Gr on Section 196 is not recognized.
# Label Gr on Section 198 is not recognized.
# Label Gr on Section 200 is not recognized.
# Label Gr on Section 202 is not recognized.
# Label Gr on Section 204 is not recognized.
# Label scp on Section 204 is not recognized.
# Label 10N on Section 206 is not recognized.
# Label scp on Section 206 is not recognized.
# Label IO on Section 206 is not recognized.
# Label 10N on Section 207 is not recognized.
# Label IO on Section 208 is not recognized.
# Label mlf on Section 208 is not recognized.
# Label 10N on Section 208 is not recognized.
# Label scp on Section 208 is not recognized.
# Label 10N on Section 209 is not recognized.
# Label Gr on Section 210 is not recognized.
# Label mlf on Section 210 is not recognized.
# Label scp on Section 210 is not recognized.
# Label IO on Section 210 is not recognized.
# Label 4N on Section 210 is not recognized.
# Label 10N on Section 210 is not recognized.
# Label 10N on Section 211 is not recognized.
# Label mlf on Section 212 is not recognized.
# Label Gr on Section 212 is not recognized.
# Label IO on Section 212 is not recognized.
# Label scp on Section 212 is not recognized.
# Label Sol on Section 212 is not recognized.
# Label 3N on Section 212 is not recognized.
# Label 10N on Section 212 is not recognized.
# Label VTg on Section 212 is not recognized.
# Label 4N on Section 212 is not recognized.
# Label 10N on Section 213 is not recognized.
# Label Gr on Section 214 is not recognized.
# Label mlf on Section 214 is not recognized.
# Label 10N on Section 214 is not recognized.
# Label scp on Section 214 is not recognized.
# Label IO on Section 214 is not recognized.
# Label 3N on Section 214 is not recognized.
# Label VTg on Section 214 is not recognized.
# Label Sol on Section 214 is not recognized.
# Label 4N on Section 214 is not recognized.
# Label 10N on Section 215 is not recognized.
# Label 3N on Section 216 is not recognized.
# Label IO on Section 216 is not recognized.
# Label 10N on Section 216 is not recognized.
# Label mlf on Section 216 is not recognized.
# Label VTg on Section 216 is not recognized.
# Label 4N on Section 216 is not recognized.
# Label scp on Section 216 is not recognized.
# Label Gr on Section 216 is not recognized.
# Label DTg on Section 216 is not recognized.
# Label Sol on Section 216 is not recognized.
# Label 10N on Section 217 is not recognized.
# Label DTg on Section 218 is not recognized.
# Label Gr on Section 218 is not recognized.
# Label IO on Section 218 is not recognized.
# Label scp on Section 218 is not recognized.
# Label mlf on Section 218 is not recognized.
# Label 10N on Section 218 is not recognized.
# Label Sol on Section 218 is not recognized.
# Label 3N on Section 218 is not recognized.
# Label 10N on Section 219 is not recognized.
# Label vtgx on Section 220 is not recognized.
# Label IO on Section 220 is not recognized.
# Label Gr on Section 220 is not recognized.
# Label mlf on Section 220 is not recognized.
# Label 4N on Section 220 is not recognized.
# Label DTg on Section 220 is not recognized.
# Label 3N on Section 220 is not recognized.
# Label scp on Section 220 is not recognized.
# Label Sol on Section 220 is not recognized.
# Label 10N on Section 220 is not recognized.
# Label 10N on Section 221 is not recognized.
# Label 10N on Section 222 is not recognized.
# Label scp on Section 222 is not recognized.
# Label vtgx on Section 222 is not recognized.
# Label Gr on Section 222 is not recognized.
# Label DR on Section 222 is not recognized.
# Label mlf on Section 222 is not recognized.
# Label dtgx on Section 222 is not recognized.
# Label DTg on Section 222 is not recognized.
# Label Sol on Section 222 is not recognized.
# Label IO on Section 222 is not recognized.
# Label 10N on Section 223 is not recognized.
# Label 10N on Section 224 is not recognized.
# Label dtgx on Section 224 is not recognized.
# Label scp on Section 224 is not recognized.
# Label LDTg on Section 224 is not recognized.
# Label DR on Section 224 is not recognized.
# Label vtgx on Section 224 is not recognized.
# Label Gr on Section 224 is not recognized.
# Label Sol on Section 224 is not recognized.
# Label DTg on Section 224 is not recognized.
# Label IO on Section 224 is not recognized.
# Label 3N on Section 224 is not recognized.
# Label 10N on Section 225 is not recognized.
# Label LDTg on Section 226 is not recognized.
# Label UDF on Section 226 is not recognized.
# Label IO on Section 226 is not recognized.
# Label Sol on Section 226 is not recognized.
# Label mlf on Section 226 is not recognized.
# Label scp on Section 226 is not recognized.
# Label DR on Section 226 is not recognized.
# Label Gr on Section 226 is not recognized.
# Label 10N on Section 226 is not recognized.
# Label 10N on Section 227 is not recognized.
# Label UDF on Section 228 is not recognized.
# Label 10N on Section 228 is not recognized.
# Label LDTg on Section 228 is not recognized.
# Label Sol on Section 228 is not recognized.
# Label Gr on Section 228 is not recognized.
# Label mlf on Section 228 is not recognized.
# Label pyx on Section 228 is not recognized.
# Label vtgx on Section 228 is not recognized.
# Label dtgx on Section 228 is not recognized.
# Label UDF on Section 228 is not recognized.
# Label scp on Section 228 is not recognized.
# Label IO on Section 228 is not recognized.
# Label UDF on Section 228 is not recognized.
# Label IO on Section 230 is not recognized.
# Label mlf on Section 230 is not recognized.
# Label Gr on Section 230 is not recognized.
# Label Sol on Section 230 is not recognized.
# Label UDF on Section 230 is not recognized.
# Label scp on Section 230 is not recognized.
# Label DTg on Section 230 is not recognized.
# Label pyx on Section 230 is not recognized.
# Label DTg on Section 232 is not recognized.
# Label pyx on Section 232 is not recognized.
# Label UDF on Section 232 is not recognized.
# Label scp on Section 232 is not recognized.
# Label mlf on Section 232 is not recognized.
# Label scp on Section 234 is not recognized.
# Label DTg on Section 234 is not recognized.
# Label 4N on Section 234 is not recognized.
# Label VTg on Section 234 is not recognized.
# Label 3N on Section 234 is not recognized.
# Label mlf on Section 234 is not recognized.
# Label pyx on Section 234 is not recognized.
# Label DTg on Section 236 is not recognized.
# Label 4N on Section 236 is not recognized.
# Label pyx on Section 236 is not recognized.
# Label VTg on Section 236 is not recognized.
# Label mlf on Section 236 is not recognized.
# Label scp on Section 236 is not recognized.
# Label Sol on Section 236 is not recognized.
# Label Gr on Section 236 is not recognized.
# Label 10N on Section 237 is not recognized.
# Label IO on Section 238 is not recognized.
# Label scp on Section 238 is not recognized.
# Label VTg on Section 238 is not recognized.
# Label UDF on Section 238 is not recognized.
# Label UDF on Section 238 is not recognized.
# Label Gr on Section 238 is not recognized.
# Label 10N on Section 238 is not recognized.
# Label pyx on Section 238 is not recognized.
# Label IO on Section 239 is not recognized.
# Label Sol on Section 239 is not recognized.
# Label VTg on Section 239 is not recognized.
# Label scp on Section 239 is not recognized.
# Label mlf on Section 239 is not recognized.
# Label 10N on Section 239 is not recognized.
# Label Gr on Section 239 is not recognized.
# Label DTg on Section 239 is not recognized.
# Label Gr on Section 240 is not recognized.
# Label VTg on Section 240 is not recognized.
# Label Sol on Section 240 is not recognized.
# Label IO on Section 240 is not recognized.
# Label 10N on Section 240 is not recognized.
# Label scp on Section 240 is not recognized.
# Label 10N on Section 241 is not recognized.
# Label 10N on Section 242 is not recognized.
# Label scp on Section 242 is not recognized.
# Label 10N on Section 243 is not recognized.
# Label 10N on Section 244 is not recognized.
# Label scp on Section 244 is not recognized.
# Label Gr on Section 245 is not recognized.
# Label 10N on Section 245 is not recognized.
# Label 10N on Section 246 is not recognized.
# Label scp on Section 246 is not recognized.
# Label 10N on Section 247 is not recognized.
# Label scp on Section 248 is not recognized.
# Label 10N on Section 248 is not recognized.
# Label 10N on Section 249 is not recognized.
# Label scp on Section 250 is not recognized.
# Label 10N on Section 250 is not recognized.
# Label 10N on Section 250 is not recognized.
# Label 10N on Section 251 is not recognized.
# Label scp on Section 252 is not recognized.
# Label 10N on Section 252 is not recognized.
# Label 10N on Section 254 is not recognized.
# Label scp on Section 254 is not recognized.
# Label 10N on Section 256 is not recognized.
# Label scp on Section 256 is not recognized.
# Label scp on Section 258 is not recognized.
# Label scp on Section 260 is not recognized.
# Label scp on Section 262 is not recognized.
# Label scp on Section 270 is not recognized.
# Label scp on Section 272 is not recognized.
# Label scp on Section 274 is not recognized.
# Label scp on Section 276 is not recognized.
# Label scp on Section 278 is not recognized.
# Label scp on Section 280 is not recognized.
# Label Cu on Section 282 is not recognized.
# Label scp on Section 282 is not recognized.
# Label MVeMC on Section 282 is not recognized.
# Label SpVe on Section 282 is not recognized.
# Label MVeMC on Section 284 is not recognized.
# Label scp on Section 284 is not recognized.
# Label MVeMC on Section 286 is not recognized.
# Label scp on Section 286 is not recognized.
# Label scp on Section 288 is not recognized.
# Label SpVe on Section 288 is not recognized.
# Label Cu on Section 290 is not recognized.
# Label scp on Section 290 is not recognized.
# Label scp on Section 292 is not recognized.
# Label scp on Section 294 is not recognized.
# Label 7N2 on Section 295 is not recognized.
# Label UDFtr on Section 296 is not recognized.
# Label scp on Section 296 is not recognized.
# Label UDFtr on Section 297 is not recognized.
# Label UDFtr on Section 297 is not recognized.
# Label UDFtr on Section 298 is not recognized.
# Label UDFtr on Section 298 is not recognized.
# Label UDFtr on Section 298 is not recognized.
# Label UDFtr on Section 298 is not recognized.
# Label UDFtr on Section 298 is not recognized.
# Label UDFtr on Section 298 is not recognized.
# Label UDFtr on Section 299 is not recognized.
# Label UDFtr on Section 299 is not recognized.
# Label UDFtr on Section 299 is not recognized.
# Label UDFtr on Section 299 is not recognized.
# Label UDFtr on Section 299 is not recognized.
# Label UDFtr on Section 299 is not recognized.
# Label UDFtr on Section 299 is not recognized.
# Label UDFtr on Section 300 is not recognized.
# Label UDFtr on Section 300 is not recognized.
# Label UDFtr on Section 300 is not recognized.
# Label UDFtr on Section 300 is not recognized.
# Label UDFtr on Section 300 is not recognized.
# Label UDFtr on Section 300 is not recognized.
# Label UDFtr on Section 300 is not recognized.
# Label UDFtr on Section 301 is not recognized.
# Label UDFtr on Section 301 is not recognized.
# Label UDFtr on Section 301 is not recognized.
# Label UDFtr on Section 301 is not recognized.
# Label UDFtr on Section 301 is not recognized.
# Label UDF on Section 301 is not recognized.
# Label UDFtr on Section 301 is not recognized.
# Label icp on Section 302 is not recognized.
# Label UDFtr on Section 302 is not recognized.
# Label SuVe on Section 302 is not recognized.
# Label LVe on Section 302 is not recognized.
# Label UDFtr on Section 302 is not recognized.
# Label UDFtr on Section 302 is not recognized.
# Label UDFtr on Section 302 is not recognized.
# Label 8n on Section 302 is not recognized.
# Label UDFtr on Section 302 is not recognized.
# Label UDFtr on Section 302 is not recognized.
# Label UDFtr on Section 302 is not recognized.
# Label UDFtr on Section 302 is not recognized.
# Label UDFtr on Section 303 is not recognized.
# Label UDFtr on Section 303 is not recognized.
# Label UDFtr on Section 303 is not recognized.
# Label UDFtr on Section 303 is not recognized.
# Label UDFtr on Section 303 is not recognized.
# Label UDFtr on Section 304 is not recognized.
# Label UDFtr on Section 304 is not recognized.
# Label UDFtr on Section 304 is not recognized.
# Label UDFtr on Section 304 is not recognized.
# Label UDFtr on Section 304 is not recognized.
# Label icp on Section 304 is not recognized.
# Label 8n on Section 304 is not recognized.
# Label LVe on Section 304 is not recognized.
# Label DC on Section 306 is not recognized.
# Label icp on Section 306 is not recognized.
# Label 8n on Section 306 is not recognized.
# Label DC on Section 308 is not recognized.
# Label icp on Section 308 is not recognized.
# Label 8n on Section 308 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0309/ does not exist.
# Label 8n on Section 310 is not recognized.
# Label DC on Section 310 is not recognized.
# Label mcp on Section 310 is not recognized.
# Label icp on Section 310 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0311/ does not exist.
# Label 8n on Section 312 is not recognized.
# Label DC on Section 312 is not recognized.
# Label icp on Section 312 is not recognized.
# Label Pr5DM on Section 312 is not recognized.
# Label mcp on Section 312 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0313/ does not exist.
# Label mcp on Section 314 is not recognized.
# Label Pr5DM on Section 314 is not recognized.
# Label DC on Section 314 is not recognized.
# Label Sp5C on Section 314 is not recognized.
# Label icp on Section 314 is not recognized.
# Label 8n on Section 314 is not recognized.
# Label Sp5I on Section 314 is not recognized.
# Label Sp5O on Section 314 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0315/ does not exist.
# Label mcp on Section 316 is not recognized.
# Label 8n on Section 316 is not recognized.
# Label Sp5I on Section 316 is not recognized.
# Label DC on Section 316 is not recognized.
# Label Sp5O on Section 316 is not recognized.
# Label icp on Section 316 is not recognized.
# Label Pr5DM on Section 316 is not recognized.
# Label Sp5C on Section 316 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0317/ does not exist.
# Label mcp on Section 318 is not recognized.
# Label icp on Section 318 is not recognized.
# Label DC on Section 318 is not recognized.
# Label 8n on Section 318 is not recognized.
# Label Pr5DM on Section 318 is not recognized.
# Label Sp5I on Section 318 is not recognized.
# Label Sp5O on Section 318 is not recognized.
# Label Sp5C on Section 318 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0319/ does not exist.
# Label Pr5DM on Section 320 is not recognized.
# Label Sp5O on Section 320 is not recognized.
# Label Sp5C on Section 320 is not recognized.
# Label mcp on Section 320 is not recognized.
# Label DC on Section 320 is not recognized.
# Label Sp5I on Section 320 is not recognized.
# Label 8n on Section 320 is not recognized.
# Label icp on Section 320 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0321/ does not exist.
# Label Sp5I on Section 322 is not recognized.
# Label Pr5DM on Section 322 is not recognized.
# Label mcp on Section 322 is not recognized.
# Label 8n on Section 322 is not recognized.
# Label icp on Section 322 is not recognized.
# Label Sp5C on Section 322 is not recognized.
# Label Sp5O on Section 322 is not recognized.
# Label DC on Section 322 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0323/ does not exist.
# Label 8n on Section 324 is not recognized.
# Label Sp5O on Section 324 is not recognized.
# Label Pr5DM on Section 324 is not recognized.
# Label Sp5C on Section 324 is not recognized.
# Label Pr5VL on Section 324 is not recognized.
# Label DC on Section 324 is not recognized.
# Label Sp5I on Section 324 is not recognized.
# Label icp on Section 324 is not recognized.
# Label mcp on Section 324 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0325/ does not exist.
# Label Sp5I on Section 326 is not recognized.
# Label Sp5C on Section 326 is not recognized.
# Label Sp5O on Section 326 is not recognized.
# Label Pr5DM on Section 326 is not recognized.
# Label DC on Section 326 is not recognized.
# Label mcp on Section 326 is not recognized.
# Label 8n on Section 326 is not recognized.
# Label icp on Section 326 is not recognized.
# Label Pr5VL on Section 326 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0327/ does not exist.
# Label 8n on Section 328 is not recognized.
# Label DC on Section 328 is not recognized.
# Label mcp on Section 328 is not recognized.
# Label icp on Section 328 is not recognized.
# Label VCA on Section 328 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0329/ does not exist.
# Label icp on Section 330 is not recognized.
# Label mcp on Section 330 is not recognized.
# Label 8n on Section 330 is not recognized.
# Label VCA on Section 330 is not recognized.
# Label DC on Section 330 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0331/ does not exist.
# Label 8n on Section 332 is not recognized.
# Label DC on Section 332 is not recognized.
# Label mcp on Section 332 is not recognized.
# Label VCA on Section 332 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0333/ does not exist.
# Label VCA on Section 334 is not recognized.
# Label DC on Section 334 is not recognized.
# Label mcp on Section 334 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0335/ does not exist.
# Label DC on Section 336 is not recognized.
# Label VCPO on Section 336 is not recognized.
# Label VCP on Section 336 is not recognized.
# Label VCA on Section 336 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0337/ does not exist.
# Label VCA on Section 338 is not recognized.
# Label VCPO on Section 338 is not recognized.
# Label DC on Section 338 is not recognized.
# Label VCP on Section 338 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0339/ does not exist.
# Label VCA on Section 340 is not recognized.
# Label DC on Section 340 is not recognized.
# Label VCPO on Section 340 is not recognized.
# Label VCP on Section 340 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0341/ does not exist.
# Label DC on Section 342 is not recognized.
# Label VCP on Section 342 is not recognized.
# Label VCPO on Section 342 is not recognized.
# Label VCA on Section 342 is not recognized.
# Label VCAGr on Section 342 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0343/ does not exist.
# Label VCP on Section 344 is not recognized.
# Label DC on Section 344 is not recognized.
# Label VCA on Section 344 is not recognized.
# Label VCPO on Section 344 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0345/ does not exist.
# Label VCPO on Section 346 is not recognized.
# Label VCA on Section 346 is not recognized.
# Label DC on Section 346 is not recognized.
# Label VCP on Section 346 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0347/ does not exist.
# Label VCA on Section 348 is not recognized.
# Label VCPO on Section 348 is not recognized.
# Label DC on Section 348 is not recognized.
# Label VCP on Section 348 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0349/ does not exist.
# Label VCP on Section 350 is not recognized.
# Label DC on Section 350 is not recognized.
# Label VCA on Section 350 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0351/ does not exist.
# Label DC on Section 352 is not recognized.
# Label VCA on Section 352 is not recognized.
# Label VCP on Section 352 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0353/ does not exist.
# Label VCA on Section 354 is not recognized.
# Label VCP on Section 354 is not recognized.
# Label DC on Section 354 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0355/ does not exist.
# Label VCA on Section 356 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0357/ does not exist.
# Label VCA on Section 358 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0359/ does not exist.
# Label VCA on Section 360 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0361/ does not exist.
# Label VCA on Section 362 is not recognized.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0363/ does not exist.
# Directory /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped_midbrainIncluded/MD594/0364/ does not exist.

# %%
label_polygons_sideAssigned = assign_sideness(label_polygons)

# %%
downsample_factor = 16
xy_pixel_distance_downsampled = xy_pixel_distance_lossless * downsample_factor
z_xy_ratio_downsampled = section_thickness / xy_pixel_distance_downsampled

# %%
# interpolate contours

t = time.time()

interpolated_contours = [{} for _ in range(int(z_xy_ratio_downsampled*section_number_lookup[stack]))]
    
for name in label_polygons_sideAssigned.keys():
    
    considered_secs = label_polygons_sideAssigned[name].dropna().keys()
    
    n = len(considered_secs)
    
    for i in range(n):
        sec = considered_secs[i]            
        z0 = int(z_xy_ratio_downsampled*sec)
        interpolated_contours[z0][name] = label_polygons_sideAssigned.loc[sec][name]
        if i + 1 < n:
            next_sec = considered_secs[i+1]
            z1 = int(z_xy_ratio_downsampled*next_sec)
            interp_cnts = interpolate_contours(label_polygons_sideAssigned.loc[sec][name], 
                                               label_polygons_sideAssigned.loc[next_sec][name],
                                               z1-z0+1)
            for zi, z in enumerate(range(z0+1, z1)):
                interpolated_contours[z][name] = interp_cnts[zi+1]
                
sys.stderr.write('interpolate contours: %.2f seconds\n' % (time.time() - t)) # ~37s
# Out:
# interpolate contours: 29.50 seconds

# %%
t = time.time()

dm = DataManager(stack=stack)

img_height_downsampled = dm.image_height/downsample_factor
img_width_downsampled = dm.image_width/downsample_factor

volume = np.zeros((img_height_downsampled, img_width_downsampled, 
                   int(section_number_lookup[stack]*z_xy_ratio_downsampled)), np.int8)

print volume.shape

for z in range(volume.shape[2]):
        
    if len(interpolated_contours[z]) == 0:
        continue
    
    label_map_downsampled = np.zeros((img_height_downsampled, img_width_downsampled), np.int8)
    
    for name_s, vs in interpolated_contours[z].iteritems():
        vs_downsampled = vs/downsample_factor
        
        xmin, ymin = np.min(vs_downsampled, axis=0).astype(np.int)
        xmax, ymax = np.max(vs_downsampled, axis=0).astype(np.int)
                
        xmin = max(0, xmin)
        ymin = max(0, ymin)
        xmax = min(xmax, img_width_downsampled-1)
        ymax = min(ymax, img_height_downsampled-1)
        
        xs, ys = np.meshgrid(range(xmin, xmax+1), range(ymin, ymax+1))
        points_to_test = np.c_[xs.flat, ys.flat]
                
        is_contained = Path(vs_downsampled).contains_points(points_to_test)
        label_map_downsampled[points_to_test[is_contained, 1], 
                              points_to_test[is_contained, 0]] = labels_sided_indices[name_s]
        
    volume[:, :, z] = label_map_downsampled.copy()
    
    del label_map_downsampled
    
sys.stderr.write('build volume all: %.2f seconds\n' % (time.time() - t)) # ~37s
# Out:
# (724, 1028, 1173)
# build volume all: 32.46 seconds

# %%
fig, axes = plt.subplots(5, 5, figsize=(20,20) , squeeze=True);
axes = axes.flatten()
for i, z in enumerate(range(0, volume.shape[2], 50)):
    axes[i].imshow(volume[..., z], vmin=0, vmax=len(labels_sided));
    axes[i].set_title('z = %d' % z);
plt.show();

# %%
xmin, xmax, ymin, ymax, zmin, zmax = bbox_3d(volume)

print 'volume bbox dimension:', xmin, xmax, ymin, ymax, zmin, zmax

reduced_xdim = xmax+1-xmin
reduced_ydim = ymax+1-ymin
reduced_zdim = zmax+1-zmin
print 'reduced bbox dimension:', reduced_xdim, reduced_ydim, reduced_zdim
# Out:
# volume bbox dimension: 233 1027 322 667 293 836
# reduced bbox dimension: 795 346 544

# %%
reduced_volume = volume[ymin:ymax+1, xmin:xmax+1, zmin:zmax+1]

# %%
# output

bp.pack_ndarray_file(reduced_volume,
                     os.path.join(volume_dir, '%(stack)s/%(stack)s_annotationVolume.bp' % {'stack': stack}))

# %%
with open(os.path.join(volume_dir, '%(stack)s/%(stack)s_annotationVolume_limits.txt' % {'stack': stack}), 'w') as f:
        f.write((' '.join(['%d']*6)+'\n') % (xmin, xmax, ymin, ymax, zmin, zmax))
        
with open(os.path.join(volume_dir, '%(stack)s/%(stack)s_annotationVolume_resolution.txt' % {'stack': stack}), 'w') as f:
        f.write((' '.join(['%f']*3)+'\n') % (downsample_factor, xy_pixel_distance_downsampled, z_xy_ratio_downsampled))

# %%
with open(os.path.join(volume_dir, '%(stack)s/%(stack)s_annotationVolume_landmarkBboxes.txt' % {'stack': stack}), 'w') as f:
    for name in label_polygons_sideAssigned.keys():
        bbox = bbox_3d(reduced_volume == labels_sided_indices[name])
        f.write(name + ' ' + ' '.join(map(str, bbox)) + '\n')

# %%
with open(os.path.join(volume_dir, '%(stack)s/%(stack)s_annotationVolume_labelIndices.txt' % {'stack': stack}), 'w') as f:
    f.write('BackG 0\n')
    for name_s in label_polygons_sideAssigned.keys():
        f.write(name_s + ' ' + str(labels_sided_indices[name_s]) + '\n')
