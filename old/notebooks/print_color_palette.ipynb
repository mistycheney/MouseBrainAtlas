# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

hc_colors = np.loadtxt('../visualization/100colors.txt')

fig, axes = plt.subplots(ncols=len(hc_colors), figsize=(100,5))
fig.subplots_adjust(top=0.95, bottom=0.01, left=0.2, right=0.99)

for i, (ax, c) in enumerate(zip(axes, hc_colors)):
    color_box = np.empty((1,1,3))
    color_box[:,:] = c
    ax.imshow(color_box, aspect='equal')
    pos = list(ax.get_position().bounds)
    x_text = pos[0] + pos[2]/2.
    y_text = pos[1] + pos[3]/2.
    fig.text(x_text, y_text, i, va='center', ha='center', fontsize=50)

for ax in axes:
    ax.set_axis_off()
    
plt.savefig('../visualization/100colors.tif', bbox_inches='tight')
# plt.show()
