# %%
# %reload_ext autoreload
# %autoreload 2

import cv2

import os
import sys
sys.path.append(os.path.join(os.environ['REPO_DIR'], 'utilities'))
from utilities2015 import *

from collections import defaultdict

from matplotlib.path import Path
# %matplotlib inline

import pandas as pd

from joblib import Parallel, delayed

from scipy.interpolate import RectBivariateSpline
from skimage.transform import rescale, resize

# %%
stack = 'MD589'
# stack = 'MD594'
dm = DataManager(stack=stack)

label_polygons = pd.read_hdf('/home/yuncong/Brain/database/'+stack+'_label_polygons.h5', 'label_polygons')

# %%
label_polygons
# Out:
#      10N  12N   3N   4N                                                 5N  \
# 110  NaN  NaN  NaN  NaN                                                NaN
# 111  NaN  NaN  NaN  NaN                                                NaN
# 113  NaN  NaN  NaN  NaN                                                NaN
# 115  NaN  NaN  NaN  NaN                                                NaN
# 117  NaN  NaN  NaN  NaN                                                NaN
# 119  NaN  NaN  NaN  NaN                                                NaN
# 121  NaN  NaN  NaN  NaN                                                NaN
# 123  NaN  NaN  NaN  NaN                                                NaN
# 125  NaN  NaN  NaN  NaN                                                NaN
# 127  NaN  NaN  NaN  NaN                                                NaN
# 129  NaN  NaN  NaN  NaN                                                NaN
# 131  NaN  NaN  NaN  NaN                                                NaN
# 133  NaN  NaN  NaN  NaN                                                NaN
# 135  NaN  NaN  NaN  NaN                                                NaN
# 137  NaN  NaN  NaN  NaN                                                NaN
# 139  NaN  NaN  NaN  NaN                                                NaN
# 141  NaN  NaN  NaN  NaN                                                NaN
# 143  NaN  NaN  NaN  NaN                                                NaN
# 145  NaN  NaN  NaN  NaN                                                NaN
# 147  NaN  NaN  NaN  NaN                                                NaN
# 149  NaN  NaN  NaN  NaN                                                NaN
# 150  NaN  NaN  NaN  NaN  [[3920, 7864], [3869, 7667], [3794, 7569], [36...
# 151  NaN  NaN  NaN  NaN  [[3759, 7277], [3926, 7120], [4120, 7044], [44...
# 152  NaN  NaN  NaN  NaN  [[4184, 7041], [4290, 7139], [4412, 7304], [43...
# 153  NaN  NaN  NaN  NaN  [[3935, 7036], [3761, 7120], [3645, 7285], [35...
# 154  NaN  NaN  NaN  NaN  [[3730, 7114], [3903, 7098], [4104, 7082], [42...
# 155  NaN  NaN  NaN  NaN  [[4064, 8535], [4258, 8514], [4358, 8198], [43...
# 156  NaN  NaN  NaN  NaN  [[3660, 7293], [3763, 7215], [3830, 7112], [40...
# 157  NaN  NaN  NaN  NaN  [[3658, 8430], [3556, 8124], [3534, 7798], [36...
# 158  NaN  NaN  NaN  NaN  [[3561, 7343], [3795, 7277], [3915, 7223], [41...
# ..   ...  ...  ...  ...                                                ...
# 305  NaN  NaN  NaN  NaN                                                NaN
# 306  NaN  NaN  NaN  NaN  [[3934, 8136], [4148, 8004], [4335, 7838], [43...
# 307  NaN  NaN  NaN  NaN  [[4157, 7230], [4117, 7444], [4039, 7580], [40...
# 308  NaN  NaN  NaN  NaN  [[4032, 7698], [4005, 7529], [4022, 7336], [40...
# 309  NaN  NaN  NaN  NaN  [[3199, 7091], [3339, 6952], [3486, 6838], [37...
# 310  NaN  NaN  NaN  NaN  [[4064, 6586], [4058, 6769], [4106, 6920], [41...
# 345                                                NaN  NaN
# 347                                                NaN  NaN
# 349                                                NaN  NaN
# 351                                                NaN  NaN
#
#                                                     7N  \
# 110                                                NaN
# 111                                                NaN
# 113                                                NaN
# 115                                                NaN
# 117                                                NaN
# 119                                                NaN
# 121                                                NaN
# 123                                                NaN
# 125                                                NaN
# 127                                                NaN
# 129                                                NaN
# 131                                                NaN
# 133                                                NaN
# 135                                                NaN
# 137                                                NaN
# 139                                                NaN
# 141                                                NaN
# 143                                                NaN
# 145                                                NaN
# 147                                                NaN
# 149                                                NaN
# 150                                                NaN
# 151                                                NaN
# 152  [[5724, 10339], [5592, 10277], [5518, 10194], ...
# 153  [[5915, 10004], [6149, 10057], [6353, 10177], ...
# 154  [[5888, 10541], [5665, 10474], [5516, 10393], ...
# 155  [[5607, 10462], [5890, 10506], [6188, 10501], ...
# 156  [[5301, 10043], [5392, 10015], [5522, 9984], [...
# 157  [[5494, 10392], [5368, 10460], [5213, 10274], ...
# 158  [[5694, 9867], [5899, 9858], [6122, 9876], [62...
# ..                                                 ...
# 305  [[5191, 10152], [5065, 10062], [4915, 9948], [...
# 306  [[4992, 10027], [4894, 9811], [4728, 9600], [4...
# 307  [[5195, 10018], [5082, 9982], [5000, 9926], [4...
# 308  [[5632, 10128], [5378, 10083], [5109, 9958], [...
# 309  [[5127, 9702], [5212, 9642], [5375, 9642], [55...
# 310  [[5681, 9980], [5914, 10030], [6142, 10062], [...
# 311  [[5526, 9475], [5608, 9493], [5693, 9488], [58...
# 312  [[5492, 9478], [5778, 9464], [6172, 9455], [64...
# 313  [[5380, 9503], [5522, 9507], [5638, 9535], [57...
# 314  [[5529, 9545], [5740, 9514], [5907, 9477], [61...
# 315  [[5722, 9773], [5637, 9734], [5598, 9709], [55...
# 316  [[5605, 9614], [5673, 9535], [5851, 9499], [59...
# 318                                                NaN
# 320                                                NaN
# 322                                                NaN
# 323                                                NaN
# 325                                                NaN
# 327                                                NaN
# 329                                                NaN
# 331                                                NaN
# 333                                                NaN
# 335                                                NaN
# 337                                                NaN
# 339                                                NaN
# 341                                                NaN
# 343                                                NaN
# 345                                                NaN
# 347                                                NaN
# 349                                                NaN
# 351                                                NaN
#
#                                                     7n   9N ...   \
# 110                                                NaN  NaN ...
# 111                                                NaN  NaN ...
# 113                                                NaN  NaN ...
# 115                                                NaN  NaN ...
# 117                                                NaN  NaN ...
# 119                                                NaN  NaN ...
# 121                                                NaN  NaN ...
# 123                                                NaN  NaN ...
# 125                                                NaN  NaN ...
# 127                                                NaN  NaN ...
# 129                                                NaN  NaN ...
# 131                                                NaN  NaN ...
# 133                                                NaN  NaN ...
# 135                                                NaN  NaN ...
# 137                                                NaN  NaN ...
# 139                                                NaN  NaN ...
# 141                                                NaN  NaN ...
# 143                                                NaN  NaN ...
# 145                                                NaN  NaN ...
# 147                                                NaN  NaN ...
# 149  [[3959, 10068], [3797, 9942], [3744, 9802], [3...  NaN ...
# 150  [[3963, 10012], [3779, 9942], [3670, 9854], [3...  NaN ...
# 151  [[4011, 9948], [3829, 9846], [3740, 9747], [37...  NaN ...
# 152  [[4094, 10060], [3900, 9970], [3813, 9881], [3...  NaN ...
# 153  [[3978, 9609], [4226, 9564], [4453, 9633], [45...  NaN ...
# 154  [[3950, 9605], [4177, 9566], [4400, 9592], [45...  NaN ...
# 155  [[4092, 9572], [4305, 9517], [4514, 9564], [46...  NaN ...
# 156  [[4044, 9529], [4213, 9466], [4469, 9450], [45...  NaN ...
# 157  [[4211, 9458], [4398, 9357], [4590, 9321], [47...  NaN ...
# 158  [[4069, 9505], [4178, 9413], [4379, 9339], [45...  NaN ...
# ..                                                 ...  ... ...
# 305  [[4357, 9265], [4183, 9253], [4075, 9163], [40...  NaN ...
# 306  [[4022, 8988], [4011, 9079], [4124, 9231], [42...  NaN ...
# 307  [[4091, 9280], [4011, 9241], [3967, 9139], [40...  NaN ...
# 308  [[4107, 9024], [4300, 8982], [4528, 8994], [46...  NaN ...
# 309  [[4161, 9355], [4090, 9326], [3970, 9291], [38...  NaN ...
# 310  [[3923, 9102], [4096, 9065], [4236, 9088], [44...  NaN ...
# 311  [[4202, 9128], [4346, 9091], [4398, 9099], [45...  NaN ...
# 312  [[3855, 9179], [4022, 9133], [4282, 9161], [44...  NaN ...
# 313  [[4176, 9188], [4382, 9138], [4505, 9163], [46...  NaN ...
# 314  [[3975, 9173], [4144, 9193], [4334, 9213], [44...  NaN ...
# 315  [[4117, 9450], [3937, 9387], [3845, 9270], [38...  NaN ...
# 316  [[3880, 9230], [4063, 9222], [4299, 9225], [44...  NaN ...
# 318                                                NaN  NaN ...
# 320                                                NaN  NaN ...
# 322                                                NaN  NaN ...
# 323                                                NaN  NaN ...
# 325                                                NaN  NaN ...
# 327                                                NaN  NaN ...
# 329                                                NaN  NaN ...
# 331                                                NaN  NaN ...
# 333                                                NaN  NaN ...
# 335                                                NaN  NaN ...
# 337                                                NaN  NaN ...
# 339                                                NaN  NaN ...
# 341                                                NaN  NaN ...
# 343                                                NaN  NaN ...
# 345                                                NaN  NaN ...
# 347                                                NaN  NaN ...
# 349                                                NaN  NaN ...
# 351                                                NaN  NaN ...
#
#                                                   VOri  \
# 110                                                NaN
# 111                                                NaN
# 113                                                NaN
# 115                                                NaN
# 117                                                NaN
# 119                                                NaN
# 121                                                NaN
# 123                                                NaN
# 125                                                NaN
# 127                                                NaN
# 129                                                NaN
# 131  [[7331, 8579], [7195, 8604], [7147, 8706], [71...
# 133                                                NaN
# 135                                                NaN
# 137                                                NaN
# 139                                                NaN
# 141                                                NaN
# 143                                                NaN
# 145                                                NaN
# 147                                                NaN
# 149                                                NaN
# 150                                                NaN
# 151                                                NaN
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
# 157                                                NaN
# 158                                                NaN
# ..                                                 ...
# 305                                                NaN
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
# 310                                                NaN
# 311                                                NaN
# 312                                                NaN
# 313                                                NaN
# 314                                                NaN
# 315                                                NaN
# 316                                                NaN
# 318                                                NaN
# 320                                                NaN
# 322                                                NaN
# 323                                                NaN
# 325                                                NaN
# 327                                                NaN
# 329                                                NaN
# 331                                                NaN
# 333                                                NaN
# 335                                                NaN
# 337                                                NaN
# 339                                                NaN
# 341                                                NaN
# 343                                                NaN
# 345                                                NaN
# 347                                                NaN
# 349                                                NaN
# 351                                                NaN
#
#                                                   VOrp  VTg  \
# 110                                                NaN  NaN
# 111                                                NaN  NaN
# 113                                                NaN  NaN
# 115                                                NaN  NaN
# 150                                                NaN  NaN
# 151  [[8336, 7364], [8848, 7253], [9232, 7279], [96...  NaN
# 152                                                NaN  NaN
# 153  [[8563, 7366], [8969, 7341], [9205, 7238], [95...  NaN
# 154  [[8426, 7433], [8840, 7333], [9266, 7308], [96...  NaN
# 155  [[8923, 7422], [9354, 7350], [9591, 7293], [99...  NaN
# 156  [[8871, 7426], [9301, 7390], [9630, 7390], [10...  NaN
# 157  [[9501, 7296], [9919, 7384], [10247, 7529], [1...  NaN
# 158  [[8870, 7598], [9429, 7567], [9875, 7598], [10...  NaN
# ..                                                 ...  ...
# 305                                                NaN  NaN
# 306  [[7974, 6662], [8448, 6675], [8899, 6813], [92...  NaN
# 307                                                NaN  NaN
# 308  [[7707, 6697], [8134, 6689], [8398, 6660], [88...  NaN
# 309                                                NaN  NaN
# 310  [[10086, 7169], [10289, 7581], [10410, 7797], ...  NaN
# 311                                                NaN  NaN
# 312  [[9306, 6880], [9577, 7038], [9807, 7096], [10...  NaN
# 313                                                NaN  NaN
# 314  [[9142, 6828], [9457, 6880], [9547, 6982], [98...  NaN
# 315                                                NaN  NaN
# 316  [[5911, 7286], [6286, 7440], [7026, 7396], [75...  NaN
# 318  [[5791, 7363], [6228, 7556], [6629, 7572], [70...  NaN
# 320  [[5950, 7832], [6646, 7811], [7136, 7663], [76...  NaN
# 322  [[5374, 7437], [5759, 7742], [6109, 7859], [68...  NaN
# 323  [[3355, 8667], [3739, 8903], [4249, 9018], [50...  NaN
# 325  [[9455, 7547], [9782, 8106], [9850, 8546], [97...  NaN
# 327  [[9589, 7770], [9737, 8176], [9801, 8595], [97...  NaN
# 329                                                NaN  NaN
# 331                                                NaN  NaN
# 333                                                NaN  NaN
# 335                                                NaN  NaN
# 337                                                NaN  NaN
# 339                                                NaN  NaN
# 341                                                NaN  NaN
# 343                                                NaN  NaN
# 345                                                NaN  NaN
# 347                                                NaN  NaN
# 349                                                NaN  NaN
# 351                                                NaN  NaN
#
# [206 rows x 60 columns]

# %%
# labels =  ['BackG', '5N', '7n', '7N', '12N', 'Gr', 'LVe', 'Pn', 'SuVe', 'VLL']

labels = ['BackG', '5N', '7n', '7N', '12N', 'Gr', 'LVe', 'Pn', 'SuVe', 'VLL', 
                     '6N', 'Amb', 'R', 'Tz', 'Sol', 'RtTg', 'LRt', 'LC', 'AP', 'sp5']


other_labels = [l for l in label_polygons.dropna().keys() if l not in labels]

# label_dict = dict([(l,i) for i, l in enumerate(labels)])

label_dict = dict([(l,i) for i, l in enumerate(labels)] + \
                  zip(other_labels, range(len(labels), len(labels)+len(other_labels))))

colors = (np.loadtxt(os.environ['REPO_DIR'] + '/visualization/100colors.txt')*255).astype(np.uint8)
colors[label_dict['BackG']] = 255

# %%
labelMapLossless_dir = '/oasis/projects/nsf/csd395/yuncong/CSHL_labelMapsLossless/%(stack)s/' % {'stack': stack}
if not os.path.exists(labelMapLossless_dir):
    os.makedirs(labelMapLossless_dir)

# %%
from matplotlib.path import Path
from itertools import product

# %%
# only 9 (19) classes
for sec in label_polygons.index:
    print sec
    
    available_labels = label_polygons.loc[sec].dropna().index
    
    valid_labels = set(available_labels) & set(labels)
    
    if len(valid_labels) == 0:
        continue
    
    label_map = np.zeros((dm.image_height, dm.image_width), np.int8)
    for l in valid_labels:
        print l
        vs = label_polygons[l][sec]
        xmin, ymin = np.min(vs, axis=0)
        xmax, ymax = np.max(vs, axis=0)
                
        if xmin > dm.image_width - 1 or ymin > dm.image_height - 1:
            print 'min coordinates exceed image boundary'
            continue
        
        xmax = min(xmax, dm.image_width-1)
        ymax = min(ymax, dm.image_height-1)
        
#         import time
#         t = time.time()
        
#         points_to_test = np.array(list(product(range(ymin, ymax+1), range(xmin, xmax+1))))[:,::-1]
        xs, ys = np.meshgrid(range(xmin, xmax+1), range(ymin, ymax+1))
        points_to_test = np.c_[xs.flat, ys.flat]
        
#         print time.time() - t
        
        is_contained = Path(vs).contains_points(points_to_test)
        label_map[points_to_test[is_contained, 1], points_to_test[is_contained, 0]] = label_dict[l]
    
    
    bp.pack_ndarray_file(label_map, os.path.join(labelMapLossless_dir, 
                                     '%(stack)s_%(sec)04d_labelMapLossless.bp' % \
                                    {'stack': stack, 'sec': sec}))

#     np.savez_compressed(os.path.join(labelMapLossless_dir, 
#                                      '%(stack)s_%(sec)04d_labelMapLossless' % \
#                                     {'stack': stack, 'sec': sec}), 
#                         label_map)
# Out:
# 110
# 111
# 113
# 115
# 117
# 119
# 121
# 123
# 125
# 127
# 129
# 131
# sp5
# 133
# sp5
# 135
# sp5
# 137
# sp5
# 139
# sp5
# 141
# sp5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4eae5536b2a4> in <module>()
#      33 #         print time.time() - t
#      34
# ---> 35         is_contained = Path(vs).contains_points(points_to_test)
#      36         label_map[points_to_test[is_contained, 1], points_to_test[is_contained, 0]] = label_dict[l]
#      37
#
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/matplotlib/path.pyc in contains_points(self, points, transform, radius)
#     510         if transform is not None:
#     511             transform = transform.frozen()
# --> 512         result = _path.points_in_path(points, radius, self, transform)
#     513         return result
#     514
#
# KeyboardInterrupt:

# %%
# all landmarks
for sec in label_polygons.index:
    
    print sec
    
    available_labels = label_polygons.loc[sec].dropna().index
    
    valid_labels = set(available_labels)
    
    if len(valid_labels) == 0:
        continue
    
    label_map = np.zeros((dm.image_height, dm.image_width), np.int8)
    for l in valid_labels:
        print l
        vs = label_polygons[l][sec]
        xmin, ymin = np.min(vs, axis=0)
        xmax, ymax = np.max(vs, axis=0)
        
        if xmin > dm.image_width - 1 or ymin > dm.image_height - 1:
            print 'min coordinates exceed image boundary'
            continue
        
        xmax = min(xmax, dm.image_width-1)
        ymax = min(ymax, dm.image_height-1)
        
        points_to_test = np.array(list(product(range(ymin, ymax+1), range(xmin, xmax+1))))[:,::-1]
        is_contained = Path(vs).contains_points(points_to_test)
        
        label_map[points_to_test[is_contained, 1], 
                  points_to_test[is_contained, 0]] = label_dict[l]
    
    np.savez_compressed(os.path.join(labelMapLossless_dir, 
                                     '%(stack)s_%(sec)04d_labelMapLossless_AllClasses' % \
                                    {'stack': stack, 'sec': sec}), 
                        label_map)
