# %%
"""
Resection a thumbnail volume in three planes.
"""

# %%
import numpy as np

import sys
import os

sys.path.append(os.environ['REPO_DIR'] + '/utilities')
from utilities2015 import *
from data_manager import *
from metadata import *

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Setting environment for Gordon

# %%
stack = 'MD589'

# %%
volume = bp.unpack_ndarray_file(volume_dir + '/%(stack)s/%(stack)s_thumbnailVolume.bp' % {'stack': stack})

# %%
volume.shape
# Out:
# (367, 499, 604)

# %%
resection_dir = '/home/yuncong/csd395/CSHL_volumes_resection'

# %%
for y in range(volume.shape[0]):
    create_if_not_exists(os.path.join(resection_dir, 'horizontal'))
    imsave(os.path.join(resection_dir, 'horizontal', '%s_thumbnailVolume_horizontal_%03d.tif'%(stack, y)), volume[y,:,::-1].T)

# %%
for x in range(volume.shape[1]):
    create_if_not_exists(os.path.join(resection_dir, 'coronal'))
    imsave(os.path.join(resection_dir, 'coronal', '%s_thumbnailVolume_coronal_%03d.tif'%(stack, x)), volume[:,x,::-1])
# Out:
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/skimage/io/_io.py:131: UserWarning: /home/yuncong/csd395/CSHL_volumes_resection/coronal/MD589_thumbnailVolume_coronal_497.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/skimage/io/_io.py:131: UserWarning: /home/yuncong/csd395/CSHL_volumes_resection/coronal/MD589_thumbnailVolume_coronal_498.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
for z in range(volume.shape[2]):
    create_if_not_exists(os.path.join(resection_dir, 'sagittal'))
    imsave(os.path.join(resection_dir, 'sagittal', '%s_thumbnailVolume_sagittal_%03d.tif'%(stack, z)), volume[:,:,z])
# Out:
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/skimage/io/_io.py:131: UserWarning: /home/yuncong/csd395/CSHL_volumes_resection/sagittal/MD589_thumbnailVolume_sagittal_000.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/skimage/io/_io.py:131: UserWarning: /home/yuncong/csd395/CSHL_volumes_resection/sagittal/MD589_thumbnailVolume_sagittal_001.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/skimage/io/_io.py:131: UserWarning: /home/yuncong/csd395/CSHL_volumes_resection/sagittal/MD589_thumbnailVolume_sagittal_002.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# ...
