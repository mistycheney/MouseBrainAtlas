# %%
# %load_ext autoreload
# %autoreload 2

from IPython.display import Image, FileLink

from compute_features_module import GaborFeatureComputer
from kmeans_module import SaliencyDetector

import cv2

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/numpy/lib/utils.py:134: DeprecationWarning: `scipy.lib.lapack` is deprecated, use `scipy.linalg.lapack` instead!
#   warnings.warn(depdoc, DeprecationWarning)

# %%
for img_id in range(241,250):
    img_name = 'PMD1305_%d.reduce2.region1'%img_id
    CACHE_DIR = '/home/yuncong/my_csd181_scratch/'
    IMG_DIR = '/home/yuncong/my_csd181/ParthaData/PMD1305_reduce2/region1/'

    # img_name = 'Resized_6_region'
    # IMG_DIR = '/home/yuncong/my_csd181_scratch/'

    # img = cv2.imread(IMG_DIR + 'PMD1305_%d.reduce2.region.tif' % img_id, 0)
    img = cv2.imread(IMG_DIR + img_name + '.tif', 0)

    gc = GaborFeatureComputer()
    filtered_output = CACHE_DIR + img_name + '_filtered'
    features_output = CACHE_DIR + img_name + '_features'
    gc.process_image(img, filtered_output=filtered_output,
                     features_output=features_output)
# Out:
# # of kernels = 60
# frequencies: [ 0.14142136  0.1         0.07071068  0.05        0.03535534]
# # of pixels per cycle: [  7.07106781  10.          14.14213562  20.          28.28427125]
# ==== do_gabor_filter Timing ====
# filtered images saved to /home/yuncong/my_csd181_scratch/PMD1305_241.reduce2.region1_filtered
# filtering completes
# 'do_gabor_filter' run time was 10.631821156 sec
# ==== compute_features Timing ====
# 32 features selected
# features saved to /home/yuncong/my_csd181_scratch/PMD1305_241.reduce2.region1_features
# 'compute_features' run time was 48.523020029 sec
# # of kernels = 60
# frequencies: [ 0.14142136  0.1         0.07071068  0.05        0.03535534]
# # of pixels per cycle: [  7.07106781  10.          14.14213562  20.          28.28427125]
# ==== do_gabor_filter Timing ====
# filtered images saved to /home/yuncong/my_csd181_scratch/PMD1305_242.reduce2.region1_filtered
# filtering completes
# 'do_gabor_filter' run time was 10.697818995 sec
# ==== compute_features Timing ====
# 32 features selected
# features saved to /home/yuncong/my_csd181_scratch/PMD1305_242.reduce2.region1_features
# 'compute_features' run time was 48.274784088 sec
# # of kernels = 60
# frequencies: [ 0.14142136  0.1         0.07071068  0.05        0.03535534]
# # of pixels per cycle: [  7.07106781  10.          14.14213562  20.          28.28427125]
# ==== do_gabor_filter Timing ====
# filtered images saved to /home/yuncong/my_csd181_scratch/PMD1305_243.reduce2.region1_filtered
# filtering completes
# 'do_gabor_filter' run time was 16.063008785 sec
# ==== compute_features Timing ====
# 32 features selected
# features saved to /home/yuncong/my_csd181_scratch/PMD1305_243.reduce2.region1_features
# 'compute_features' run time was 48.267506838 sec
# # of kernels = 60
# frequencies: [ 0.14142136  0.1         0.07071068  0.05        0.03535534]
# # of pixels per cycle: [  7.07106781  10.          14.14213562  20.          28.28427125]
# ==== do_gabor_filter Timing ====
# filtered images saved to /home/yuncong/my_csd181_scratch/PMD1305_244.reduce2.region1_filtered
# filtering completes
# 'do_gabor_filter' run time was 10.914150953 sec
# ==== compute_features Timing ====
# 32 features selected
# features saved to /home/yuncong/my_csd181_scratch/PMD1305_244.reduce2.region1_features
# 'compute_features' run time was 48.436132193 sec
# # of kernels = 60
# frequencies: [ 0.14142136  0.1         0.07071068  0.05        0.03535534]
# # of pixels per cycle: [  7.07106781  10.          14.14213562  20.          28.28427125]
# ==== do_gabor_filter Timing ====
# filtered images saved to /home/yuncong/my_csd181_scratch/PMD1305_245.reduce2.region1_filtered
# filtering completes
# 'do_gabor_filter' run time was 14.104610920 sec
# ==== compute_features Timing ====
# 32 features selected
# features saved to /home/yuncong/my_csd181_scratch/PMD1305_245.reduce2.region1_features
# 'compute_features' run time was 59.575933933 sec
# # of kernels = 60
# frequencies: [ 0.14142136  0.1         0.07071068  0.05        0.03535534]
# # of pixels per cycle: [  7.07106781  10.          14.14213562  20.          28.28427125]
# ==== do_gabor_filter Timing ====
# filtered images saved to /home/yuncong/my_csd181_scratch/PMD1305_246.reduce2.region1_filtered
# filtering completes
# 'do_gabor_filter' run time was 27.260679960 sec
# ==== compute_features Timing ====
# 32 features selected
# features saved to /home/yuncong/my_csd181_scratch/PMD1305_246.reduce2.region1_features
# 'compute_features' run time was 73.890228987 sec
# # of kernels = 60
# frequencies: [ 0.14142136  0.1         0.07071068  0.05        0.03535534]
# # of pixels per cycle: [  7.07106781  10.          14.14213562  20.          28.28427125]
# ==== do_gabor_filter Timing ====
# filtered images saved to /home/yuncong/my_csd181_scratch/PMD1305_247.reduce2.region1_filtered
# filtering completes
# 'do_gabor_filter' run time was 21.564924002 sec
# ==== compute_features Timing ====
# 32 features selected
# features saved to /home/yuncong/my_csd181_scratch/PMD1305_247.reduce2.region1_features
# 'compute_features' run time was 77.629153967 sec
# # of kernels = 60
# frequencies: [ 0.14142136  0.1         0.07071068  0.05        0.03535534]
# # of pixels per cycle: [  7.07106781  10.          14.14213562  20.          28.28427125]
# ==== do_gabor_filter Timing ====
# filtered images saved to /home/yuncong/my_csd181_scratch/PMD1305_248.reduce2.region1_filtered
# filtering completes
# 'do_gabor_filter' run time was 24.005906105 sec
# ==== compute_features Timing ====
# 32 features selected
# features saved to /home/yuncong/my_csd181_scratch/PMD1305_248.reduce2.region1_features
# 'compute_features' run time was 81.817692041 sec
# # of kernels = 60
# frequencies: [ 0.14142136  0.1         0.07071068  0.05        0.03535534]
# # of pixels per cycle: [  7.07106781  10.          14.14213562  20.          28.28427125]
# ==== do_gabor_filter Timing ====
# filtered images saved to /home/yuncong/my_csd181_scratch/PMD1305_249.reduce2.region1_filtered
# filtering completes
# 'do_gabor_filter' run time was 13.952374935 sec
# ==== compute_features Timing ====
# 32 features selected
# features saved to /home/yuncong/my_csd181_scratch/PMD1305_249.reduce2.region1_features
# 'compute_features' run time was 101.556287050 sec

# %%
img_id = 244
img_name = 'PMD1305_%d.reduce2.region1'%img_id
CACHE_DIR = '/home/yuncong/my_csd181_scratch/'
IMG_DIR = '/home/yuncong/my_csd181/ParthaData/PMD1305_reduce2/region1/'

sd = SaliencyDetector(img, CACHE_DIR + img_name +'_features.npy')
sd.compute_texton(num_textons=10)
sd.segment_superpixels(compactness=5)
sd.compute_connectivity()
sd.compute_distance_matrix()
sd.compute_saliency_map()
sd.find_salient_clusters(dist_thresh=.5)

# %%
sd.visualize_features()

# %%
sd.visualize_textonmap_superpixels(output='ts1.jpg')
Image('ts1.jpg')

# %%
sd.visualize_saliency_map()

# %%
sd.visualize_salient_clusters(output='sel.jpg')
Image('sel.jpg')

# %%
FileLink('sel.jpg')
