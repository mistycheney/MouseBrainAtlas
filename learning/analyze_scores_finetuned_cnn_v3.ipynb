# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import time

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

sys.path.append(os.environ['REPO_DIR'] + '/utilities')
from utilities2015 import *
from metadata import *
from data_manager import *
from learning_utilities import *
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# No vtk
# Setting environment for AWS compute node

# %%
model_dir_name = 'inception-bn-blue-softmax'
download_from_s3(os.path.join(MXNET_MODEL_ROOTDIR, model_dir_name), is_dir=True)

model_name = 'inception-bn-blue-softmax'

# %%
structure = 'IC'

prefix = os.path.join(MXNET_MODEL_ROOTDIR, model_dir_name, model_name + '_' + structure)

metric_history_fp = prefix + '_evalMetricHistory.pkl'
download_from_s3(metric_history_fp)

eval_metric_history = load_pickle(metric_history_fp)

plt.plot(eval_metric_history['accuracy'], label='test_acc');
plt.title('Evaluation Metrics');
plt.xlabel('Iteration');
plt.ylabel('Accuracy');
plt.legend();
