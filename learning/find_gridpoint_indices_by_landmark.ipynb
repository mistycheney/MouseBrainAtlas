# %%
# %reload_ext autoreload
# %autoreload 2

import cv2

import os
import sys
sys.path.append(os.path.join(os.environ['REPO_DIR'], 'utilities'))
from utilities2015 import *

from collections import defaultdict

from matplotlib.path import Path
# %matplotlib inline

# %%
stack = 'MD589'
# stack = 'MD594'
first, last = section_range_lookup[stack]

# %%
patch_size = 224
half_size = patch_size/2
stride = 56

dm = DataManager(stack=stack, load_mask=False)

w = dm.image_width
h = dm.image_height 

ys, xs = np.meshgrid(np.arange(half_size, h-half_size, stride), np.arange(half_size, w-half_size, stride),
                     indexing='xy')
    
sample_locations = np.c_[xs.flat, ys.flat]

# %%
# Generate a summary file of label polygons

# label_polygons = defaultdict(lambda: {})
# for sec, dm in dms.iteritems():
#     res = dm.load_proposal_review_result(None, 'latest', 'consolidated')
#     if res is None:
#         continue
#     usr, ts, suffix, result = res
#     for props in result:
#         label_polygons[props['label']][sec] = props['vertices']
# label_polygon.default_factory = None

# pickle.dump(label_polygons, open(os.environ['REPO_DIR']+'/database/'+stack+'_label_polygons.pkl', 'w'))

# %%
# Load label polygons summary
import pandas as pd
label_polygons = pd.read_hdf('/home/yuncong/Brain/database/'+stack+'_label_polygons.h5', 'label_polygons')
# labels_to_collect = ['5N', '7n', '7N', '12N', 'Gr', 'LVe', 'Pn', 'SuVe', 'VLL']

labels_to_collect = ['5N', '7n', '7N', '12N', 'Gr', 'LVe', 'Pn', 'SuVe', 'VLL', 
                     '6N', 'Amb', 'R', 'Tz', 'Sol', 'RtTg', 'LRt', 'LC', 'AP', 'sp5']

assert set(labels_to_collect).issubset(set(label_polygons.keys()))

# %%
label_polygons
# Out:
#      10N  12N   3N   4N                                                 5N  \
# 110  NaN  NaN  NaN  NaN                                                NaN
# 111  NaN  NaN  NaN  NaN                                                NaN
# 113  NaN  NaN  NaN  NaN                                                NaN
# 115  NaN  NaN  NaN  NaN                                                NaN
# 117  NaN  NaN  NaN  NaN                                                NaN
# 119  NaN  NaN  NaN  NaN                                                NaN
# 121  NaN  NaN  NaN  NaN                                                NaN
# 123  NaN  NaN  NaN  NaN                                                NaN
# 125  NaN  NaN  NaN  NaN                                                NaN
# 127  NaN  NaN  NaN  NaN                                                NaN
# 129  NaN  NaN  NaN  NaN                                                NaN
# 131  NaN  NaN  NaN  NaN                                                NaN
# 133  NaN  NaN  NaN  NaN                                                NaN
# 135  NaN  NaN  NaN  NaN                                                NaN
# 137  NaN  NaN  NaN  NaN                                                NaN
# 139  NaN  NaN  NaN  NaN                                                NaN
# 141  NaN  NaN  NaN  NaN                                                NaN
# 143  NaN  NaN  NaN  NaN                                                NaN
# 145  NaN  NaN  NaN  NaN                                                NaN
# 147  NaN  NaN  NaN  NaN                                                NaN
# 149  NaN  NaN  NaN  NaN                                                NaN
# 150  NaN  NaN  NaN  NaN  [[3920, 7864], [3869, 7667], [3794, 7569], [36...
# 151  NaN  NaN  NaN  NaN  [[3759, 7277], [3926, 7120], [4120, 7044], [44...
# 152  NaN  NaN  NaN  NaN  [[4184, 7041], [4290, 7139], [4412, 7304], [43...
# 153  NaN  NaN  NaN  NaN  [[3935, 7036], [3761, 7120], [3645, 7285], [35...
# 154  NaN  NaN  NaN  NaN  [[3730, 7114], [3903, 7098], [4104, 7082], [42...
# 155  NaN  NaN  NaN  NaN  [[4064, 8535], [4258, 8514], [4358, 8198], [43...
# 156  NaN  NaN  NaN  NaN  [[3660, 7293], [3763, 7215], [3830, 7112], [40...
# 157  NaN  NaN  NaN  NaN  [[3658, 8430], [3556, 8124], [3534, 7798], [36...
# 158  NaN  NaN  NaN  NaN  [[3561, 7343], [3795, 7277], [3915, 7223], [41...
# ..   ...  ...  ...  ...                                                ...
# 305  NaN  NaN  NaN  NaN                                                NaN
# 306  NaN  NaN  NaN  NaN  [[3934, 8136], [4148, 8004], [4335, 7838], [43...
# 307  NaN  NaN  NaN  NaN  [[4157, 7230], [4117, 7444], [4039, 7580], [40...
# 308  NaN  NaN  NaN  NaN  [[4032, 7698], [4005, 7529], [4022, 7336], [40...
# 309  NaN  NaN  NaN  NaN  [[3199, 7091], [3339, 6952], [3486, 6838], [37...
# 310  NaN  NaN  NaN  NaN  [[4064, 6586], [4058, 6769], [4106, 6920], [41...
# 311  NaN  NaN  NaN  NaN  [[3611, 6577], [3677, 6695], [3703, 6787], [37...
# 312  NaN  NaN  NaN  NaN  [[3229, 6808], [3346, 6730], [3431, 6751], [35...
# 313  NaN  NaN  NaN  NaN                                                NaN
# 314  NaN  NaN  NaN  NaN                                                NaN
# 315  NaN  NaN  NaN  NaN                                                NaN
# 316  NaN  NaN  NaN  NaN                                                NaN
# 318  NaN  NaN  NaN  NaN                                                NaN
# 320  NaN  NaN  NaN  NaN                                                NaN
# 322  NaN  NaN  NaN  NaN                                                NaN
# 323  NaN  NaN  NaN  NaN                                                NaN
# 325  NaN  NaN  NaN  NaN                                                NaN
# 327  NaN  NaN  NaN  NaN                                                NaN
# 329  NaN  NaN  NaN  NaN                                                NaN
# 331  NaN  NaN  NaN  NaN                                                NaN
# 333  NaN  NaN  NaN  NaN                                                NaN
# 335  NaN  NaN  NaN  NaN                                                NaN
# 337  NaN  NaN  NaN  NaN                                                NaN
# 339  NaN  NaN  NaN  NaN                                                NaN
# 341  NaN  NaN  NaN  NaN                                                NaN
# 343  NaN  NaN  NaN  NaN                                                NaN
# 345  NaN  NaN  NaN  NaN                                                NaN
# 347  NaN  NaN  NaN  NaN                                                NaN
# 349  NaN  NaN  NaN  NaN                                                NaN
# 351  NaN  NaN  NaN  NaN                                                NaN
#
#                                                    5TT   6N  \
# 110                                                NaN  NaN
# 111                                                NaN  NaN
# 113                                                NaN  NaN
# 115                                                NaN  NaN
# 117                                                NaN  NaN
# 119                                                NaN  NaN
# 121                                                NaN  NaN
# 123                                                NaN  NaN
# 125                                                NaN  NaN
# 127                                                NaN  NaN
# 129                                                NaN  NaN
# 131                                                NaN  NaN
# 133                                                NaN  NaN
# 135                                                NaN  NaN
# 137                                                NaN  NaN
# 139                                                NaN  NaN
# 141                                                NaN  NaN
# 143                                                NaN  NaN
# 145                                                NaN  NaN
# 147                                                NaN  NaN
# 149                                                NaN  NaN
# 150  [[3545, 8271], [3676, 8232], [3850, 8229], [40...  NaN
# 151  [[3742, 7902], [3995, 7935], [4170, 8066], [42...  NaN
# 152  [[3973, 8006], [4080, 8091], [4221, 8239], [43...  NaN
# 153                                                NaN  NaN
# 154                                                NaN  NaN
# 155                                                NaN  NaN
# 156                                                NaN  NaN
# 157                                                NaN  NaN
# 158                                                NaN  NaN
# ..                                                 ...  ...
# 305                                                NaN  NaN
# 306                                                NaN  NaN
# 307                                                NaN  NaN
# 308                                                NaN  NaN
# 309                                                NaN  NaN
# 310                                                NaN  NaN
# 311                                                NaN  NaN
# 312                                                NaN  NaN
# 313                                                NaN  NaN
# 314                                                NaN  NaN
# 315                                                NaN  NaN
# 316                                                NaN  NaN
# 318                                                NaN  NaN
# 320                                                NaN  NaN
# 322                                                NaN  NaN
# 323                                                NaN  NaN
# 325                                                NaN  NaN
# 327                                                NaN  NaN
# 329                                                NaN  NaN
# 331                                                NaN  NaN
# 333                                                NaN  NaN
# 335                                                NaN  NaN
# 337                                                NaN  NaN
# 339                                                NaN  NaN
# 341                                                NaN  NaN
# 343                                                NaN  NaN
# 345                                                NaN  NaN
# 347                                                NaN  NaN
# 349                                                NaN  NaN
# 351                                                NaN  NaN
#
#                                                     7N  \
# 110                                                NaN
# 111                                                NaN
# 113                                                NaN
# 115                                                NaN
# 117                                                NaN
# 119                                                NaN
# 121                                                NaN
# 123                                                NaN
# 125                                                NaN
# 127                                                NaN
# 129                                                NaN
# 131                                                NaN
# 133                                                NaN
# 135                                                NaN
# 137                                                NaN
# 139                                                NaN
# 141                                                NaN
# 143                                                NaN
# 145                                                NaN
# 147                                                NaN
# 149                                                NaN
# 150                                                NaN
# 151                                                NaN
# 152  [[5724, 10339], [5592, 10277], [5518, 10194], ...
# 153  [[5915, 10004], [6149, 10057], [6353, 10177], ...
# 154  [[5888, 10541], [5665, 10474], [5516, 10393], ...
# 155  [[5607, 10462], [5890, 10506], [6188, 10501], ...
# 156  [[5301, 10043], [5392, 10015], [5522, 9984], [...
# 157  [[5494, 10392], [5368, 10460], [5213, 10274], ...
# 158  [[5694, 9867], [5899, 9858], [6122, 9876], [62...
# ..                                                 ...
# 305  [[5191, 10152], [5065, 10062], [4915, 9948], [...
# 306  [[4992, 10027], [4894, 9811], [4728, 9600], [4...
# 307  [[5195, 10018], [5082, 9982], [5000, 9926], [4...
# 308  [[5632, 10128], [5378, 10083], [5109, 9958], [...
# 309  [[5127, 9702], [5212, 9642], [5375, 9642], [55...
# 310  [[5681, 9980], [5914, 10030], [6142, 10062], [...
# 311  [[5526, 9475], [5608, 9493], [5693, 9488], [58...
# 312  [[5492, 9478], [5778, 9464], [6172, 9455], [64...
# 313  [[5380, 9503], [5522, 9507], [5638, 9535], [57...
# 314  [[5529, 9545], [5740, 9514], [5907, 9477], [61...
# 315  [[5722, 9773], [5637, 9734], [5598, 9709], [55...
# 316  [[5605, 9614], [5673, 9535], [5851, 9499], [59...
# 318                                                NaN
# 320                                                NaN
# 322                                                NaN
# 323                                                NaN
# 325                                                NaN
# 327                                                NaN
# 329                                                NaN
# 331                                                NaN
# 333                                                NaN
# 335                                                NaN
# 337                                                NaN
# 339                                                NaN
# 341                                                NaN
# 343                                                NaN
# 345                                                NaN
# 347                                                NaN
# 349                                                NaN
# 351                                                NaN
#
#                                                     7n   9N ...   \
# 110                                                NaN  NaN ...
# 111                                                NaN  NaN ...
# 113                                                NaN  NaN ...
# 115                                                NaN  NaN ...
# 117                                                NaN  NaN ...
# 119                                                NaN  NaN ...
# 121                                                NaN  NaN ...
# 123                                                NaN  NaN ...
# 125                                                NaN  NaN ...
# 127                                                NaN  NaN ...
# 129                                                NaN  NaN ...
# 131                                                NaN  NaN ...
# 133                                                NaN  NaN ...
# 135                                                NaN  NaN ...
# 137                                                NaN  NaN ...
# 139                                                NaN  NaN ...
# 141                                                NaN  NaN ...
# 143                                                NaN  NaN ...
# 145                                                NaN  NaN ...
# 147                                                NaN  NaN ...
# 149  [[3959, 10068], [3797, 9942], [3744, 9802], [3...  NaN ...
# 150  [[3963, 10012], [3779, 9942], [3670, 9854], [3...  NaN ...
# 151  [[4011, 9948], [3829, 9846], [3740, 9747], [37...  NaN ...
# 152  [[4094, 10060], [3900, 9970], [3813, 9881], [3...  NaN ...
# 153  [[3978, 9609], [4226, 9564], [4453, 9633], [45...  NaN ...
# 154  [[3950, 9605], [4177, 9566], [4400, 9592], [45...  NaN ...
# 155  [[4092, 9572], [4305, 9517], [4514, 9564], [46...  NaN ...
# 156  [[4044, 9529], [4213, 9466], [4469, 9450], [45...  NaN ...
# 157  [[4211, 9458], [4398, 9357], [4590, 9321], [47...  NaN ...
# 158  [[4069, 9505], [4178, 9413], [4379, 9339], [45...  NaN ...
# ..                                                 ...  ... ...
# 305  [[4357, 9265], [4183, 9253], [4075, 9163], [40...  NaN ...
# 306  [[4022, 8988], [4011, 9079], [4124, 9231], [42...  NaN ...
# 307  [[4091, 9280], [4011, 9241], [3967, 9139], [40...  NaN ...
# 308  [[4107, 9024], [4300, 8982], [4528, 8994], [46...  NaN ...
# 309  [[4161, 9355], [4090, 9326], [3970, 9291], [38...  NaN ...
# 310  [[3923, 9102], [4096, 9065], [4236, 9088], [44...  NaN ...
# 311  [[4202, 9128], [4346, 9091], [4398, 9099], [45...  NaN ...
# 312  [[3855, 9179], [4022, 9133], [4282, 9161], [44...  NaN ...
# 313  [[4176, 9188], [4382, 9138], [4505, 9163], [46...  NaN ...
# 314  [[3975, 9173], [4144, 9193], [4334, 9213], [44...  NaN ...
# 315  [[4117, 9450], [3937, 9387], [3845, 9270], [38...  NaN ...
# 316  [[3880, 9230], [4063, 9222], [4299, 9225], [44...  NaN ...
# 318                                                NaN  NaN ...
# 320                                                NaN  NaN ...
# 322                                                NaN  NaN ...
# 323                                                NaN  NaN ...
# 325                                                NaN  NaN ...
# 327                                                NaN  NaN ...
# 329                                                NaN  NaN ...
# 331                                                NaN  NaN ...
# 333                                                NaN  NaN ...
# 335                                                NaN  NaN ...
# 337                                                NaN  NaN ...
# 339                                                NaN  NaN ...
# 341                                                NaN  NaN ...
# 343                                                NaN  NaN ...
# 345                                                NaN  NaN ...
# 347                                                NaN  NaN ...
# 349                                                NaN  NaN ...
# 351                                                NaN  NaN ...
#
#                                                   VOri  \
# 110                                                NaN
# 111                                                NaN
# 113                                                NaN
# 115                                                NaN
# 117                                                NaN
# 119                                                NaN
# 121                                                NaN
# 123                                                NaN
# 125                                                NaN
# 127                                                NaN
# 129                                                NaN
# 131  [[7331, 8579], [7195, 8604], [7147, 8706], [71...
# 133                                                NaN
# 135                                                NaN
# 137                                                NaN
# 139                                                NaN
# 141                                                NaN
# 143                                                NaN
# 145                                                NaN
# 147                                                NaN
# 149                                                NaN
# 150                                                NaN
# 151                                                NaN
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
# 157                                                NaN
# 158                                                NaN
# ..                                                 ...
# 305                                                NaN
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
# 310                                                NaN
# 311                                                NaN
# 312                                                NaN
# 313                                                NaN
# 314                                                NaN
# 315                                                NaN
# 316                                                NaN
# 318                                                NaN
# 320                                                NaN
# 322                                                NaN
# 323                                                NaN
# 325                                                NaN
# 327                                                NaN
# 329                                                NaN
# 331                                                NaN
# 333                                                NaN
# 335                                                NaN
# 337                                                NaN
# 339                                                NaN
# 341                                                NaN
# 343                                                NaN
# 345                                                NaN
# 347                                                NaN
# 349                                                NaN
# 351                                                NaN
#
#                                                   VOrp  VTg  \
# 110                                                NaN  NaN
# 111                                                NaN  NaN
# 113                                                NaN  NaN
# 115                                                NaN  NaN
# 117  [[8477, 8197], [8354, 8311], [8235, 8491], [82...  NaN
# 119  [[8439, 8194], [8328, 8246], [8188, 8396], [81...  NaN
# 121  [[8414, 8181], [8244, 8277], [8117, 8378], [80...  NaN
# 123  [[7813, 8961], [7792, 8795], [7841, 8628], [79...  NaN
# 125                                                NaN  NaN
# 127                                                NaN  NaN
# 129                                                NaN  NaN
# 131  [[7604, 8768], [7622, 8520], [7777, 8291], [80...  NaN
# 133                                                NaN  NaN
# 135                                                NaN  NaN
# 137                                                NaN  NaN
# 139                                                NaN  NaN
# 141                                                NaN  NaN
# 143                                                NaN  NaN
# 145                                                NaN  NaN
# 147                                                NaN  NaN
# 149                                                NaN  NaN
# 150                                                NaN  NaN
# 151                                                NaN  NaN
# 152                                                NaN  NaN
# 153                                                NaN  NaN
# 154                                                NaN  NaN
# 155                                                NaN  NaN
# 156                                                NaN  NaN
# 157                                                NaN  NaN
# 158                                                NaN  NaN
# ..                                                 ...  ...
# 305                                                NaN  NaN
# 306                                                NaN  NaN
# 307                                                NaN  NaN
# 308                                                NaN  NaN
# 309                                                NaN  NaN
# 310                                                NaN  NaN
# 311                                                NaN  NaN
# 312                                                NaN  NaN
# 313                                                NaN  NaN
# 314                                                NaN  NaN
# 315                                                NaN  NaN
# 316                                                NaN  NaN
# 318                                                NaN  NaN
# 320                                                NaN  NaN
# 322                                                NaN  NaN
# 323                                                NaN  NaN
# 325                                                NaN  NaN
# 327                                                NaN  NaN
# 329                                                NaN  NaN
# 331                                                NaN  NaN
# 333                                                NaN  NaN
# 335                                                NaN  NaN
# 337                                                NaN  NaN
# 339                                                NaN  NaN
# 341                                                NaN  NaN
# 343                                                NaN  NaN
# 345                                                NaN  NaN
# 347                                                NaN  NaN
# 349                                                NaN  NaN
# 351                                                NaN  NaN
#
#                                                    Vcd dtgx  mlf  pyx  scp  \
# 110                                                NaN  NaN  NaN  NaN  NaN
# 111                                                NaN  NaN  NaN  NaN  NaN
# 113                                                NaN  NaN  NaN  NaN  NaN
# 115                                                NaN  NaN  NaN  NaN  NaN
# 117                                                NaN  NaN  NaN  NaN  NaN
# 119                                                NaN  NaN  NaN  NaN  NaN
# 121                                                NaN  NaN  NaN  NaN  NaN
# 123                                                NaN  NaN  NaN  NaN  NaN
# 125                                                NaN  NaN  NaN  NaN  NaN
# 127                                                NaN  NaN  NaN  NaN  NaN
# 129  [[9460, 8010], [9561, 7941], [9717, 7984], [98...  NaN  NaN  NaN  NaN
# 131  [[9573, 7969], [9724, 7959], [9864, 7988], [99...  NaN  NaN  NaN  NaN
# 133                                                NaN  NaN  NaN  NaN  NaN
# 135                                                NaN  NaN  NaN  NaN  NaN
# 137                                                NaN  NaN  NaN  NaN  NaN
# 139                                                NaN  NaN  NaN  NaN  NaN
# 141                                                NaN  NaN  NaN  NaN  NaN
# 143                                                NaN  NaN  NaN  NaN  NaN
# 145                                                NaN  NaN  NaN  NaN  NaN
# 147                                                NaN  NaN  NaN  NaN  NaN
# 149                                                NaN  NaN  NaN  NaN  NaN
# 150                                                NaN  NaN  NaN  NaN  NaN
# 151                                                NaN  NaN  NaN  NaN  NaN
# 152                                                NaN  NaN  NaN  NaN  NaN
# 153                                                NaN  NaN  NaN  NaN  NaN
# 154                                                NaN  NaN  NaN  NaN  NaN
# 155                                                NaN  NaN  NaN  NaN  NaN
# 156                                                NaN  NaN  NaN  NaN  NaN
# 157  [[9872, 10276], [10191, 10404], [10471, 10477]...  NaN  NaN  NaN  NaN
# 158                                                NaN  NaN  NaN  NaN  NaN
# ..                                                 ...  ...  ...  ...  ...
# 305                                                NaN  NaN  NaN  NaN  NaN
# 306                                                NaN  NaN  NaN  NaN  NaN
# 307                                                NaN  NaN  NaN  NaN  NaN
# 308                                                NaN  NaN  NaN  NaN  NaN
# 309                                                NaN  NaN  NaN  NaN  NaN
# 310                                                NaN  NaN  NaN  NaN  NaN
# 311                                                NaN  NaN  NaN  NaN  NaN
# 312                                                NaN  NaN  NaN  NaN  NaN
# 313                                                NaN  NaN  NaN  NaN  NaN
# 314                                                NaN  NaN  NaN  NaN  NaN
# 315                                                NaN  NaN  NaN  NaN  NaN
# 316                                                NaN  NaN  NaN  NaN  NaN
# 318                                                NaN  NaN  NaN  NaN  NaN
# 320                                                NaN  NaN  NaN  NaN  NaN
# 322                                                NaN  NaN  NaN  NaN  NaN
# 323                                                NaN  NaN  NaN  NaN  NaN
# 325                                                NaN  NaN  NaN  NaN  NaN
# 327                                                NaN  NaN  NaN  NaN  NaN
# 329                                                NaN  NaN  NaN  NaN  NaN
# 331                                                NaN  NaN  NaN  NaN  NaN
# 333                                                NaN  NaN  NaN  NaN  NaN
# 335                                                NaN  NaN  NaN  NaN  NaN
# 337                                                NaN  NaN  NaN  NaN  NaN
# 339                                                NaN  NaN  NaN  NaN  NaN
# 341                                                NaN  NaN  NaN  NaN  NaN
# 343                                                NaN  NaN  NaN  NaN  NaN
# 345                                                NaN  NaN  NaN  NaN  NaN
# 347                                                NaN  NaN  NaN  NaN  NaN
# 349                                                NaN  NaN  NaN  NaN  NaN
# 351                                                NaN  NaN  NaN  NaN  NaN
#
#                                                    sp5 vtgx
# 110                                                NaN  NaN
# 111                                                NaN  NaN
# 113                                                NaN  NaN
# 115                                                NaN  NaN
# 117                                                NaN  NaN
# 119                                                NaN  NaN
# 121                                                NaN  NaN
# 123                                                NaN  NaN
# 125                                                NaN  NaN
# 127                                                NaN  NaN
# 129                                                NaN  NaN
# 131  [[10009, 7741], [10223, 7953], [10286, 8216], ...  NaN
# 133  [[10010, 7685], [10285, 7978], [10327, 8161], ...  NaN
# 135  [[9638, 7547], [9858, 7509], [10068, 7591], [1...  NaN
# 137  [[9789, 7518], [10178, 7667], [10342, 7955], [...  NaN
# 139  [[10306, 7747], [10541, 8092], [10613, 8315], ...  NaN
# 141  [[5687, 7840], [6172, 7973], [6556, 8039], [68...  NaN
# 143  [[6579, 7766], [6752, 7637], [7034, 7526], [74...  NaN
# 145  [[10429, 7658], [10644, 8045], [10709, 8321], ...  NaN
# 147  [[7533, 7490], [7608, 7435], [7862, 7363], [83...  NaN
# 149  [[7672, 7472], [8017, 7347], [8518, 7280], [90...  NaN
# 150                                                NaN  NaN
# 151  [[8336, 7364], [8848, 7253], [9232, 7279], [96...  NaN
# 152                                                NaN  NaN
# 153  [[8563, 7366], [8969, 7341], [9205, 7238], [95...  NaN
# 154  [[8426, 7433], [8840, 7333], [9266, 7308], [96...  NaN
# 155  [[8923, 7422], [9354, 7350], [9591, 7293], [99...  NaN
# 156  [[8871, 7426], [9301, 7390], [9630, 7390], [10...  NaN
# 157  [[9501, 7296], [9919, 7384], [10247, 7529], [1...  NaN
# 158  [[8870, 7598], [9429, 7567], [9875, 7598], [10...  NaN
# ..                                                 ...  ...
# 305                                                NaN  NaN
# 306  [[7974, 6662], [8448, 6675], [8899, 6813], [92...  NaN
# 307                                                NaN  NaN
# 308  [[7707, 6697], [8134, 6689], [8398, 6660], [88...  NaN
# 309                                                NaN  NaN
# 310  [[10086, 7169], [10289, 7581], [10410, 7797], ...  NaN
# 311                                                NaN  NaN
# 312  [[9306, 6880], [9577, 7038], [9807, 7096], [10...  NaN
# 313                                                NaN  NaN
# 314  [[9142, 6828], [9457, 6880], [9547, 6982], [98...  NaN
# 315                                                NaN  NaN
# 316  [[5911, 7286], [6286, 7440], [7026, 7396], [75...  NaN
# 318  [[5791, 7363], [6228, 7556], [6629, 7572], [70...  NaN
# 320  [[5950, 7832], [6646, 7811], [7136, 7663], [76...  NaN
# 322  [[5374, 7437], [5759, 7742], [6109, 7859], [68...  NaN
# 323  [[3355, 8667], [3739, 8903], [4249, 9018], [50...  NaN
# 325  [[9455, 7547], [9782, 8106], [9850, 8546], [97...  NaN
# 327  [[9589, 7770], [9737, 8176], [9801, 8595], [97...  NaN
# 329                                                NaN  NaN
# 331                                                NaN  NaN
# 333                                                NaN  NaN
# 335                                                NaN  NaN
# 337                                                NaN  NaN
# 339                                                NaN  NaN
# 341                                                NaN  NaN
# 343                                                NaN  NaN
# 345                                                NaN  NaN
# 347                                                NaN  NaN
# 349                                                NaN  NaN
# 351                                                NaN  NaN
#
# [206 rows x 60 columns]

# %%
label_polygons.keys()
# Out:
# Index([u'10N', u'12N', u'3N', u'4N', u'5N', u'5TT', u'6N', u'7N', u'7n', u'9N',
#        u'AP', u'Amb', u'CC', u'CereNuc', u'DC', u'DTgP', u'Gr', u'IO', u'LC',
#        u'LDTg', u'LM1C', u'LM1R', u'LRt', u'LSO', u'LVe', u'MVe', u'MVePC',
#        u'Nuc1', u'Pn', u'PnO', u'Pr5', u'Pr5DM', u'Pr5VL', u'PrVd', u'PrVv',
#        u'R', u'RtTg', u'Sol', u'Sp5C', u'Sp5I', u'Sp5O', u'SuVe', u'Tz',
#        u'UDF', u'VCA', u'VCP', u'VIpp', u'VLL', u'VMu', u'VOra', u'VOri',
#        u'VOrp', u'VTg', u'Vcd', u'dtgx', u'mlf', u'pyx', u'scp', u'sp5',
#        u'vtgx'],
#       dtype='object')

# %%
section_contains_labels = defaultdict(set)
for l in label_polygons.keys():
    for s in label_polygons[l].dropna().index:
        section_contains_labels[s].add(l)
section_contains_labels.default_factory = None

# %%
from shapely.geometry import Polygon, Point
from shapely.ops import cascaded_union

# %%
margin = int(.3*half_size)

sample_locations_ul = sample_locations - (margin, margin)
sample_locations_ur = sample_locations - (-margin, margin)
sample_locations_ll = sample_locations - (margin, -margin)
sample_locations_lr = sample_locations - (-margin, -margin)

# %%
indices_allLandmarks_allSections = defaultdict(dict)

for sec, labels in section_contains_labels.iteritems():

    print sec

    labs = set(labels) & set(labels_to_collect)

    if len(labs) == 0:
        continue

    dm = DataManager(stack=stack, section=sec, segm_params_id='tSLIC200', load_mask=False)

    mask = dm.load_thumbnail_mask()
    indices_fg = np.where(mask[sample_locations[:,1]/32, sample_locations[:,0]/32])[0]
    indices_bg = np.setdiff1d(range(sample_locations.shape[0]), indices_fg)

    all_polygons = {}
    indices_inside = {}
    indices_surround = {}
    
    for label in labs:

        path = Path(label_polygons[label][sec])
        indices_inside[label] =  np.where(path.contains_points(sample_locations_ll) &\
                                          path.contains_points(sample_locations_lr) &\
                                          path.contains_points(sample_locations_ul) &\
                                          path.contains_points(sample_locations_ur))[0]

    indices_allInside = np.concatenate(indices_inside.values())
        
    for label in labs:
 
        surround = Polygon(label_polygons[label][sec]).buffer(500, resolution=2)

        path = Path(list(surround.exterior.coords))
        indices_sur =  np.where(path.contains_points(sample_locations_ll) &\
                                path.contains_points(sample_locations_lr) &\
                                path.contains_points(sample_locations_ul) &\
                                path.contains_points(sample_locations_ur))[0]

        indices_surround[label] = np.setdiff1d(indices_sur, np.r_[indices_bg, indices_allInside])
        
    for l, inds in indices_inside.iteritems():
        indices_allLandmarks_allSections[sec][l] = inds
    for l, inds in indices_surround.iteritems():
        indices_allLandmarks_allSections[sec][l+'_surround'] = inds
    indices_allLandmarks_allSections[sec]['bg'] = indices_bg

indices_allLandmarks_allSections.default_factory = None
# Out:
# 110
# 111
# 113
# 115
# 117
# 119
# 121
# 123
# 125
# 127
# 129
# 131
# 133
# 135
# 137
# 139
# 141
# 143
# 145
# 147
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 318
# 320
# 322
# 323
# 325
# 327
# 329
# 331
# 333
# 335
# 337
# 339
# 341
# 343
# 345
# 347
# 349
# 351

# %%
import pandas as pd
indices_allLandmarks_allSections_df = pd.DataFrame(indices_allLandmarks_allSections)

# %%
indices_allLandmarks_allSections_df
# Out:
#                                                              131  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [157, 158, 159, 160, 161, 162, 163, 164, 165, ...
# sp5            [9423, 9424, 9425, 9623, 9624, 9625, 9626, 962...
# sp5_surround   [7972, 7973, 8176, 8177, 8178, 8179, 8180, 838...
#
#                                                              133  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [156, 157, 158, 159, 160, 161, 162, 163, 164, ...
# sp5            [6524, 6525, 6726, 6727, 6728, 6729, 6730, 673...
# sp5_surround   [4670, 4870, 4871, 4872, 4873, 4874, 4875, 487...
#
#                                                              135  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [155, 156, 157, 158, 159, 160, 161, 162, 163, ...
# sp5            [6523, 6524, 6525, 6526, 6527, 6528, 6529, 672...
# sp5_surround   [4668, 4669, 4873, 4874, 4875, 5077, 5078, 507...
#
#                                                              137  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [154, 155, 156, 157, 158, 159, 160, 161, 162, ...
# sp5            [6320, 6321, 6322, 6323, 6525, 6526, 6527, 652...
# sp5_surround   [4464, 4668, 4669, 4873, 4874, 4875, 4886, 507...
#
#                                                              139  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [152, 153, 154, 155, 156, 157, 158, 159, 160, ...
# sp5            [5910, 5911, 6113, 6114, 6115, 6116, 6117, 611...
# sp5_surround   [4258, 4259, 4461, 4462, 4463, 4464, 4465, 466...
#
#                                                              141  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [153, 154, 155, 156, 157, 158, 159, 160, 161, ...
# sp5            [5908, 5909, 5910, 5911, 6111, 6112, 6113, 611...
# sp5_surround   [4052, 4053, 4054, 4055, 4056, 4057, 4058, 425...
#
#                                                              143  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [8363, 8364, 8365, 8366, 8367, 8368, 8369, 856...
# VLL_surround   [6508, 6509, 6510, 6511, 6512, 6513, 6514, 651...
# bg             [151, 152, 153, 154, 155, 156, 157, 158, 159, ...
# sp5            [9227, 9228, 9433, 9434, 9638, 9639, 9640, 964...
# sp5_surround   [7575, 7576, 7780, 7781, 7782, 7783, 7985, 798...
#
#                                                              145  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [9417, 9622, 9623, 9624, 9625, 9827, 9828, 982...
# VLL_surround   [8379, 8380, 8381, 8382, 8585, 8586, 8587, 858...
# bg             [151, 152, 153, 154, 155, 156, 157, 158, 159, ...
# sp5            [5501, 5502, 5503, 5504, 5505, 5506, 5507, 570...
# sp5_surround   [3848, 3849, 3850, 3851, 3852, 4051, 4052, 405...
#
#                                                              147  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [9212, 9213, 9214, 9418, 9419, 9420, 9421, 942...
# VLL_surround   [7357, 7358, 7359, 7360, 7361, 7559, 7560, 756...
# bg             [151, 152, 153, 154, 155, 156, 157, 158, 159, ...
# sp5            [27531, 27532, 27736, 27737, 27738, 27942, 279...
# sp5_surround   [25676, 25677, 25678, 25679, 25879, 25880, 258...
#
#                                                              149  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n             [13975, 13976, 13977, 14181, 14182, 14183, 141...
# 7n_surround    [12118, 12119, 12120, 12121, 12122, 12123, 121...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [7136, 7137, 7138, 7340, 7341, 7342, 7343, 734...
# VLL_surround   [5281, 5282, 5283, 5284, 5285, 5286, 5484, 548...
# bg             [150, 151, 152, 153, 154, 155, 156, 157, 158, ...
# sp5            [27943, 27944, 28148, 28149, 28150, 28354, 283...
# sp5_surround   [26088, 26089, 26090, 26292, 26293, 26294, 262...
#
#                                      ...                          \
# 12N                                  ...
# 12N_surround                         ...
# 5N                                   ...
# 5N_surround                          ...
# 6N                                   ...
# 6N_surround                          ...
# 7N                                   ...
# 7N_surround                          ...
# 7n                                   ...
# 7n_surround                          ...
# AP                                   ...
# AP_surround                          ...
# Amb                                  ...
# Amb_surround                         ...
# Gr                                   ...
# Gr_surround                          ...
# LC                                   ...
# LC_surround                          ...
# LRt                                  ...
# LRt_surround                         ...
# LVe                                  ...
# LVe_surround                         ...
# Pn                                   ...
# Pn_surround                          ...
# R                                    ...
# R_surround                           ...
# RtTg                                 ...
# RtTg_surround                        ...
# Sol                                  ...
# Sol_surround                         ...
# SuVe                                 ...
# SuVe_surround                        ...
# Tz                                   ...
# Tz_surround                          ...
# VLL                                  ...
# VLL_surround                         ...
# bg                                   ...
# sp5                                  ...
# sp5_surround                         ...
#
#                                                              313  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N             [19945, 20151, 20357, 20563, 20769, 20975, 211...
# 7N_surround    [18086, 18087, 18088, 18089, 18090, 18091, 180...
# 7n             [14170, 14171, 14376, 14377, 14378, 14582, 145...
# 7n_surround    [12314, 12315, 12316, 12317, 12318, 12519, 125...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [7739, 7740, 7741, 7742, 7743, 7944, 7945, 794...
# VLL_surround   [5883, 5884, 5885, 5886, 5887, 5888, 5889, 589...
# bg             [141, 142, 143, 144, 145, 146, 147, 148, 149, ...
# sp5                                                          NaN
# sp5_surround                                                 NaN
#
#                                                              314  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N             [19946, 20152, 20153, 20154, 20155, 20357, 203...
# 7N_surround    [18294, 18295, 18296, 18297, 18298, 18299, 183...
# 7n             [13965, 14171, 14172, 14377, 14378, 14583, 145...
# 7n_surround    [12108, 12109, 12110, 12111, 12313, 12314, 123...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [141, 142, 143, 144, 145, 146, 147, 148, 149, ...
# sp5            [22374, 22580, 22581, 22786, 22787, 22788, 229...
# sp5_surround   [20521, 20721, 20722, 20723, 20724, 20725, 207...
#
#                                                              315  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N             [20358, 20563, 20564, 20565, 20769, 20770, 207...
# 7N_surround    [18500, 18501, 18502, 18503, 18504, 18505, 185...
# 7n             [14171, 14377, 14378, 14379, 14584, 14585, 147...
# 7n_surround    [12316, 12317, 12318, 12319, 12519, 12520, 125...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [141, 142, 143, 144, 145, 146, 147, 148, 149, ...
# sp5                                                          NaN
# sp5_surround                                                 NaN
#
#                                                              316  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N             [20564, 20769, 20770, 20771, 20975, 20976, 209...
# 7N_surround    [18709, 18710, 18711, 18913, 18914, 18915, 189...
# 7n             [14378, 14584, 14585, 14790, 14791, 14792, 149...
# 7n_surround    [12521, 12522, 12523, 12524, 12525, 12526, 127...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [140, 141, 142, 143, 144, 145, 146, 147, 148, ...
# sp5            [21757, 21963, 21964, 22169, 22170, 22374, 223...
# sp5_surround   [19900, 19901, 19902, 19903, 19904, 19905, 199...
#
#                                                              318  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [140, 141, 142, 143, 144, 145, 146, 147, 148, ...
# sp5            [11489, 11490, 11491, 11492, 11694, 11695, 116...
# sp5_surround   [9635, 9636, 9839, 9840, 9841, 9842, 10044, 10...
#
#                                                              320  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [140, 141, 142, 143, 144, 145, 146, 147, 148, ...
# sp5            [11075, 11281, 11282, 11487, 11488, 11489, 116...
# sp5_surround   [9217, 9218, 9219, 9220, 9221, 9222, 9423, 942...
#
#                                                              322  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [140, 141, 142, 143, 144, 145, 146, 147, 148, ...
# sp5            [11486, 11487, 11690, 11691, 11692, 11693, 116...
# sp5_surround   [9632, 9833, 9834, 9835, 9836, 9837, 9838, 100...
#
#                                                              323  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [141, 142, 143, 144, 145, 146, 147, 148, 149, ...
# sp5            [11896, 11897, 11898, 11899, 11900, 12102, 121...
# sp5_surround   [10039, 10040, 10041, 10042, 10043, 10244, 102...
#
#                                                              325  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [141, 142, 143, 144, 145, 146, 147, 148, 149, ...
# sp5            [12103, 12104, 12308, 12309, 12310, 12311, 125...
# sp5_surround   [10452, 10656, 10657, 10658, 10860, 10861, 108...
#
#                                                              327
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# Gr                                                           NaN
# Gr_surround                                                  NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# LVe                                                          NaN
# LVe_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Sol                                                          NaN
# Sol_surround                                                 NaN
# SuVe                                                         NaN
# SuVe_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [142, 143, 144, 145, 146, 147, 148, 149, 150, ...
# sp5            [12718, 12721, 12722, 12924, 12925, 12926, 129...
# sp5_surround   [11065, 11066, 11270, 11271, 11272, 11475, 114...
#
# [39 rows x 183 columns]

# %%
patch_dir = '/oasis/projects/nsf/csd395/yuncong/CSHL_data_patches/'
table_filepath = os.path.join(patch_dir, '%(stack)s_indices_allLandmarks_allSections.h5'%{'stack':stack})
indices_allLandmarks_allSections_df.to_hdf(table_filepath, 'indices_allLandmarks_allSections')
pd.Series([patch_size, stride, w, h]).to_hdf(table_filepath, 'grid_parameters')
# Out:
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/pandas/core/generic.py:939: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->[131, 133, 135, 137, 139, 141, 143, 145, 147, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 318, 320, 322, 323, 325, 327]]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
