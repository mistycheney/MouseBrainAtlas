# %%
# %reload_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append(os.path.join(os.environ['REPO_DIR'], 'utilities'))
from utilities2015 import *

# %matplotlib inline

# This script is supposed to be run on the local machine

# %%
stack = 'MD594'
first_bs_sec, last_bs_sec = section_range_lookup[stack]

# %%
for sec in range(first_bs_sec, last_bs_sec + 1):
    print sec
    dm = DataManager(stack=stack, section=sec)
    try:        
        fn = dm.load_review_result_path('yuncong', 'latest', suffix='consolidated')[0]
        cmd = 'scp %(fn)s yuncong@gcn-20-33.sdsc.edu:/home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/%(stack)s/%(sec)04d'% \
        {'fn': fn, 'stack': stack, 'sec':sec}
        print cmd
#         os.system(cmd)
    except:
        continue
# Out:
# 93
# 94
# 95
# 96
# scp /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped/MD594/0096/MD594_0096_yuncong_01142016170154_consolidated.pkl yuncong@gcn-20-33.sdsc.edu:/home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD594/0096
# 97
# 98
# scp /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped/MD594/0098/MD594_0098_yuncong_01142016170154_consolidated.pkl yuncong@gcn-20-33.sdsc.edu:/home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD594/0098
# 99
# 100
# scp /oasis/projects/nsf/csd395/yuncong/CSHL_data_labelings_losslessAlignCropped/MD594/0100/MD594_0100_yuncong_01142016170154_consolidated.pkl yuncong@gcn-20-33.sdsc.edu:/home/yuncong/csd395/CSHL_data_labelings_losslessAlignCropped/MD594/0100
# 101
# 102
# ...
