# %%
import cv2

import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append('/home/yuncong/Brain/utilities/tifffile/')
import tifffile

import numpy as np

# %%
img = tifffile.imread('/home/yuncong/MD635-F58-2016.05.19-06.52.57_MD635_2_0173.tif')

# %%
img = img.astype(np.float)

# %%
img_normalized = (img-img.min())/(img.max()-img.min())

# %%
img_gamma = img_normalized ** (1/2.2)

# %%
plt.figure(figsize=(20,20));
plt.imshow(img_gamma[..., 2]);

# %%
cv2.imread()

# %%
from PIL import Image

img = Image.open('/home/yuncong/MD635-F58-2016.05.19-06.52.57_MD635_2_0173.tif')
data = np.array(img)

# %%
img = plt.imread('/home/yuncong/MD635-F58-2016.05.19-06.52.57_MD635_2_0173.tif')

# %%
img = cv2.imread('/home/yuncong/MD635-F58-2016.05.19-06.52.57_MD635_2_0173.tif')

# %%
plt.figure(figsize=(20,20));
plt.imshow(img[..., 0] == 0, cmap=plt.cm.gray);

# %%
plt.figure(figsize=(20,20));
plt.imshow(img[..., 0] == 1, cmap=plt.cm.gray);

# %%
plt.figure(figsize=(20,20));
plt.imshow(img[..., 0] == 2, cmap=plt.cm.gray);

# %%
plt.figure(figsize=(20,20));
plt.imshow(img[..., 1], cmap=plt.cm.gray, vmin=img[..., 1].min(), vmax=img[..., 1].max());

# %%
plt.figure(figsize=(20,20));
plt.imshow(img[..., 2], cmap=plt.cm.gray, vmin=img[..., 2].min(), vmax=img[..., 2].max());
