# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

import sys
import os

sys.path.append(os.environ['REPO_DIR'] + '/utilities')
from utilities2015 import *
from registration_utilities import parallel_where_binary, Aligner4
from data_manager import *
from metadata import *

import matplotlib.pyplot as plt
# %matplotlib inline

from joblib import Parallel, delayed
import time

from metadata import *
# Out:
# Setting environment for Gordon

# %%
stack_fixed = 'MD589'
stack_moving = 'MD594'

# %%
volume_fixed = bp.unpack_ndarray_file(os.path.join(VOLUME_ROOTDIR, '%(stack)s/%(stack)s_down32_annotationVolume.bp' % {'stack': stack_fixed}))
volume_moving = bp.unpack_ndarray_file(os.path.join(VOLUME_ROOTDIR, '%(stack)s/%(stack)s_down32_annotationVolume.bp' % {'stack': stack_moving}))
print volume_fixed.shape
print volume_moving.shape
# Out:
# (348, 421, 377)
# (326, 515, 368)

# %%
label_to_name_fixed = {}
name_to_label_fixed = {}

with open(os.path.join(VOLUME_ROOTDIR, stack_fixed, stack_fixed+'_down32_annotationVolume_nameToLabel.txt'), 'r') as f:
    for line in f.readlines():
        name_s, label = line.split()
        label_to_name_fixed[int(label)] = name_s
        name_to_label_fixed[name_s] = int(label)
        
with open(os.path.join(VOLUME_ROOTDIR, stack_fixed, stack_fixed+'_down32_annotationVolume_bbox.txt'), 'r') as f:
    vol_fixed_xmin, vol_fixed_xmax, vol_fixed_ymin, vol_fixed_ymax, vol_fixed_zmin, vol_fixed_zmax = map(int, f.readline().strip().split())

# %%
label_to_name_moving = {}
name_to_label_moving = {}

with open(os.path.join(VOLUME_ROOTDIR, stack_moving, stack_moving+'_down32_annotationVolume_nameToLabel.txt'), 'r') as f:
    for line in f.readlines():
        name_s, label = line.split()
        label_to_name_moving[int(label)] = name_s
        name_to_label_moving[name_s] = int(label)
        
with open(os.path.join(VOLUME_ROOTDIR, stack_moving, stack_moving+'_down32_annotationVolume_bbox.txt'), 'r') as f:
    vol_moving_xmin, vol_moving_xmax, vol_moving_ymin, vol_moving_ymax, vol_moving_zmin, vol_moving_zmax = map(int, f.readline().strip().split())

# %%
labelIndexMap_m2f = {}
for label_m, name_m in label_to_name_moving.iteritems():
    labelIndexMap_m2f[label_m] = name_to_label_fixed[name_m]

# %%
# aligner = Alizgner4(volume_fixed, volume_moving, labelIndexMap_m2f={37:37, 36:36})

# %%
aligner = Aligner4(volume_fixed, volume_moving, labelIndexMap_m2f=labelIndexMap_m2f)

# %%
aligner.set_centroid(centroid_m='volume_centroid', centroid_f='volume_centroid')
# aligner.set_centroid(centroid_m='structure_centroid', centroid_f='centroid_m', indices_m=[name_to_label_moving['SNR_R']])

# %%
gradient_filepath_map_f = {ind_f: VOLUME_ROOTDIR + '/%(stack)s/gradients/%(stack)s_down32_annotationVolume_%(label)s_%%(suffix)s.bp' % \
                           {'stack': stack_fixed, 'label': label_to_name_fixed[ind_f]}
                           for ind_m, ind_f in labelIndexMap_m2f.iteritems()}

# %%
aligner.load_gradient(gradient_filepath_map_f=gradient_filepath_map_f, indices_f=None)
# Out:
# load gradient 1: 0.324104 seconds
# load gradient 2: 0.322172 seconds
# load gradient 3: 0.463556 seconds
# load gradient 4: 0.446181 seconds
# load gradient 5: 0.354535 seconds
# load gradient 6: 0.328675 seconds
# load gradient 7: 0.337708 seconds
# load gradient 8: 0.345296 seconds
# load gradient 9: 0.391006 seconds
# load gradient 10: 0.335618 seconds
# load gradient 11: 0.329814 seconds
# load gradient 12: 0.306679 seconds
# load gradient 13: 0.375108 seconds
# load gradient 14: 0.331948 seconds
# load gradient 15: 0.333031 seconds
# load gradient 16: 0.381058 seconds
# load gradient 17: 0.423382 seconds
# load gradient 18: 0.387658 seconds
# load gradient 19: 0.480414 seconds
# load gradient 20: 0.411454 seconds
# load gradient 21: 0.379928 seconds
# load gradient 22: 0.259766 seconds
# load gradient 23: 0.306557 seconds
# load gradient 24: 0.284285 seconds
# load gradient 25: 0.310948 seconds
# load gradient 26: 0.318510 seconds
# load gradient 27: 0.316717 seconds
# load gradient 28: 0.312995 seconds
# load gradient 29: 0.299808 seconds
# load gradient 30: 0.355444 seconds
# load gradient 31: 0.356042 seconds
# load gradient 32: 0.415412 seconds
# load gradient 33: 0.427650 seconds
# load gradient 34: 0.355787 seconds
# load gradient 35: 0.456565 seconds
# load gradient 36: 0.401439 seconds
# load gradient 37: 0.380084 seconds
# load gradient 38: 0.398877 seconds
# load gradient 39: 0.419086 seconds
# load gradient 40: 0.336232 seconds
# load gradient 41: 0.284478 seconds
# load gradient 42: 0.427205 seconds
# load gradient 43: 0.348181 seconds
# load gradient 44: 0.345111 seconds
# load gradient 45: 0.350178 seconds
# load gradient 46: 0.286685 seconds
# load gradient 47: 0.343329 seconds
# load gradient 48: 0.285039 seconds
# load gradient 49: 0.301731 seconds
# load gradient 50: 0.338622 seconds
# load gradient 51: 0.287398 seconds
# overall: 18.120865 seconds

# %%
# aligner.load_gradient(gradient_filepath_map_f=gradient_filepath_map_f, indices_f=[name_to_label_fixed['5N_L'],
#                                                                                  name_to_label_fixed['5N_R'],
#                                                                                  name_to_label_fixed['12N'],
#                                                                                   name_to_label_fixed['SNR_L'],
#                                        name_to_label_fixed['SNR_R']])

# %%
# aligner.load_gradient(gradient_filepath_map_f=gradient_filepath_map_f, indices_f=[name_to_label_fixed['SNR_L']])

# %%
# T, scores = aligner.optimize(type='rigid', max_iter_num=10, history_len=500, terminate_thresh=1e-4,
#                              grid_search_sample_number=1000,
#                              indices_m=None)

# %%
# T, scores = aligner.optimize(type='rigid', max_iter_num=20, history_len=500, terminate_thresh=1e-4,
#                              indices_m=[name_to_label_moving['5N_L'],
#                                         name_to_label_moving['5N_R'],
#                                        name_to_label_fixed['12N'],
#                                        name_to_label_fixed['SNR_L'],
#                                        name_to_label_fixed['SNR_R']])

# %%
# largely the same optimization path regardless of the starting condition

# For rigid, 
# grad_computation_sample_number = 1e5 is desired
# grid_search_iteration_number and grid_search_sample_number seem to be unimportant as well, set to 100
# lr1=10, lr2=.1 is best

# For affine, 
# lr2 = .001 is too slow; 0.1 rises faster than 0.01
# lr1 does not matter
# plateus around iteration 100, but keep rising afterwards.
# grad_computation_sample_number does not make a difference

T, scores = aligner.optimize(type='rigid', max_iter_num=1000, history_len=500, terminate_thresh=1e-4,
#                              indices_m=[name_to_label_fixed['SNR_L']],
                             indices_m=None,
                            grid_search_iteration_number=10,
                             grid_search_sample_number=100,
                             grad_computation_sample_number=1e5,
                             lr1=10., lr2=.1)
#                              init_T=[1,0,0,-10,0,1,0,0,0,0,1,0])
# Out:
# grid search: 2.908054 seconds
# 0.000000 1.406241
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# iteration 950
# score: 2.342656
# iteration 951
# score: 2.342310
# iteration 952
# score: 2.341823
# iteration 953
# score: 2.341382
# iteration 954
# score: 2.340961
# iteration 955
# score: 2.340583
# iteration 956
# score: 2.340130
# iteration 957
# score: 2.339781
# iteration 958
# score: 2.339412
# iteration 959
# score: 2.338953
# iteration 960
# score: 2.338550
# iteration 961
# score: 2.338099
# iteration 962
# score: 2.337655
# iteration 963
# score: 2.337232
# iteration 964
# score: 2.336849
# iteration 965
# score: 2.336408
# iteration 966
# score: 2.335999
# iteration 967
# score: 2.335589
# iteration 968
# score: 2.335181
# iteration 969
# score: 2.334782
# iteration 970
# score: 2.334328
# iteration 971
# score: 2.333971
# iteration 972
# score: 2.333539
# iteration 973
# score: 2.333144
# iteration 974
# score: 2.332682
# iteration 975
# score: 2.332296
# iteration 976
# score: 2.331898
# iteration 977
# score: 2.331574
# iteration 978
# score: 2.331099
# iteration 979
# score: 2.330762
# iteration 980
# score: 2.330309
# iteration 981
# score: 2.329879
# iteration 982
# score: 2.329557
# iteration 983
# score: 2.329164
# iteration 984
# score: 2.328809
# iteration 985
# score: 2.328363
# iteration 986
# score: 2.327964
# iteration 987
# score: 2.327621
# iteration 988
# score: 2.327231
# iteration 989
# score: 2.326866
# iteration 990
# score: 2.326493
# iteration 991
# score: 2.326024
# iteration 992
# score: 2.325649
# iteration 993
# score: 2.325321
# iteration 994
# score: 2.324961
# iteration 995
# score: 2.324548
# iteration 996
# score: 2.324233
# iteration 997
# score: 2.323886
# iteration 998
# score: 2.323510
# iteration 999
# score: 2.323166

# %%
print T.reshape((3,4))
plt.plot(scores);
print max(scores), scores[-1]
# Out:
# [[  9.37209771e-01  -3.47865972e-01   2.50421977e-02   3.50770693e+01]
#  [  3.48413665e-01   9.37073372e-01  -2.23922698e-02   2.91192870e+01]
#  [ -1.56768679e-02   2.97112979e-02   9.99435578e-01  -2.21067751e+00]]
# 2.48011682954 2.32316579063

# %%
atlasAlignParams_dir = create_if_not_exists(atlasAlignParams_rootdir + '/%(stack_moving)s_to_%(stack_fixed)s' % \
                     {'stack_moving': stack_moving, 'stack_fixed': stack_fixed})

# %%
with open(atlasAlignParams_dir + '/%(stack_moving)s_down32_annotationVolume_to_%(stack_fixed)s_down32_annotationVolume_parameters.txt' % \
          {'stack_moving': stack_moving, 'stack_fixed': stack_fixed}, 'w') as f:
    
    f.write(array_to_one_liner(T))
    f.write(array_to_one_liner(aligner.centroid_m))
    f.write(array_to_one_liner([aligner.xdim_m, aligner.ydim_m, aligner.zdim_m]))
    f.write(array_to_one_liner(aligner.centroid_f))
    f.write(array_to_one_liner([aligner.xdim_f, aligner.ydim_f, aligner.zdim_f]))

# %%
# Try all sets of parameters

# %%
c = 0

for lr1 in [.1, 1., 10.]:
    for lr2 in [1e-1, 1e-2, 1e-3]:
        for n in [1e3, 1e4, 1e5]:
            
            
            c += 1
        
            T, scores = aligner.optimize(type='affine', max_iter_num=500, history_len=500, terminate_thresh=1e-4,
            #                              indices_m=[name_to_label_fixed['SNR_L']],
                                         indices_m=None,
                                        grid_search_iteration_number=10,
                                         grid_search_sample_number=100,
                                         grad_computation_sample_number=n,
                                         lr1=lr1, lr2=lr2)
            #                              init_T=[1,0,0,-10,0,1,0,0,0,0,1,0])
            
            plt.figure();
            plt.plot(scores);
            plt.savefig(atlasAlignParams_dir + '/affine/%(stack_moving)s_to_%(stack_fixed)s_scoreEvolution_%(c)d.png' % \
                        {'stack_moving': stack_moving, 'stack_fixed': stack_fixed, 'c':c},
                        bbox_inches='tight')
            
            with open(atlasAlignParams_dir + '/affine/%(stack_moving)s_to_%(stack_fixed)s_scoreEvolution_%(c)d.txt' % \
                       {'stack_moving': stack_moving, 'stack_fixed': stack_fixed, 'c':c}, 'w') as f:
                f.write(array_to_one_liner([lr1, lr2, n]))
#             print max(scores), scores[-1]
# Out:
# grid search: 2.804557 seconds
# 0.000000 1.468269
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# grid search: 2.085076 seconds
# 1.468269 1.555371
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# grid search: 1.995485 seconds
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# No valid voxels after transform.
# grid search: 1.516099 seconds
# grid search: 1.204264 seconds
# grid search: 1.007529 seconds
# grid search: 1.010375 seconds
# 1.555371 1.563551
# grid search: 0.802451 seconds
# grid search: 0.713143 seconds
# grid search: 0.705630 seconds
# 1.563551 1.567134
# iteration 0
# score: 1.567134
# iteration 1
# score: 1.221753
# iteration 2
# score: 1.448174
# iteration 3
# score: 1.626250
# iteration 4
# score: 1.751489
# iteration 5
# score: 1.822651
# iteration 6
# score: 1.876183
# iteration 7
# score: 1.880210
# iteration 8
# score: 1.912120
# iteration 9
# score: 1.901603
# iteration 10
# score: 1.930656
# iteration 11
# score: 1.919232
# iteration 12
# score: 1.941358
# iteration 13
# score: 1.930811
# iteration 14
# score: 1.949364
# iteration 15
# score: 1.939914
# iteration 16
# score: 1.954946
# iteration 17
# score: 1.947116
# iteration 18
# score: 1.959926
# iteration 19
# score: 1.952645
# iteration 20
# score: 1.963174
# iteration 21
# score: 1.956438
# iteration 22
# score: 1.965679
# iteration 23
# score: 1.959259
# iteration 24
# score: 1.967336
# iteration 25
# score: 1.961785
# iteration 26
# score: 1.968504
# iteration 27
# score: 1.963469
# iteration 28
# score: 1.969294
# iteration 29
# score: 1.965137
# iteration 30
# score: 1.969826
# iteration 31
# score: 1.966541
# iteration 32
# score: 1.970331
# iteration 33
# score: 1.967902
# iteration 34
# score: 1.970925
# iteration 35
# score: 1.968888
# iteration 36
# score: 1.971344
# iteration 37
# score: 1.969818
# iteration 38
# score: 1.971905
# iteration 39
# score: 1.970747
# iteration 40
# score: 1.972462
# iteration 41
# score: 1.971689
# iteration 42
# score: 1.973052
# iteration 43
# score: 1.972634
# iteration 44
# score: 1.973665
# iteration 45
# score: 1.973472
# iteration 46
# score: 1.974323
# iteration 47
# score: 1.974290
# iteration 48
# score: 1.974989
# iteration 49
# score: 1.975106
# iteration 50
# score: 1.975651
# iteration 51
# score: 1.975821
# iteration 52
# score: 1.976301
# iteration 53
# score: 1.976428
# iteration 54
# score: 1.976856
# iteration 55
# score: 1.977092
# iteration 56
# score: 1.977458
# iteration 57
# score: 1.977650
# iteration 58
# score: 1.977983
# score: 1.988898
# iteration 449
# score: 1.988910
# iteration 450
# score: 1.988928
# iteration 451
# score: 1.988945
# iteration 452
# score: 1.988960
# iteration 453
# score: 1.988973
# iteration 454
# score: 1.988989
# iteration 455
# score: 1.989014
# iteration 456
# score: 1.989020
# iteration 457
# score: 1.989035
# iteration 458
# score: 1.989053
# iteration 459
# score: 1.989067
# iteration 460
# score: 1.989095
# iteration 461
# score: 1.989115
# iteration 462
# score: 1.989133
# iteration 463
# score: 1.989148
# iteration 464
# score: 1.989156
# iteration 465
# score: 1.989173
# iteration 466
# score: 1.989183
# iteration 467
# score: 1.989202
# iteration 468
# score: 1.989214
# iteration 469
# score: 1.989232
# iteration 470
# score: 1.989255
# iteration 471
# score: 1.989265
# iteration 472
# score: 1.989287
# iteration 473
# score: 1.989310
# iteration 474
# score: 1.989329
# iteration 475
# score: 1.989339
# iteration 476
# score: 1.989356
# iteration 477
# score: 1.989378
# iteration 478
# score: 1.989397
# iteration 479
# score: 1.989427
# iteration 480
# score: 1.989447
# iteration 481
# score: 1.989473
# iteration 482
# score: 1.989489
# iteration 483
# score: 1.989507
# iteration 484
# score: 1.989523
# iteration 485
# score: 1.989533
# iteration 486
# score: 1.989560
# iteration 487
# score: 1.989582
# iteration 488
# score: 1.989609
# iteration 489
# score: 1.989627
# iteration 490
# score: 1.989649
# iteration 491
# score: 1.989661
# iteration 492
# score: 1.989673
# iteration 493
# score: 1.989685
# iteration 494
# score: 1.989703
# iteration 495
# score: 1.989720
# iteration 496
# score: 1.989729
# iteration 497
# score: 1.989750
# iteration 498
# score: 1.989772
# iteration 499
# score: 1.989788
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9464485c62b8> in <module>()
#      19             plt.figure();
#      20             plt.plot(scores);
# ---> 21             plt.savefig(atlasAlignParams_dir + '/affine/%(stack_moving)s_to_%(stack_fixed)s_scoreEvolution_%(c)d.png' %                         {'stack_moving': stack_moving, 'stack_fixed': stack_fixed, 'c':c},
#      22                         bbox_inches='tight')
#      23
#
# NameError: name 'atlasAlignParams_dir' is not defined

# %%
c = 0
for lr1 in [.1, 1., 10.]:
    for lr2 in [1e-1, 1e-2, 1e-3]:
        for n in [1e3, 1e4, 1e5]:
            c += 1
            print c, lr1, lr2, int(n)
# Out:
# 1 0.1 0.1 1000
# 2 0.1 0.1 10000
# 3 0.1 0.1 100000
# 4 0.1 0.01 1000
# 5 0.1 0.01 10000
# 6 0.1 0.01 100000
# 7 0.1 0.001 1000
# 8 0.1 0.001 10000
# 9 0.1 0.001 100000
# 10 1.0 0.1 1000
# 11 1.0 0.1 10000
# 12 1.0 0.1 100000
# 13 1.0 0.01 1000
# 14 1.0 0.01 10000
# 15 1.0 0.01 100000
# 16 1.0 0.001 1000
# 17 1.0 0.001 10000
# 18 1.0 0.001 100000
# 19 10.0 0.1 1000
# 20 10.0 0.1 10000
# 21 10.0 0.1 100000
# 22 10.0 0.01 1000
# 23 10.0 0.01 10000
# 24 10.0 0.01 100000
# 25 10.0 0.001 1000
# 26 10.0 0.001 10000
# 27 10.0 0.001 100000

# %%
# READ

# %%
stack_fixed = 'MD589'
stack_moving = 'MD594'

# %%
atlasAlignParams_dir = create_if_not_exists(atlasAlignParams_rootdir + '/%(stack_moving)s_to_%(stack_fixed)s' % \
                     {'stack_moving': stack_moving, 'stack_fixed': stack_fixed})

# %%
volume_fixed = bp.unpack_ndarray_file(os.path.join(VOLUME_ROOTDIR, '%(stack)s/%(stack)s_down32_annotationVolume.bp' % {'stack': stack_fixed}))
volume_moving = bp.unpack_ndarray_file(os.path.join(VOLUME_ROOTDIR, '%(stack)s/%(stack)s_down32_annotationVolume.bp' % {'stack': stack_moving}))
print volume_fixed.shape
print volume_moving.shape
# Out:
# (348, 421, 377)
# (326, 515, 368)

# %%
# stack = 'MD589'

with open(atlasAlignParams_dir + '/%(stack_moving)s_down32_annotationVolume_to_%(stack_fixed)s_down32_annotationVolume_parameters.txt' % \
          {'stack_moving': stack_moving, 'stack_fixed': stack_fixed}, 'r') as f:
    
    lines = f.readlines()
    
    global_params = one_liner_to_arr(lines[0], float)
    centroid_m = one_liner_to_arr(lines[1], float)
    xdim_m, ydim_m, zdim_m  = one_liner_to_arr(lines[2], int)
    centroid_f = one_liner_to_arr(lines[3], float)
    xdim_f, ydim_f, zdim_f  = one_liner_to_arr(lines[4], int)

# %%
all_indices_m = set(np.unique(volume_moving)) - {0}

# %%
nzvoxels_m = {i: parallel_where_binary(volume_moving==i) for i in all_indices_m}

# %%
# HANGS for some reason
# from multiprocessing import Pool

# pool = Pool(2)
# # nzvoxels_m_ = pool.map(lambda i: parallel_where_binary(volume_m[i] > 0, num_samples=int(1e6)),
# #                         self.all_indices_m)
# nzvoxels_m = pool.map(lambda i: parallel_where_binary(volume_moving==i),
#                         all_indices_m)
# pool.close()
# pool.join()

# nzvoxels_m = dict(zip(all_indices_m, nzvoxels_m))

# %%
from registration_utilities import transform_points

# %%
nzs_m_aligned_to_f = {ind_m: transform_points(global_params, pts=nzs_m, 
                                              c=centroid_m, c_prime=centroid_f).astype(np.int16)
                      for ind_m, nzs_m in nzvoxels_m.iteritems()}

volume_m_aligned_to_f = np.zeros((ydim_f, xdim_f, zdim_f), np.int)

for ind_m in nzs_m_aligned_to_f.iterkeys():

    xs_f, ys_f, zs_f = nzs_m_aligned_to_f[ind_m].T
    
    valid = (xs_f >= 0) & (ys_f >= 0) & (zs_f >= 0) & \
    (xs_f < xdim_f) & (ys_f < ydim_f) & (zs_f < zdim_f)

    xs_m, ys_m, zs_m = nzvoxels_m[ind_m].T
    
    volume_m_aligned_to_f[ys_f[valid], xs_f[valid], zs_f[valid]] = \
    volume_moving[ys_m[valid], xs_m[valid], zs_m[valid]]

del nzs_m_aligned_to_f

# %%
# filename_to_section = {}
# section_to_filename = {}
# with open('/home/yuncong/CSHL_data_processed/%(stack_fixed)s/%(stack_fixed)s_sorted_filenames.txt' %\
#           dict(stack_fixed=stack_fixed), 'r') as f:
#     for line in f.readlines():
#         fn, label = line.strip().split()
#         filename_to_section[fn] = int(label)
#         section_to_filename[int(label)] = fn

# %%
with open(VOLUME_ROOTDIR + '/%(stack_fixed)s/%(stack_fixed)s_down32_annotationVolume_bbox.txt' %\
          dict(stack_fixed=stack_fixed), 'r') as f:
    xmin_vol_f, xmax_vol_f, ymin_vol_f, ymax_vol_f, zmin_vol_f, zmax_vol_f = map(int, f.readline().strip().split())
    print xmin_vol_f, xmax_vol_f, ymin_vol_f, ymax_vol_f, zmin_vol_f, zmax_vol_f

# %%
# with open('/home/yuncong/CSHL_data_processed/%(stack_fixed)s/%(stack_fixed)s_cropbox.txt' %\
#           dict(stack_fixed=stack_fixed), 'r') as f:
#     xmin, xmax, ymin, ymax, sec_min, sec_max = map(int, f.readline().strip().split())
#     print xmin, xmax, ymin, ymax, sec_min, sec_max

# %%
# volume_tb_fixed = bp.unpack_ndarray_file('/home/yuncong/csd395/CSHL_volumes2/%(stack_fixed)s/%(stack_fixed)s_down32Volume.bp' % dict(stack_fixed=stack_fixed))

# %%
from registration_utilities import find_contour_points

# %%
downsample_factor = 32
xy_pixel_distance_downsampled = xy_pixel_distance_lossless * downsample_factor
voxel_z_size = section_thickness / xy_pixel_distance_downsampled

# %%
create_if_not_exists(os.path.join(atlasAlignParams_dir, 'viz'))

# %%
bar = show_progress_bar(100, 300)

for sec in range(100, 300):
    
    if metadata_cache['sections_to_filenames'][stack_fixed][sec] in ['Placeholder', 'Rescan', 'Nonexisting']:
        continue
    
    bar.value = sec

    z = voxel_z_size * (sec - 1) - zmin_vol_f

    contours_f_on_volume = find_contour_points(volume_fixed[..., int(z)])
    contours_f_on_cropped = {i: [cnt + (xmin_vol_f, ymin_vol_f) for cnt in cnts] for i, cnts in contours_f_on_volume.iteritems()}

    contours_m_alignedTo_f_on_volume = find_contour_points(volume_m_aligned_to_f[..., int(z)])
    contours_m_alignedTo_f_on_cropped = {i: [cnt + (xmin_vol_f, ymin_vol_f) for cnt in cnts] for i, cnts in contours_m_alignedTo_f_on_volume.iteritems()}

    img = imread('/home/yuncong/CSHL_data_processed/%(stack_fixed)s/%(stack_fixed)s_thumbnail_sorted_aligned/%(stack_fixed)s_%(sec)04d_thumbnail_aligned.tif' %\
               dict(stack_fixed=stack_fixed, sec=sec))


    viz = img.copy()

    for ind_m, cnts_m in contours_m_alignedTo_f_on_cropped.iteritems():
        for cnt_m in cnts_m:
            cv2.polylines(viz, [cnt_m.astype(np.int)], True, (255,0,0), 2)

    for ind_f, cnts_f in contours_f_on_cropped.iteritems():
        for cnt_f in cnts_f:
            cv2.polylines(viz, [cnt_f.astype(np.int)], True, (0,255,0), 2)


#     plt.figure(figsize=(20,20));
#     plt.imshow(viz[:800, :1200])
#     plt.show();
    
    viz_fn = os.path.join(atlasAlignParams_dir, 'viz', '%(stack_moving)s_to_%(stack_fixed)s_%(sec)04d.jpg' % \
          {'stack_moving': stack_moving, 'stack_fixed': stack_fixed, 'sec': sec})
    imsave(viz_fn, viz[:800, :1200])

# %%
volume_m_alignedTo_f_fn = os.path.join(atlasAlignParams_dir, '%(stack_moving)s_down32_annotationVolume_alignedTo_%(stack_fixed)s_down32_annotationVolume.bp' % \
                                       {'stack_moving': stack_moving, 'stack_fixed': stack_fixed})

# %%
from annotation_utilities import fill_sparse_volume
volume_m_aligned_to_f_densified = fill_sparse_volume(volume_m_aligned_to_f)

# %%
bp.pack_ndarray_file(volume_m_aligned_to_f_densified, volume_m_alignedTo_f_fn)

# %%
# Create voxel occupancy-based probabilistic volume

# %%
aggregated_structure_volumes = {}
aggregated_structure_volume_bbox = {}

for label, name_s in label_to_name_fixed.iteritems():
    
    aggregated_volume_aligned_to_f = ((volume_m_aligned_to_f_densified == label).astype(np.int8) + (volume_fixed == label).astype(np.int8)) / 2.
    
    xmin, xmax, ymin, ymax, zmin, zmax = bbox_3d(aggregated_volume_aligned_to_f > 0)
    vol = aggregated_volume_aligned_to_f[ymin:ymax+1, xmin:xmax+1, zmin:zmax+1].copy().astype(np.float16)
    
    aggregated_structure_volume_bbox[name_s] = (xmin, xmax, ymin, ymax, zmin, zmax)
    aggregated_structure_volumes[name_s] = vol
    
#     output_dir = create_if_not_exists(os.path.join(VOLUME_ROOTDIR, 'atlas_to_%(stack_f)s' % dict(stack_f=stack_fixed)))
#     vol_fn = os.path.join(output_dir, 'atlas_to_%(stack_f)s_%(name_s)s.bp' % dict(stack_f=stack_fixed, name_s=name_s))
#     bbox_fn = os.path.join(output_dir, 'atlas_to_%(stack_f)s_%(name_s)s_bbox.txt' % dict(stack_f=stack_fixed, name_s=name_s))
    
#     bp.pack_ndarray_file(vol, vol_fn)
#     np.savetxt(bbox_fn, np.array((xmin, xmax, ymin, ymax, zmin, zmax))[None])

# %%
paired_structures = ['5N', '6N', '7N', '7n', 'Amb', 'LC', 'LRt', 'Pn', 'Tz', 'VLL', 'RMC', 'SNC', 'SNR', '3N', '4N',
                    'Sp5I', 'Sp5O', 'Sp5C', 'PBG', '10N', 'VCA', 'VCP', 'DC']
singular_structures = ['AP', '12N', 'RtTg', 'SC', 'IC']
structures = paired_structures + singular_structures

# %%
atlas_score_volumes = {}

for name_u in structures:
    
    print name_u
    
    atlas_score_volume = np.zeros_like(volume_fixed, np.float16)
    
    if name_u in singular_structures:
        
#         output_dir = create_if_not_exists(os.path.join(VOLUME_ROOTDIR, 'atlas_to_%(stack_f)s' % dict(stack_f=stack_fixed)))
#         vol_fn = os.path.join(output_dir, 'atlas_to_%(stack_f)s_%(name_s)s.bp' % dict(stack_f=stack_fixed, name_s=name_u))
#         bbox_fn = os.path.join(output_dir, 'atlas_to_%(stack_f)s_%(name_s)s_bbox.txt' % dict(stack_f=stack_fixed, name_s=name_u))
#         vol = bp.unpack_ndarray_file(vol_fn)
#         xmin, xmax, ymin, ymax, zmin, zmax = np.loadtxt(bbox_fn)
        
        vol = aggregated_structure_volumes[name_u]
        xmin, xmax, ymin, ymax, zmin, zmax = aggregated_structure_volume_bbox[name_u]
        
        atlas_score_volume[ymin:ymax+1, xmin:xmax+1, zmin:zmax+1] = vol
        
        atlas_score_volumes[name_u] = atlas_score_volume
        
    else:
    
        lname = convert_to_left_name(name_u)

#         output_dir = create_if_not_exists(os.path.join(VOLUME_ROOTDIR, 'atlas_to_%(stack_f)s' % dict(stack_f=stack_fixed)))
#         vol_fn = os.path.join(output_dir, 'atlas_to_%(stack_f)s_%(name_s)s.bp' % dict(stack_f=stack_fixed, name_s=lname))
#         bbox_fn = os.path.join(output_dir, 'atlas_to_%(stack_f)s_%(name_s)s_bbox.txt' % dict(stack_f=stack_fixed, name_s=lname))

#         vol = bp.unpack_ndarray_file(vol_fn)
#         xmin, xmax, ymin, ymax, zmin, zmax = np.loadtxt(bbox_fn)

        vol = aggregated_structure_volumes[lname]
        xmin, xmax, ymin, ymax, zmin, zmax = aggregated_structure_volume_bbox[lname]

        atlas_score_volume[ymin:ymax+1, xmin:xmax+1, zmin:zmax+1] = vol
        
        atlas_score_volumes[name_u] = atlas_score_volume
        
        ###############################

        rname = convert_to_right_name(name_u)

#         output_dir = create_if_not_exists(os.path.join(VOLUME_ROOTDIR, 'atlas_to_%(stack_f)s' % dict(stack_f=stack_fixed), 'score_volumes'))
#         vol_fn = os.path.join(output_dir, 'atlas_to_%(stack_f)s_%(name_s)s.bp' % dict(stack_f=stack_fixed, name_s=rname))
#         bbox_fn = os.path.join(output_dir, 'atlas_to_%(stack_f)s_%(name_s)s_bbox.txt' % dict(stack_f=stack_fixed, name_s=rname))
    
#         vol = bp.unpack_ndarray_file(vol_fn)
#         xmin, xmax, ymin, ymax, zmin, zmax = np.loadtxt(bbox_fn)
        
        vol = aggregated_structure_volumes[rname]
        xmin, xmax, ymin, ymax, zmin, zmax = aggregated_structure_volume_bbox[rname]
        
        atlas_score_volume[ymin:ymax+1, xmin:xmax+1, zmin:zmax+1] = vol
        atlas_score_volumes[name_u] = atlas_score_volume
# Out:
# 5N
# 6N
# 7N
# 7n
# Amb
# /oasis/projects/nsf/csd395/yuncong/brain_virtualenv/lib/python2.7/site-packages/ipykernel/__main__.py:33: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /oasis/projects/nsf/csd395/yuncong/brain_virtualenv/lib/python2.7/site-packages/ipykernel/__main__.py:48: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# LC
# LRt
# Pn
# Tz
# VLL
# RMC
# SNC
# SNR
# 3N
# 4N
# Sp5I
# Sp5O
# Sp5C
# PBG
# 10N
# VCA
# VCP
# DC
# AP
# 12N
# RtTg
# SC
# IC
# /oasis/projects/nsf/csd395/yuncong/brain_virtualenv/lib/python2.7/site-packages/ipykernel/__main__.py:18: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
for name_u, vol in atlas_score_volumes.iteritems():
    
    output_dir = create_if_not_exists(os.path.join(VOLUME_ROOTDIR, 'atlas_on_%(stack_f)s' % dict(stack_f=stack_fixed), 'score_volumes'))
    vol_fn = os.path.join(output_dir, 'atlas_on_%(stack_f)s_down32_scoreVolume_%(name)s.bp' % dict(stack_f=stack_fixed, name=name_u))
    bp.pack_ndarray_file(vol, vol_fn)

# %%
name_u = '7N'
ims = [atlas_score_volumes[name_u][:, :, z] 
       for z in range(0, atlas_score_volumes[name_u].shape[2], 10)]

display_images_in_grids(ims, 5, cmap=plt.cm.gray, vmin=0, vmax=1)

# %%
name_s = 'VLL_L'
ims = [aggregated_structure_volumes[name_s][:, :, z] 
       for z in range(0, aggregated_structure_volumes[name_s].shape[2], 2)]

display_images_in_grids(ims, 5, cmap=plt.cm.gray, vmin=0, vmax=1)
