# %%
# %reload_ext autoreload
# %autoreload 2

import cv2

import os
import sys
sys.path.append(os.path.join(os.environ['REPO_DIR'], 'utilities'))
from utilities2015 import *

from collections import defaultdict

from matplotlib.path import Path
# %matplotlib inline

import pandas as pd
from shapely.geometry import Polygon

from annotation_utilities import *
# Out:
# [autoreload of utilities2015 failed: Traceback (most recent call last):
#   File "/oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# AttributeError: __abstractmethods__
# ]

# %%
stack = 'MD589'
# stack = 'MD594'

# %%
patch_size = 224
half_size = patch_size/2
stride = 56

dm = DataManager(stack=stack)

w = dm.image_width
h = dm.image_height 

ys, xs = np.meshgrid(np.arange(half_size, h-half_size, stride), np.arange(half_size, w-half_size, stride),
                     indexing='xy')
    
sample_locations = np.c_[xs.flat, ys.flat]

# require 30% of the diameter to be within the landmark boundary

margin = int(.3*half_size)

sample_locations_ul = sample_locations - (margin, margin)
sample_locations_ur = sample_locations - (-margin, margin)
sample_locations_ll = sample_locations - (margin, -margin)
sample_locations_lr = sample_locations - (-margin, -margin)

# %%
username = 'yuncong'
label_polygons = load_label_polygons_if_exists(stack, username, force=True)
# Out:
# username yuncong does not have any annotations for current section 93
# username yuncong does not have any annotations for current section 94
# username yuncong does not have any annotations for current section 95
# username yuncong does not have any annotations for current section 96
# username yuncong does not have any annotations for current section 97
# username yuncong does not have any annotations for current section 98
# username yuncong does not have any annotations for current section 99
# username yuncong does not have any annotations for current section 100
# username yuncong does not have any annotations for current section 101
# username yuncong does not have any annotations for current section 102
# username yuncong does not have any annotations for current section 103
# username yuncong does not have any annotations for current section 104
# username yuncong does not have any annotations for current section 105
# username yuncong does not have any annotations for current section 106
# username yuncong does not have any annotations for current section 107
# username yuncong does not have any annotations for current section 108
# username yuncong does not have any annotations for current section 109
# username yuncong does not have any annotations for current section 112
# username yuncong does not have any annotations for current section 114
# username yuncong does not have any annotations for current section 116
# username yuncong does not have any annotations for current section 118
# username yuncong does not have any annotations for current section 120
# username yuncong does not have any annotations for current section 122
# username yuncong does not have any annotations for current section 124
# username yuncong does not have any annotations for current section 126
# username yuncong does not have any annotations for current section 128
# username yuncong does not have any annotations for current section 130
# username yuncong does not have any annotations for current section 132
# username yuncong does not have any annotations for current section 134
# username yuncong does not have any annotations for current section 136
# username yuncong does not have any annotations for current section 138
# username yuncong does not have any annotations for current section 140
# username yuncong does not have any annotations for current section 328
# username yuncong does not have any annotations for current section 330
# username yuncong does not have any annotations for current section 332
# username yuncong does not have any annotations for current section 334
# username yuncong does not have any annotations for current section 336
# username yuncong does not have any annotations for current section 338
# username yuncong does not have any annotations for current section 340
# username yuncong does not have any annotations for current section 342
# username yuncong does not have any annotations for current section 344
# username yuncong does not have any annotations for current section 346
# username yuncong does not have any annotations for current section 348
# username yuncong does not have any annotations for current section 350
# username yuncong does not have any annotations for current section 352
# username yuncong does not have any annotations for current section 353
# username yuncong does not have any annotations for current section 354
# username yuncong does not have any annotations for current section 355
# username yuncong does not have any annotations for current section 356
# username yuncong does not have any annotations for current section 357
# username yuncong does not have any annotations for current section 358
# username yuncong does not have any annotations for current section 359
# username yuncong does not have any annotations for current section 360
# username yuncong does not have any annotations for current section 361
# username yuncong does not have any annotations for current section 362
# username yuncong does not have any annotations for current section 363
# username yuncong does not have any annotations for current section 364
# username yuncong does not have any annotations for current section 365
# username yuncong does not have any annotations for current section 366
# username yuncong does not have any annotations for current section 367
# username yuncong does not have any annotations for current section 368
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/pandas/core/generic.py:939: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->['10N', '12N', '3N', '4N', '5N', '5TT', '6N', '7N', '7n', '9N', 'AP', 'Amb', 'CC', 'CereNuc', 'DC', 'DTgP', 'Gr', 'IO', 'LC', 'LDTg', 'LM1C', 'LM1R', 'LRt', 'LSO', 'LVe', 'MVe', 'MVePC', 'Nuc1', 'Pn', 'PnO', 'Pr5', 'Pr5DM', 'Pr5VL', 'PrVd', 'PrVv', 'R', 'RtTg', 'Sol', 'Sp5C', 'Sp5I', 'Sp5O', 'SuVe', 'Tz', 'UDF', 'UDFtr', 'VCA', 'VCP', 'VIpp', 'VLL', 'VMu', 'VOra', 'VOri', 'VOrp', 'VTg', 'Vcd', 'dtgx', 'mlf', 'pyx', 'scp', 'sp5', 'vtgx']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
labels = ['BackG', '5N', '7n', '7N', '12N', 'Pn', 'VLL', 
          '6N', 'Amb', 'R', 'Tz', 'RtTg', 'LRt', 'LC', 'AP', 'sp5']

label_surroundIncluded = set(labels[1:] + [l+'_surround' for l in labels[1:]])

annotation_on_sections = get_annotation_on_sections(label_polygons=label_polygons, 
                                                    filtered_labels=label_surroundIncluded)

landmark_range_limits = get_landmark_range_limits(stack=stack, label_polygons=label_polygons, 
                                                  filtered_labels=label_surroundIncluded)

# %%
landmark_range_limits
# Out:
# {'12N': [(206, 247)],
#  '5N': [(150, 171), (287, 312)],
#  '6N': [(205, 213)],
#  '7N': [(152, 195), (275, 316)],
#  '7n': [(149, 204), (257, 316)],
#  'AP': [(215, 233)],
#  'Amb': [(164, 170), (295, 299)],
#  'LC': [(175, 184), (267, 273)],
#  'LRt': [(161, 188), (284, 306)],
#  'Pn': [(175, 229), (244, 294)],
#  'R': [(187, 215), (238, 245)],
#  'RtTg': [(190, 278)],
#  'Tz': [(197, 219), (250, 276)],
#  'VLL': [(143, 173), (294, 313)],
#  'sp5': [(131, 327)]}

# %%
from itertools import chain
for l, secs_with_annotations in annotation_on_sections.iteritems():
    secs_within_landmark_range_limits = set(chain(*[range(s1,s2+1) for s1,s2 in landmark_range_limits[l]]))
#     print l, sorted(secs_within_landmark_range_limits - set(secs_with_annotations))
    print l, sorted(secs_within_landmark_range_limits.symmetric_difference(set(secs_with_annotations)))
# Out:
# RtTg []
# Tz []
# VLL []
# 7n []
# Amb []
# sp5 [132, 134, 136, 138, 140, 142, 221]
# 12N [221]
# AP [221]
# LRt [285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299]
# 5N []
# 6N []
# 7N []
# R []
# Pn [245]
# LC []

# %%
# print 'all annotated classes'
# print label_polygons.keys().tolist()

# labels_to_detect = ['5N', '7n', '7N', '12N', 'Gr', 'LVe', 'Pn', 'SuVe', 'VLL', 
#                      '6N', 'Amb', 'R', 'Tz', 'Sol', 'RtTg', 'LRt', 'LC', 'AP', 'sp5']

# assert set(labels_to_detect).issubset(set(label_polygons.keys()))

# %%
labels_to_detect = labels[1:]

# %%
section_contains = get_section_contains_labels(label_polygons, filtered_labels=label_surroundIncluded)
secs = section_contains.keys()

# %%
progress_bar = FloatProgress(min=np.min(secs), max=np.max(secs))
display(progress_bar, description='identifying landmark patch indices')

indices_allLandmarks_allSections = defaultdict(dict)

# for sec, labs in section_contains.iteritems():
for sec in [160]:
    
#     labs = section_contains[sec]
    labs = ['sp5']

    progress_bar.value = sec
        
    if len(labs) == 0:
        continue

    dm.set_slice(sec)
    mask = dm.load_thumbnail_mask()
    
    indices_fg = np.where(mask[sample_locations[:,1]/32, sample_locations[:,0]/32])[0]
    indices_bg = np.setdiff1d(range(sample_locations.shape[0]), indices_fg)

    indices_inside = {}
    indices_surround = {}
    
    for label in labs:

        path = Path(label_polygons[label][sec])
        indices_inside[label] =  np.where(path.contains_points(sample_locations_ll) &\
                                          path.contains_points(sample_locations_lr) &\
                                          path.contains_points(sample_locations_ul) &\
                                          path.contains_points(sample_locations_ur))[0]
                    
    indices_allInside = np.concatenate(indices_inside.values())    
    
    for label in labs:
 
        surround = Polygon(label_polygons[label][sec]).buffer(500, resolution=2)

        path = Path(list(surround.exterior.coords))
        indices_sur =  np.where(path.contains_points(sample_locations_ll) &\
                                path.contains_points(sample_locations_lr) &\
                                path.contains_points(sample_locations_ul) &\
                                path.contains_points(sample_locations_ur))[0]

        # surround classes do not include patches of any no-surround class
        indices_surround[label] = np.setdiff1d(indices_sur, np.r_[indices_bg, indices_allInside])
        
        
    for l, inds in indices_inside.iteritems():
        indices_allLandmarks_allSections[sec][l] = inds
    for l, inds in indices_surround.iteritems():
        indices_allLandmarks_allSections[sec][l+'_surround'] = inds
    indices_allLandmarks_allSections[sec]['bg'] = indices_bg

indices_allLandmarks_allSections.default_factory = None

# %%
41155 in indices_inside
# Out:
# False

# %%
41155 in indices_sur
# Out:
# True

# %%
41155 in indices_surround['sp5']
# Out:
# True

# %%
41155 in indices_allLandmarks_allSections[160]['sp5_surround']
# Out:
# True

# %%
# Find which section has sampling locations of a surround class because it is next to an annotated landmark in the z direction.

annotate_z_surround = defaultdict(dict)

num_z_distance = 5

for l, ranges in landmark_range_limits.iteritems():
    
    all_in_range_secs = set(chain(*[range(s1, s2+1) for s1, s2 in ranges]))
    
    for s1, s2 in ranges:
        for before_s1 in set(range(s1 - num_z_distance, s1)) - all_in_range_secs:
            annotate_z_surround[before_s1][l] = s1
        for after_s2 in set(range(s2 + 1, s2 + num_z_distance + 1)) - all_in_range_secs:
            annotate_z_surround[after_s2][l] = s2
            
annotate_z_surround.default_factory = None

# %%
# augment the surround sets with above sampling locations

for sec in section_contains:
    if sec in annotate_z_surround:
        for l, annotated_sec in annotate_z_surround[sec].iteritems():
            if l+'_surround' in indices_allLandmarks_allSections[sec]:
                indices_allLandmarks_allSections[sec][l+'_surround'] = \
                np.vstack(indices_allLandmarks_allSections[sec][l+'_surround'],
                          indices_allLandmarks_allSections[annotated_sec][l])
            else:
                indices_allLandmarks_allSections[sec][l+'_surround'] = indices_allLandmarks_allSections[annotated_sec][l]

# %%
indices_allLandmarks_allSections_df = pd.DataFrame(indices_allLandmarks_allSections)

# %%
indices_allLandmarks_allSections_df
# Out:
#                                                              108  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [1623, 1826, 2028, 2029, 2230, 2231, 2232, 243...
# sp5            [16373, 16374, 16575, 16576, 16577, 16578, 165...
# sp5_surround   [14546, 14547, 14747, 14748, 14749, 14750, 147...
#
#                                                              110  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [1420, 1623, 1825, 1826, 2028, 2029, 2230, 223...
# sp5            [15359, 15560, 15561, 15562, 15563, 15564, 157...
# sp5_surround   [13731, 13732, 13733, 13734, 13735, 13736, 137...
#
#                                                              112  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [1420, 1622, 1623, 1825, 1826, 2027, 2028, 202...
# sp5            [14952, 14953, 14954, 14955, 14956, 14957, 151...
# sp5_surround   [13124, 13125, 13126, 13127, 13128, 13129, 131...
#
#                                                              114  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [1217, 1419, 1420, 1622, 1623, 1824, 1825, 182...
# sp5            [14347, 14546, 14547, 14548, 14549, 14550, 145...
# sp5_surround   [12719, 12720, 12721, 12722, 12723, 12724, 127...
#
#                                                              116  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [1217, 1419, 1420, 1622, 1623, 1824, 1825, 182...
# sp5            [14142, 14143, 14144, 14145, 14146, 14147, 143...
# sp5_surround   [12314, 12315, 12316, 12317, 12318, 12319, 123...
#
#                                                              118  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [1014, 1216, 1217, 1419, 1420, 1621, 1622, 162...
# sp5            [13536, 13537, 13538, 13539, 13540, 13541, 137...
# sp5_surround   [11709, 11710, 11711, 11712, 11713, 11714, 117...
#
#                                                              132  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [202, 404, 405, 606, 607, 608, 809, 810, 811, ...
# sp5            [12744, 12945, 12946, 12947, 12948, 12949, 131...
# sp5_surround   [11519, 11520, 11521, 11720, 11721, 11722, 117...
#
#                                                              134  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround                                                 NaN
# bg             [202, 404, 405, 606, 607, 608, 809, 810, 811, ...
# sp5            [12129, 12332, 12333, 12334, 12535, 12536, 125...
# sp5_surround   [10098, 10299, 10300, 10301, 10302, 10303, 103...
#
#                                                              136  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround   [13928, 13929, 13930, 13931, 13932, 13933, 141...
# bg             [201, 202, 403, 404, 405, 604, 605, 606, 607, ...
# sp5            [13554, 13555, 13757, 13758, 13759, 13959, 139...
# sp5_surround   [11524, 11525, 11725, 11726, 11727, 11728, 117...
#
#                                                              138  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround                                                  NaN
# 7n                                                           NaN
# 7n_surround                                                  NaN
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround                                                 NaN
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL                                                          NaN
# VLL_surround   [13928, 13929, 13930, 13931, 13932, 13933, 141...
# bg             [201, 202, 403, 404, 405, 604, 605, 606, 607, ...
# sp5            [14164, 14165, 14366, 14367, 14368, 14569, 145...
# sp5_surround   [12137, 12138, 12336, 12337, 12338, 12339, 123...
#
#                                      ...                          \
# 12N                                  ...
# 12N_surround                         ...
# 5N                                   ...
# 5N_surround                          ...
# 6N                                   ...
# 6N_surround                          ...
# 7N                                   ...
# 7N_surround                          ...
# 7n                                   ...
# 7n_surround                          ...
# AP                                   ...
# AP_surround                          ...
# Amb                                  ...
# Amb_surround                         ...
# LC                                   ...
# LC_surround                          ...
# LRt                                  ...
# LRt_surround                         ...
# Pn                                   ...
# Pn_surround                          ...
# R                                    ...
# R_surround                           ...
# RtTg                                 ...
# RtTg_surround                        ...
# Tz                                   ...
# Tz_surround                          ...
# VLL                                  ...
# VLL_surround                         ...
# bg                                   ...
# sp5                                  ...
# sp5_surround                         ...
#
#                                                              298  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N             [17586, 17789, 17992, 17993, 18195, 18196, 183...
# 5N_surround    [15961, 15962, 15963, 16162, 16163, 16164, 161...
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N             [26351, 26352, 26353, 26553, 26554, 26555, 265...
# 7N_surround    [24323, 24522, 24523, 24524, 24525, 24526, 245...
# 7n             [21269, 21471, 21472, 21673, 21674, 21675, 216...
# 7n_surround    [19442, 19443, 19444, 19641, 19642, 19643, 196...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt            [35271, 35473, 35474, 35676, 35677, 35678, 358...
# LRt_surround   [33443, 33644, 33645, 33646, 33647, 33648, 336...
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [12110, 12111, 12112, 12113, 12114, 12115, 121...
# VLL_surround   [10283, 10284, 10285, 10286, 10287, 10288, 102...
# bg             [198, 199, 200, 201, 202, 400, 401, 402, 403, ...
# sp5                                                          NaN
# sp5_surround                                                 NaN
#
#                                                              299  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N             [18395, 18396, 18397, 18398, 18399, 18400, 184...
# 5N_surround    [16566, 16567, 16568, 16569, 16570, 16571, 165...
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N             [26351, 26352, 26553, 26554, 26555, 26556, 265...
# 7N_surround    [24526, 24723, 24724, 24725, 24726, 24727, 247...
# 7n             [21067, 21269, 21270, 21471, 21472, 21473, 216...
# 7n_surround    [19439, 19440, 19441, 19442, 19443, 19444, 194...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt            [37503, 37702, 37703, 37704, 37705, 37706, 377...
# LRt_surround   [35874, 35875, 35876, 35877, 35878, 35879, 358...
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [12307, 12308, 12309, 12310, 12311, 12312, 123...
# VLL_surround   [10480, 10481, 10482, 10483, 10484, 10485, 104...
# bg             [199, 200, 201, 202, 401, 402, 403, 404, 405, ...
# sp5                                                          NaN
# sp5_surround                                                 NaN
#
#                                                              300  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N             [26753, 26754, 26755, 26756, 26954, 26955, 269...
# 7N_surround    [24924, 24925, 24926, 24927, 24928, 24929, 249...
# 7n             [20864, 20865, 21066, 21067, 21068, 21269, 212...
# 7n_surround    [19039, 19040, 19041, 19235, 19236, 19237, 192...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt            [38316, 38317, 38519, 38520, 38521, 38522, 387...
# LRt_surround   [36690, 36691, 36692, 36693, 36694, 36695, 366...
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [11909, 11910, 11911, 11912, 11913, 12109, 121...
# VLL_surround   [10081, 10082, 10083, 10084, 10085, 10086, 100...
# bg             [199, 200, 201, 202, 401, 402, 403, 404, 405, ...
# sp5            [35828, 35829, 35830, 36031, 36032, 36233, 362...
# sp5_surround   [33597, 33798, 33799, 33800, 33801, 33802, 339...
#
#                                                              301  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N             [18803, 18804, 18805, 19004, 19005, 19006, 190...
# 5N_surround    [16974, 16975, 16976, 16977, 16978, 17175, 171...
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N             [26551, 26552, 26753, 26754, 26755, 26756, 269...
# 7N_surround    [24722, 24723, 24724, 24725, 24726, 24727, 249...
# 7n             [20865, 21067, 21068, 21270, 21271, 21473, 214...
# 7n_surround    [19038, 19039, 19040, 19237, 19238, 19239, 192...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt            [38109, 38110, 38311, 38312, 38313, 38515, 385...
# LRt_surround   [36280, 36481, 36482, 36483, 36484, 36485, 364...
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [11906, 11907, 12108, 12109, 12110, 12111, 121...
# VLL_surround   [10280, 10281, 10282, 10283, 10284, 10285, 102...
# bg             [200, 201, 202, 402, 403, 404, 405, 604, 605, ...
# sp5                                                          NaN
# sp5_surround                                                 NaN
#
#                                                              302  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N             [19003, 19205, 19206, 19207, 19408, 19409, 194...
# 5N_surround    [17173, 17174, 17175, 17176, 17375, 17376, 173...
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N             [26957, 26958, 27160, 27161, 27362, 27363, 273...
# 7N_surround    [25130, 25331, 25332, 25333, 25334, 25335, 253...
# 7n             [21068, 21270, 21271, 21472, 21473, 21474, 214...
# 7n_surround    [19037, 19038, 19238, 19239, 19240, 19241, 192...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt            [38521, 38723, 38724, 38725, 38926, 38927, 389...
# LRt_surround   [36691, 36692, 36693, 36694, 36695, 36696, 366...
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [12314, 12315, 12316, 12317, 12318, 12510, 125...
# VLL_surround   [10487, 10488, 10489, 10490, 10491, 10682, 106...
# bg             [201, 202, 403, 404, 405, 604, 605, 606, 607, ...
# sp5                                                          NaN
# sp5_surround                                                 NaN
#
#                                                              303  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround    [19003, 19205, 19206, 19207, 19408, 19409, 194...
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N             [27969, 28172, 28173, 28174, 28175, 28375, 283...
# 7N_surround    [25938, 25939, 26138, 26139, 26140, 26141, 261...
# 7n             [20662, 20865, 21067, 21068, 21069, 21270, 212...
# 7n_surround    [18838, 18839, 19034, 19035, 19036, 19037, 190...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt            [38926, 38927, 39129, 39130, 39332, 39333, 393...
# LRt_surround   [36894, 36895, 36896, 37096, 37097, 37098, 370...
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [12105, 12106, 12107, 12109, 12110, 12111, 121...
# VLL_surround   [10282, 10283, 10284, 10285, 10286, 10479, 104...
# bg             [202, 404, 405, 606, 607, 608, 809, 810, 811, ...
# sp5            [34208, 34209, 34410, 34411, 34613, 34614, 348...
# sp5_surround   [31771, 31772, 31773, 31774, 31775, 31776, 317...
#
#                                                              304  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround    [19003, 19205, 19206, 19207, 19408, 19409, 194...
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N             [27567, 27769, 27770, 27971, 27972, 27973, 281...
# 7N_surround    [25739, 25740, 25741, 25742, 25743, 25939, 259...
# 7n             [21676, 21677, 21878, 21879, 21880, 22081, 220...
# 7n_surround    [19645, 19646, 19647, 19648, 19846, 19847, 198...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround   [38926, 38927, 39129, 39130, 39332, 39333, 393...
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [12108, 12109, 12110, 12111, 12112, 12306, 123...
# VLL_surround   [10281, 10282, 10283, 10284, 10478, 10479, 104...
# bg             [202, 405, 607, 608, 809, 810, 811, 1010, 1011...
# sp5                                                          NaN
# sp5_surround   [34208, 34209, 34410, 34411, 34613, 34614, 348...
#
#                                                              306  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround    [19003, 19205, 19206, 19207, 19408, 19409, 194...
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround    [27567, 27769, 27770, 27971, 27972, 27973, 281...
# 7n                                                           NaN
# 7n_surround    [21676, 21677, 21878, 21879, 21880, 22081, 220...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround   [38926, 38927, 39129, 39130, 39332, 39333, 393...
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [12306, 12307, 12308, 12309, 12310, 12311, 125...
# VLL_surround   [10480, 10481, 10482, 10483, 10484, 10485, 106...
# bg             [202, 404, 405, 607, 608, 809, 810, 811, 1011,...
# sp5                                                          NaN
# sp5_surround   [34208, 34209, 34410, 34411, 34613, 34614, 348...
#
#                                                              307  \
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround    [19003, 19205, 19206, 19207, 19408, 19409, 194...
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround    [27567, 27769, 27770, 27971, 27972, 27973, 281...
# 7n                                                           NaN
# 7n_surround    [21676, 21677, 21878, 21879, 21880, 22081, 220...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround   [38926, 38927, 39129, 39130, 39332, 39333, 393...
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [12506, 12507, 12508, 12509, 12513, 12708, 127...
# VLL_surround   [10679, 10680, 10681, 10682, 10879, 10880, 108...
# bg             [607, 608, 810, 811, 1012, 1013, 1014, 1213, 1...
# sp5                                                          NaN
# sp5_surround   [34208, 34209, 34410, 34411, 34613, 34614, 348...
#
#                                                              308
# 12N                                                          NaN
# 12N_surround                                                 NaN
# 5N                                                           NaN
# 5N_surround                                                  NaN
# 6N                                                           NaN
# 6N_surround                                                  NaN
# 7N                                                           NaN
# 7N_surround    [27567, 27769, 27770, 27971, 27972, 27973, 281...
# 7n                                                           NaN
# 7n_surround    [21676, 21677, 21878, 21879, 21880, 22081, 220...
# AP                                                           NaN
# AP_surround                                                  NaN
# Amb                                                          NaN
# Amb_surround                                                 NaN
# LC                                                           NaN
# LC_surround                                                  NaN
# LRt                                                          NaN
# LRt_surround   [38926, 38927, 39129, 39130, 39332, 39333, 393...
# Pn                                                           NaN
# Pn_surround                                                  NaN
# R                                                            NaN
# R_surround                                                   NaN
# RtTg                                                         NaN
# RtTg_surround                                                NaN
# Tz                                                           NaN
# Tz_surround                                                  NaN
# VLL            [12707, 12708, 12709, 12710, 12711, 12712, 127...
# VLL_surround   [10879, 10880, 10881, 10882, 10883, 10884, 108...
# bg             [1013, 1014, 1214, 1215, 1216, 1217, 1416, 141...
# sp5                                                          NaN
# sp5_surround   [34208, 34209, 34410, 34411, 34613, 34614, 348...
#
# [31 rows x 173 columns]

# %%
patch_dir = '/oasis/projects/nsf/csd395/yuncong/CSHL_data_patches/'
table_filepath = os.path.join(patch_dir, '%(stack)s_indices_allLandmarks_allSections.h5'%{'stack':stack})
indices_allLandmarks_allSections_df.to_hdf(table_filepath, 'indices_allLandmarks_allSections')
pd.Series([patch_size, stride, w, h]).to_hdf(table_filepath, 'grid_parameters')
# Out:
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/pandas/core/generic.py:939: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->[108, 110, 112, 114, 116, 118, 132, 134, 136, 138, 140, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 254, 256, 257, 258, 259, 260, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 306, 307, 308]]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
# sync with workstation

workstation_patch_dir = '/home/yuncong/CSHL_data_patches'
cmd = 'scp %(fn)s yuncong@132.239.73.151:%(dest)s' % {'fn': table_filepath, 'dest': workstation_patch_dir}
os.system(cmd)
# Out:
# 0
