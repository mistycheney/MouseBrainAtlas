# %%
# %reload_ext autoreload
# %autoreload 2

import os
import sys
import time
import cv2

sys.path.append(os.path.join(os.environ['REPO_DIR'], 'utilities'))
from utilities2015 import *

from collections import defaultdict

from enum import Enum
    
class PolygonType(Enum):
    CLOSED = 'closed'
    OPEN = 'open'
    TEXTURE = 'textured'
    TEXTURE_WITH_CONTOUR = 'texture with contour'
    DIRECTION = 'directionality'

# %%
stack = 'MD589'
# stack = 'MD594'

first, last = section_range_lookup[stack]

# %%
labels_merge_map = {'SolM': 'Sol'}

# %%
label_polygons = defaultdict(lambda: {})

for sec in range(first, last+1):
    
    dm = DataManager(stack=stack, section=sec)
    
    try:
        res = dm.load_proposal_review_result(None, 'latest', 'consolidated')
    except:
        continue
    
    if res is None:
        continue

    print sec

    usr, ts, suffix, result = res
    
    for props in result:
        label = props['label']
        if label in labels_merge_map:
            label = labels_merge_map[label]
        label_polygons[label][sec] = np.array(props['vertices']).astype(np.int)
    
label_polygons.default_factory = None
# Out:
# 110
# 111
# 113
# 115
# 117
# 119
# 121
# 123
# 125
# 127
# 129
# 131
# 133
# 135
# 137
# 139
# 141
# 143
# 145
# 147
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 318
# 320
# 322
# 323
# 325
# 327
# 329
# 331
# 333
# 335
# 337
# 339
# 341
# 343
# 345
# 347
# 349
# 351

# %%
import pandas as pd

label_polygons_df = pd.DataFrame(label_polygons)
label_polygons_df.to_hdf('/home/yuncong/Brain/database/'+stack+'_label_polygons.h5', 'label_polygons')
# Out:
# /oasis/projects/nsf/csd181/yuncong/virtualenv-1.9.1/yuncongve/lib/python2.7/site-packages/pandas/core/generic.py:939: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->['10N', '12N', '3N', '4N', '5N', '5TT', '6N', '7N', '7n', '9N', 'AP', 'Amb', 'CC', 'CereNuc', 'DC', 'DTgP', 'Gr', 'IO', 'LC', 'LDTg', 'LM1C', 'LM1R', 'LRt', 'LSO', 'LVe', 'MVe', 'MVePC', 'Nuc1', 'Pn', 'PnO', 'Pr5', 'Pr5DM', 'Pr5VL', 'PrVd', 'PrVv', 'R', 'RtTg', 'Sol', 'Sp5C', 'Sp5I', 'Sp5O', 'SuVe', 'Tz', 'UDF', 'VCA', 'VCP', 'VIpp', 'VLL', 'VMu', 'VOra', 'VOri', 'VOrp', 'VTg', 'Vcd', 'dtgx', 'mlf', 'pyx', 'scp', 'sp5', 'vtgx']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
