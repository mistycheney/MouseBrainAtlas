# %%
# Aligns a score volume with an annotation volume

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

import sys
import os

sys.path.append(os.environ['REPO_DIR'] + '/utilities')
from utilities2015 import *
from registration_utilities import *

import matplotlib.pyplot as plt
# %matplotlib inline

from joblib import Parallel, delayed
import time

import logging

# %%
volume_dir = '/oasis/projects/nsf/csd395/yuncong/CSHL_volumes/'

# %%
labels_twoSides = []
labels_twoSides_indices = {}
with open(volume_dir + '/MD589/volume_MD589_annotation_withOuterContour_labelIndices.txt', 'r') as f:
    lines = f.readlines()
    for line in lines:
        name, index = line.split()
        labels_twoSides.append(name)
        labels_twoSides_indices[name] = int(index)
        
labelMap_sidedToUnsided = {name: name if '_' not in name else name[:-2] for name in labels_twoSides_indices.keys()}
labels_unsided = ['BackG'] + sorted(set(labelMap_sidedToUnsided.values()) - {'BackG', 'outerContour'}) + ['outerContour']
labels_unsided_indices = dict((j, i) for i, j in enumerate(labels_unsided))

from collections import defaultdict

labelMap_unsidedToSided = defaultdict(list)
for name_sided, name_unsided in labelMap_sidedToUnsided.iteritems():
    labelMap_unsidedToSided[name_unsided].append(name_sided)
labelMap_unsidedToSided.default_factory = None

# %%
atlas_volume = bp.unpack_ndarray_file(os.path.join(volume_dir, 'MD589/volume_MD589_annotation_withOuterContour.bp'))

atlas_ydim, atlas_xdim, atlas_zdim = atlas_volume.shape
atlas_centroid = np.array([.5*atlas_xdim, .5*atlas_ydim, .5*atlas_zdim])
print atlas_centroid
# Out:
# [ 419.   229.5  267. ]

# %%
def parallel_where(name, num_samples=None):
    
    w = np.where(atlas_volume == labels_twoSides_indices[name])
    
    if num_samples is not None:
        n = len(w[0])
        sample_indices = np.random.choice(range(n), min(num_samples, n), replace=False)
        return np.c_[w[1][sample_indices].astype(np.int16), 
                     w[0][sample_indices].astype(np.int16), 
                     w[2][sample_indices].astype(np.int16)]
    else:
        return np.c_[w[1].astype(np.int16), w[0].astype(np.int16), w[2].astype(np.int16)]

t = time.time()

atlas_nzs = Parallel(n_jobs=16)(delayed(parallel_where)(name, num_samples=int(1e5)) for name in labels_twoSides[1:])

atlas_nzs = {name: nzs for name, nzs in zip(labels_twoSides[1:], atlas_nzs)}

sys.stderr.write('load atlas: %f seconds\n' % (time.time() - t)) #~ 7s
# Out:
# load atlas: 7.055487 seconds

# %%
# atlas_nzs_full = Parallel(n_jobs=16)(delayed(parallel_where)(name) for name in labels_twoSides[1:])
# atlas_nzs_full = {name: nzs for name, nzs in zip(labels_twoSides[1:], atlas_nzs_full)}

# %%
downsample_factor = 16

section_thickness = 20 # in um
xy_pixel_distance_lossless = 0.46
xy_pixel_distance_tb = xy_pixel_distance_lossless * 32 # in um, thumbnail

xy_pixel_distance_downsampled = xy_pixel_distance_lossless * downsample_factor
z_xy_ratio_downsampled = section_thickness / xy_pixel_distance_downsampled

# %%
atlasAlignOptLogs_dir = create_if_not_exists('/oasis/projects/nsf/csd395/yuncong/CSHL_atlasAlignOptLogs')
atlasAlignParams_dir = create_if_not_exists('/oasis/projects/nsf/csd395/yuncong/CSHL_atlasAlignParams')
annotationsViz_rootdir = '/oasis/projects/nsf/csd395/yuncong/CSHL_annotaionsPojectedViz'

# %%
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# %%
pts_centered = {name: (np.concatenate([atlas_nzs[n] for n in labelMap_unsidedToSided[name]]) - atlas_centroid).astype(np.int16) 
                         for name in labels_unsided[1:]}

# %%
label_weights = {name: .1 if name == 'outerContour' else 1. for name in labels_unsided[1:]}

# %%
def compute_score_and_gradient(T):
    global pts_centered
    
    score = 0
    dMdA = np.zeros((12,))
    
    for name in labels_unsided[1:]:
#         t1 = time.time()
    
        pts_prime = transform_points(T, pts_centered=pts_centered[name], c_prime=test_centroid)
        
        xs_prime, ys_prime, zs_prime = pts_prime.T.astype(np.int16)

        valid = (xs_prime >= 0) & (ys_prime >= 0) & (zs_prime >= 0) & \
                (xs_prime < test_xdim) & (ys_prime < test_ydim) & (zs_prime < test_zdim)
                   
        if np.count_nonzero(valid) > 0:

            xs_prime_valid = xs_prime[valid]
            ys_prime_valid = ys_prime[valid]
            zs_prime_valid = zs_prime[valid]
            
            voxel_probs_valid = volume2_allLabels[name][ys_prime_valid, xs_prime_valid, zs_prime_valid] / 1e4

            score += label_weights[name] * voxel_probs_valid.sum()
            
            Sx = dSdxyz[name][0, ys_prime_valid, xs_prime_valid, zs_prime_valid]
            Sy = dSdxyz[name][1, ys_prime_valid, xs_prime_valid, zs_prime_valid]
            Sz = dSdxyz[name][2, ys_prime_valid, xs_prime_valid, zs_prime_valid]
            
            dxs, dys, dzs = pts_centered[name][valid].T

            q = np.c_[Sx*dxs, Sx*dys, Sx*dzs, Sx, 
                          Sy*dxs, Sy*dys, Sy*dzs, Sy,
                          Sz*dxs, Sz*dys, Sz*dzs, Sz]        
            
            dMdA += label_weights[name] * q.sum(axis=0)
            
            del voxel_probs_valid, q, Sx, Sy, Sz, dxs, dys, dzs, xs_prime_valid, ys_prime_valid, zs_prime_valid
        
#         sys.stderr.write('########### %s: %f seconds\n' % (labels[l], time.time() - t1))
        
        del valid, xs_prime, ys_prime, zs_prime, pts_prime
        
    return score, dMdA

# %%
def compute_score(T):
    
    score = 0
    for name in labels_unsided[1:]:
        
        pts_prime = transform_points(T, pts_centered=pts_centered[name], c_prime=test_centroid)
    
        xs_prime, ys_prime, zs_prime = pts_prime.T.astype(np.int16)
        
        valid = (xs_prime >= 0) & (ys_prime >= 0) & (zs_prime >= 0) & \
            (xs_prime < test_xdim) & (ys_prime < test_ydim) & (zs_prime < test_zdim)
            
        voxel_probs_valid = volume2_allLabels[name][ys_prime[valid], xs_prime[valid], zs_prime[valid]] / 1e4

        score += label_weights[name] * voxel_probs_valid.sum()
                
        del voxel_probs_valid, valid, xs_prime, ys_prime, zs_prime, pts_prime
                
    return score

def compute_score_gradient(T):

    dMdA = np.zeros((12,))

    for name in labels_unsided[1:]:
#       
        pts_prime = transform_points(T, pts_centered=pts_centered[name], c_prime=test_centroid)

        xs_prime, ys_prime, zs_prime = pts_prime.T.astype(np.int16)

        valid = (xs_prime >= 0) & (ys_prime >= 0) & (zs_prime >= 0) & \
            (xs_prime < test_xdim) & (ys_prime < test_ydim) & (zs_prime < test_zdim)
            
        if np.count_nonzero(valid) > 0:
            
            xs_prime_valid = xs_prime[valid]
            ys_prime_valid = ys_prime[valid]
            zs_prime_valid = zs_prime[valid]
            
            Sx = dSdxyz[name][0, ys_prime_valid, xs_prime_valid, zs_prime_valid]
            Sy = dSdxyz[name][1, ys_prime_valid, xs_prime_valid, zs_prime_valid]
            Sz = dSdxyz[name][2, ys_prime_valid, xs_prime_valid, zs_prime_valid]
               
            dxs, dys, dzs = pts_centered[name][valid].T
                        
            dMdA += label_weights[name] * np.c_[Sx*dxs, Sx*dys, Sx*dzs, Sx, 
                          Sy*dxs, Sy*dys, Sy*dzs, Sy,
                          Sz*dxs, Sz*dys, Sz*dzs, Sz].sum(axis=0)
            
    return dMdA

# %%
stack = 'MD594'

# %%
################# LOAD TEST VOLUME ######################

section_bs_begin, section_bs_end = section_range_lookup[stack]
print section_bs_begin, section_bs_end

(volume_xmin, volume_xmax, volume_ymin, volume_ymax, volume_zmin, volume_zmax) = \
np.loadtxt(os.path.join(volume_dir, '%(stack)s/%(stack)s_scoreVolume_limits.txt' % {'stack': stack}), dtype=np.int)

map_z_to_section = {}
for s in range(section_bs_begin, section_bs_end+1):
    for z in range(int(z_xy_ratio_downsampled*s) - volume_zmin, int(z_xy_ratio_downsampled*(s+1)) - volume_zmin + 1):
        map_z_to_section[z] = s


volume2_allLabels = {}

for name in labels_unsided:

    if name == 'BackG':
        continue

    volume2_roi = bp.unpack_ndarray_file(os.path.join(volume_dir, '%(stack)s/%(stack)s_scoreVolume_%(label)s.bp' % \
                                                      {'stack': stack, 'label': name})).astype(np.float16)
    volume2_allLabels[name] = volume2_roi
    del volume2_roi

test_ydim, test_xdim, test_zdim = volume2_allLabels.values()[0].shape
test_centroid = np.array([.5*test_xdim, .5*test_ydim, .5*test_zdim])

print test_xdim, test_ydim, test_zdim
print test_centroid

# test_xdim = volume_xmax - volume_xmin + 1
# test_ydim = volume_ymax - volume_ymin + 1
# test_zdim = volume_zmax - volume_zmin + 1

###################### Load Gradient #####################

dSdxyz = {name: np.empty((3, test_ydim, test_xdim, test_zdim), dtype=np.float16) for name in labels_unsided[1:]}

t1 = time.time()

for name in labels_unsided:

    if name == 'BackG':
        continue

    t = time.time()

    dSdxyz[name][0] = bp.unpack_ndarray_file(volume_dir + '/%(stack)s/%(stack)s_scoreVolume_%(label)s_gx.bp' % {'stack':stack, 'label':name})
    dSdxyz[name][1] = bp.unpack_ndarray_file(volume_dir + '/%(stack)s/%(stack)s_scoreVolume_%(label)s_gy.bp' % {'stack':stack, 'label':name})
    dSdxyz[name][2] = bp.unpack_ndarray_file(volume_dir + '/%(stack)s/%(stack)s_scoreVolume_%(label)s_gz.bp' % {'stack':stack, 'label':name})

    sys.stderr.write('load gradient %s: %f seconds\n' % (name, time.time() - t))

sys.stderr.write('overall: %f seconds\n' % (time.time() - t1)) # 140s
# Out:
# 93 364
# 844
# load gradient 12N: 5.484035 seconds
# load gradient 5N: 6.940750 seconds
# load gradient 6N: 5.883514 seconds
# load gradient 7N: 6.698527 seconds
# load gradient 7n: 5.487856 seconds
# load gradient AP: 5.461054 seconds
# load gradient Amb: 5.355412 seconds
# load gradient LC: 6.452136 seconds
# load gradient LRt: 6.066488 seconds
# load gradient Pn: 6.762748 seconds
# load gradient R: 6.241635 seconds
# load gradient RtTg: 7.202044 seconds
# load gradient Tz: 5.602598 seconds
# load gradient VLL: 6.871995 seconds
# load gradient sp5: 5.807950 seconds
# load gradient outerContour: 6.142578 seconds
#  484 443
# [ 422.   242.   221.5]
# overall: 98.468625 seconds

# %%
handler = logging.FileHandler(atlasAlignOptLogs_dir + '/%(stack)s_atlasAlignOpt.log' % {'stack': stack})
handler.setLevel(logging.INFO)
logger.addHandler(handler)

################# GRID SEARCH ######################

grid_search_iteration_number = 10
# grid_search_iteration_number = 1

params_best_upToNow = (0, 0, 0)
score_best_upToNow = 0

init_n = 1000

for iteration in range(grid_search_iteration_number):

    logger.info('grid search iteration %d', iteration)

    init_tx, init_ty, init_tz  = params_best_upToNow

    n = int(init_n*np.exp(-iteration/3.))

    sigma_tx = 300*np.exp(-iteration/3.)
    sigma_ty = 300*np.exp(-iteration/3.)
    sigma_tz = 100*np.exp(-iteration/3.)

    tx_grid = init_tx + sigma_tx * (2 * np.random.random(n) - 1)
    ty_grid = init_ty + sigma_ty * (2 * np.random.random(n) - 1)
    tz_grid = init_tz + sigma_tz * (2 * np.random.random(n) - 1)

    samples = np.c_[tx_grid, ty_grid, tz_grid]

    import time

    t = time.time()
    # num jobs * memory each job
    
    scores = Parallel(n_jobs=8)(delayed(compute_score)(np.array([1, 0, 0, tx, 0, 1, 0, ty, 0, 0, 1, tz]))
                                 for tx, ty, tz in samples)

#     scores = []
#     for tx, ty, tz in samples:
#         scores.append(compute_score([1, 0, 0, tx, 0, 1, 0, ty, 0, 0, 1, tz]))

    sys.stderr.write('grid search: %f seconds\n' % (time.time() - t)) # ~23s
    
    score_best = np.max(scores)

    tx_best, ty_best, tz_best = samples[np.argmax(scores)]

    if score_best > score_best_upToNow:
        logger.info('%f %f', score_best_upToNow, score_best)

        score_best_upToNow = score_best
        params_best_upToNow = tx_best, ty_best, tz_best

        logger.info('%f %f %f', tx_best, ty_best, tz_best)
    
    logger.info('\n')
# Out:
# INFO:__main__:grid search iteration 0
# grid search: 23.652536 seconds
# INFO:__main__:0.000000 22.896895
# INFO:__main__:72.163303 -2.333709 4.358628
# INFO:__main__:
#
# INFO:__main__:grid search iteration 1
# grid search: 19.867429 seconds
# INFO:__main__:22.896895 31.645752
# INFO:__main__:52.958007 -13.982644 -3.264277
# INFO:__main__:
#
# INFO:__main__:grid search iteration 2
# grid search: 15.752052 seconds
# INFO:__main__:31.645752 32.950571
# INFO:__main__:57.643631 -2.465972 -1.885419
# INFO:__main__:
#
# INFO:__main__:grid search iteration 3
# grid search: 11.736301 seconds
# INFO:__main__:
#
# INFO:__main__:grid search iteration 4
# grid search: 8.945194 seconds
# INFO:__main__:32.950571 34.997639
# INFO:__main__:42.691690 -8.521901 -10.018324
# INFO:__main__:
#
# INFO:__main__:grid search iteration 5
# grid search: 6.705439 seconds
# INFO:__main__:34.997639 37.114959
# INFO:__main__:49.579430 0.540843 -6.979395
# INFO:__main__:
#
# INFO:__main__:grid search iteration 6
# grid search: 5.046976 seconds
# INFO:__main__:
#
# INFO:__main__:grid search iteration 7
# grid search: 4.009434 seconds
# INFO:__main__:37.114959 37.223110
# INFO:__main__:45.401065 -0.725582 -6.711479
# INFO:__main__:
#
# INFO:__main__:grid search iteration 8
# grid search: 3.015363 seconds
# INFO:__main__:
#
# INFO:__main__:grid search iteration 9
# grid search: 2.532455 seconds
# INFO:__main__:

# %%
################# GRADIENT DESCENT ######################

lr1, lr2 = (10., 1e-1)
# lr1, lr2 = (1., 1e-3)

# auto_corr = .95

max_iter_num = 1000
fudge_factor = 1e-6 #for numerical stability
dMdA_historical = np.zeros((12,))

tx_best, ty_best, tz_best = params_best_upToNow
T_best = np.r_[1,0,0, tx_best, 0,1,0, ty_best, 0,0,1, tz_best]

lr = np.array([lr2, lr2, lr2, lr1, lr2, lr2, lr2, lr1, lr2, lr2, lr2, lr1])

score_best = 0

scores = []

for iteration in range(max_iter_num):

    logger.info('iteration %d', iteration)

#     t = time.time()
    s, dMdA = compute_score_and_gradient(T_best)
#     sys.stderr.write('compute_score_and_gradient: %f seconds\n' % (time.time() - t)) #~ 2s/iteration or ~.5s: 1e5 samples per landmark

    dMdA_historical += dMdA**2
#     dMdA_historical = auto_corr * dMdA_historical + (1-auto_corr) * dMdA**2

    dMdA_adjusted = dMdA / (fudge_factor + np.sqrt(dMdA_historical))

    T_best += lr*dMdA_adjusted

#         logger.info('A: ' + ' '.join(['%f']*12) % tuple(A_best))
#         logger.info('dMdA adjusted: ' + ' '.join(['%f']*12) % tuple(dMdA_adjusted))

    logger.info('score: %f', s)
    scores.append(s)

    logger.info('\n')

    history_len = 50
    if iteration > 100:
        if np.abs(np.mean(scores[iteration-history_len:iteration]) - \
                  np.mean(scores[iteration-2*history_len:iteration-history_len])) < 1e-1:
            break

    if s > score_best:
#             logger.info('Current best')
        best_gradient_descent_params = T_best
        score_best = s

    np.save(atlasAlignOptLogs_dir + '/%(stack)s_scoreEvolutions.npy' % {'stack':stack}, scores)

plt.plot(scores);
# Out:
# INFO:__main__:iteration 0
# INFO:__main__:score: 37.223110
# INFO:__main__:
#
# INFO:__main__:iteration 1
# INFO:__main__:score: 19.423907
# INFO:__main__:
#
# INFO:__main__:iteration 2
# INFO:__main__:score: 14.992588
# INFO:__main__:
#
# INFO:__main__:iteration 3
# INFO:__main__:score: 35.149701
# INFO:__main__:
#
# INFO:__main__:iteration 4
# INFO:__main__:score: 43.225993
# INFO:__main__:
#
# INFO:__main__:iteration 5
# INFO:__main__:score: 31.121026
# INFO:__main__:
#
# INFO:__main__:iteration 6
# INFO:__main__:score: 54.053836
# INFO:__main__:
#
# INFO:__main__:iteration 7
# INFO:__main__:score: 44.242153
# INFO:__main__:
#
# INFO:__main__:iteration 8
# INFO:__main__:score: 42.196761
# INFO:__main__:
#
# INFO:__main__:iteration 9
# INFO:__main__:score: 51.080771
# INFO:__main__:
#
# INFO:__main__:iteration 10
# INFO:__main__:score: 56.038654
# INFO:__main__:
#
# INFO:__main__:iteration 11
# INFO:__main__:score: 46.065938
# INFO:__main__:
#
# INFO:__main__:iteration 12
# INFO:__main__:score: 61.802275
# INFO:__main__:
#
# INFO:__main__:iteration 13
# INFO:__main__:score: 63.131404
# INFO:__main__:
#
# INFO:__main__:iteration 14
# INFO:__main__:score: 61.255308
# INFO:__main__:
#
# INFO:__main__:iteration 15
# INFO:__main__:score: 67.552678
# INFO:__main__:
#
# INFO:__main__:iteration 16
# INFO:__main__:score: 60.330257
# INFO:__main__:
#
# INFO:__main__:iteration 17
# INFO:__main__:score: 64.601785
# INFO:__main__:
#
# INFO:__main__:iteration 18
# INFO:__main__:score: 67.134451
# INFO:__main__:
#
# INFO:__main__:iteration 19
# INFO:__main__:score: 65.039877
# INFO:__main__:
#
# INFO:__main__:iteration 20
# INFO:__main__:score: 71.294993
# INFO:__main__:
#
# INFO:__main__:iteration 21
# INFO:__main__:score: 69.289633
# INFO:__main__:
#
# INFO:__main__:iteration 22
# INFO:__main__:score: 71.253702
# INFO:__main__:
#
# INFO:__main__:iteration 23
# INFO:__main__:score: 70.120624
# INFO:__main__:
#
# INFO:__main__:iteration 24
# INFO:__main__:score: 72.230338
# INFO:__main__:
#
# INFO:__main__:iteration 25
# INFO:__main__:score: 72.090222
# INFO:__main__:
#
# INFO:__main__:iteration 26
# INFO:__main__:score: 72.084290
# INFO:__main__:
#
# INFO:__main__:iteration 27
# INFO:__main__:score: 70.943469
# INFO:__main__:
#
# INFO:__main__:iteration 28
# INFO:__main__:score: 72.070898
# INFO:__main__:
#
# INFO:__main__:iteration 29
# INFO:__main__:score: 73.491638
# INFO:__main__:
#
# INFO:__main__:iteration 30
# INFO:__main__:score: 74.587268
# INFO:__main__:
#
# INFO:__main__:iteration 31
# INFO:__main__:score: 74.390527
# INFO:__main__:
#
# INFO:__main__:iteration 32
# INFO:__main__:score: 75.958167
# INFO:__main__:
#
# INFO:__main__:iteration 33
# INFO:__main__:score: 75.951636
# INFO:__main__:
#
# INFO:__main__:iteration 34
# INFO:__main__:score: 76.420056
# INFO:__main__:
#
# INFO:__main__:iteration 35
# INFO:__main__:score: 76.852612
# INFO:__main__:
#
# INFO:__main__:iteration 36
# INFO:__main__:score: 76.989783
# INFO:__main__:
#
# INFO:__main__:iteration 37
# INFO:__main__:score: 77.382227
# INFO:__main__:
#
# INFO:__main__:iteration 38
# INFO:__main__:score: 77.370569
# INFO:__main__:
#
# INFO:__main__:iteration 39
# INFO:__main__:score: 77.935474
# INFO:__main__:
#
# INFO:__main__:iteration 40
# INFO:__main__:score: 77.979333
# INFO:__main__:
#
# INFO:__main__:iteration 41
# INFO:__main__:score: 78.509277
# INFO:__main__:
#
# INFO:__main__:iteration 42
# INFO:__main__:score: 78.469958
# INFO:__main__:
#
# INFO:__main__:iteration 43
# INFO:__main__:score: 78.887256
# INFO:__main__:
#
# INFO:__main__:iteration 44
# INFO:__main__:score: 78.982471
# INFO:__main__:
#
# INFO:__main__:iteration 45
# INFO:__main__:score: 79.163086
# INFO:__main__:
#
# INFO:__main__:iteration 46
# INFO:__main__:score: 79.377161
# INFO:__main__:
#
# INFO:__main__:iteration 47
# INFO:__main__:score: 79.424438
# INFO:__main__:
#
# INFO:__main__:iteration 48
# INFO:__main__:score: 79.645691
# INFO:__main__:
#
# INFO:__main__:iteration 49
# INFO:__main__:score: 79.649756
# INFO:__main__:
#
# INFO:__main__:iteration 50
# INFO:__main__:score: 79.882495
# INFO:__main__:
#
# INFO:__main__:iteration 51
# INFO:__main__:score: 79.846509
# INFO:__main__:
#
# INFO:__main__:iteration 52
# INFO:__main__:score: 80.140405
# INFO:__main__:
#
# INFO:__main__:iteration 53
# INFO:__main__:score: 80.013794
# INFO:__main__:
#
# INFO:__main__:iteration 54
# INFO:__main__:score: 80.317554
# INFO:__main__:
#
# INFO:__main__:iteration 55
# INFO:__main__:score: 80.193408
# INFO:__main__:
#
# INFO:__main__:iteration 56
# INFO:__main__:score: 80.535059
# INFO:__main__:
#
# INFO:__main__:iteration 57
# INFO:__main__:score: 80.403882
# INFO:__main__:
#
# INFO:__main__:iteration 58
# INFO:__main__:score: 80.700269
# INFO:__main__:
#
# INFO:__main__:iteration 59
# INFO:__main__:score: 80.635571
# INFO:__main__:
#
# INFO:__main__:iteration 60
# INFO:__main__:score: 80.858911
# INFO:__main__:
#
# INFO:__main__:iteration 61
# INFO:__main__:score: 80.810645
# INFO:__main__:
#
# INFO:__main__:iteration 62
# INFO:__main__:score: 81.033618
# INFO:__main__:
#
# INFO:__main__:iteration 63
# INFO:__main__:score: 80.960522
# INFO:__main__:
#
# INFO:__main__:iteration 64
# INFO:__main__:score: 81.132935
# INFO:__main__:
#
# INFO:__main__:iteration 65
# INFO:__main__:score: 81.035327
# INFO:__main__:
#
# INFO:__main__:iteration 66
# INFO:__main__:score: 81.205493
# INFO:__main__:
#
# INFO:__main__:iteration 67
# INFO:__main__:score: 81.104443
# INFO:__main__:
#
# INFO:__main__:iteration 68
# INFO:__main__:score: 81.277832
# INFO:__main__:
#
# INFO:__main__:iteration 69
# INFO:__main__:score: 81.167456
# INFO:__main__:
#
# INFO:__main__:iteration 70
# INFO:__main__:score: 81.320776
# INFO:__main__:
#
# INFO:__main__:iteration 71
# INFO:__main__:score: 81.198877
# INFO:__main__:
#
# INFO:__main__:iteration 72
# INFO:__main__:score: 81.334058
# INFO:__main__:
#
# INFO:__main__:iteration 73
# INFO:__main__:score: 81.236719
# INFO:__main__:
#
# INFO:__main__:iteration 74
# INFO:__main__:score: 81.359668
# INFO:__main__:
#
# INFO:__main__:iteration 75
# INFO:__main__:score: 81.264868
# INFO:__main__:
#
# INFO:__main__:iteration 76
# INFO:__main__:score: 81.369409
# INFO:__main__:
#
# INFO:__main__:iteration 77
# INFO:__main__:score: 81.304883
# INFO:__main__:
#
# INFO:__main__:iteration 78
# INFO:__main__:score: 81.389282
# INFO:__main__:
#
# INFO:__main__:iteration 79
# INFO:__main__:score: 81.316553
# INFO:__main__:
#
# INFO:__main__:iteration 80
# INFO:__main__:score: 81.383179
# INFO:__main__:
#
# INFO:__main__:iteration 81
# INFO:__main__:score: 81.329395
# INFO:__main__:
#
# INFO:__main__:iteration 82
# INFO:__main__:score: 81.402222
# INFO:__main__:
#
# INFO:__main__:iteration 83
# INFO:__main__:score: 81.333862
# INFO:__main__:
#
# INFO:__main__:iteration 84
# INFO:__main__:score: 81.407080
# INFO:__main__:
#
# INFO:__main__:iteration 85
# INFO:__main__:score: 81.336450
# INFO:__main__:
#
# INFO:__main__:iteration 86
# INFO:__main__:score: 81.428809
# INFO:__main__:
#
# INFO:__main__:iteration 87
# INFO:__main__:score: 81.357275
# INFO:__main__:
#
# INFO:__main__:iteration 88
# INFO:__main__:score: 81.445020
# INFO:__main__:
#
# INFO:__main__:iteration 89
# INFO:__main__:score: 81.359668
# INFO:__main__:
#
# INFO:__main__:iteration 90
# INFO:__main__:score: 81.434277
# INFO:__main__:
#
# INFO:__main__:iteration 91
# INFO:__main__:score: 81.372974
# INFO:__main__:
#
# INFO:__main__:iteration 92
# INFO:__main__:score: 81.434399
# INFO:__main__:
#
# INFO:__main__:iteration 93
# INFO:__main__:score: 81.354907
# INFO:__main__:
#
# INFO:__main__:iteration 94
# INFO:__main__:score: 81.401294
# INFO:__main__:
#
# INFO:__main__:iteration 95
# INFO:__main__:score: 81.376343
# INFO:__main__:
#
# INFO:__main__:iteration 96
# INFO:__main__:score: 81.414355
# INFO:__main__:
#
# INFO:__main__:iteration 97
# INFO:__main__:score: 81.342651
# INFO:__main__:
#
# INFO:__main__:iteration 98
# INFO:__main__:score: 81.421680
# INFO:__main__:
#
# INFO:__main__:iteration 99
# INFO:__main__:score: 81.369995
# INFO:__main__:
#
# INFO:__main__:iteration 100
# INFO:__main__:score: 81.409473
# INFO:__main__:
#
# INFO:__main__:iteration 101
# INFO:__main__:score: 81.381592
# INFO:__main__:
#
# INFO:__main__:iteration 102
# INFO:__main__:score: 81.407397
# INFO:__main__:
#
# INFO:__main__:iteration 103
# INFO:__main__:score: 81.368530
# INFO:__main__:
#
# INFO:__main__:iteration 104
# INFO:__main__:score: 81.445605
# INFO:__main__:
#
# INFO:__main__:iteration 105
# INFO:__main__:score: 81.387891
# INFO:__main__:
#
# INFO:__main__:iteration 106
# INFO:__main__:score: 81.418262
# INFO:__main__:
#
# INFO:__main__:iteration 107
# INFO:__main__:score: 81.358716
# INFO:__main__:
#
# INFO:__main__:iteration 108
# INFO:__main__:score: 81.425952
# INFO:__main__:
#
# INFO:__main__:iteration 109
# INFO:__main__:score: 81.387939
# INFO:__main__:
#
# INFO:__main__:iteration 110
# INFO:__main__:score: 81.442310
# INFO:__main__:
#
# INFO:__main__:iteration 111
# INFO:__main__:score: 81.362549
# INFO:__main__:
#
# INFO:__main__:iteration 112
# INFO:__main__:score: 81.422778
# INFO:__main__:
#
# INFO:__main__:iteration 113
# INFO:__main__:score: 81.387573
# INFO:__main__:
#
# INFO:__main__:iteration 114
# INFO:__main__:score: 81.433276
# INFO:__main__:
#
# INFO:__main__:iteration 115
# INFO:__main__:score: 81.369092
# INFO:__main__:
#
# INFO:__main__:iteration 116
# INFO:__main__:score: 81.427173
# INFO:__main__:
#
# INFO:__main__:iteration 117
# INFO:__main__:score: 81.383667
# INFO:__main__:
#
# INFO:__main__:iteration 118
# INFO:__main__:score: 81.425586
# INFO:__main__:
#
# INFO:__main__:iteration 119
# INFO:__main__:score: 81.372461
# INFO:__main__:
#
# INFO:__main__:iteration 120
# INFO:__main__:score: 81.427905
# INFO:__main__:
#
# INFO:__main__:iteration 121
# INFO:__main__:score: 81.384790
# INFO:__main__:
#
# INFO:__main__:iteration 122
# INFO:__main__:score: 81.430957
# INFO:__main__:
#
# INFO:__main__:iteration 123
# INFO:__main__:score: 81.378857
# INFO:__main__:
#
# INFO:__main__:iteration 124
# INFO:__main__:score: 81.441455
# INFO:__main__:
#
# INFO:__main__:iteration 125
# INFO:__main__:score: 81.367383
# INFO:__main__:
#
# INFO:__main__:iteration 126
# INFO:__main__:score: 81.430347
# INFO:__main__:
#
# INFO:__main__:iteration 127
# INFO:__main__:score: 81.394678
# INFO:__main__:
#
# INFO:__main__:iteration 128
# INFO:__main__:score: 81.441089
# INFO:__main__:
#
# INFO:__main__:iteration 129
# INFO:__main__:score: 81.373193
# INFO:__main__:
#
# INFO:__main__:iteration 130
# INFO:__main__:score: 81.420093
# INFO:__main__:
#
# INFO:__main__:iteration 131
# INFO:__main__:score: 81.376074
# INFO:__main__:
#
# INFO:__main__:iteration 132
# INFO:__main__:score: 81.442065
# INFO:__main__:
#
# INFO:__main__:iteration 133
# INFO:__main__:score: 81.381201
# INFO:__main__:
#
# INFO:__main__:iteration 134
# INFO:__main__:score: 81.435474
# INFO:__main__:
#
# INFO:__main__:iteration 135
# INFO:__main__:score: 81.393408
# INFO:__main__:
#
# INFO:__main__:iteration 136
# INFO:__main__:score: 81.431934
# INFO:__main__:
#
# INFO:__main__:iteration 137
# INFO:__main__:score: 81.406836
# INFO:__main__:
#
# INFO:__main__:iteration 138
# INFO:__main__:score: 81.435718
# INFO:__main__:
#
# INFO:__main__:iteration 139
# INFO:__main__:score: 81.374731
# INFO:__main__:
#
# INFO:__main__:iteration 140
# INFO:__main__:score: 81.439868
# INFO:__main__:
#
# INFO:__main__:iteration 141
# INFO:__main__:score: 81.402930
# INFO:__main__:
#
# INFO:__main__:iteration 142
# INFO:__main__:score: 81.423364
# INFO:__main__:
#
# INFO:__main__:iteration 143
# INFO:__main__:score: 81.408423
# INFO:__main__:
#
# INFO:__main__:iteration 144
# INFO:__main__:score: 81.454736
# INFO:__main__:
#
# INFO:__main__:iteration 145
# INFO:__main__:score: 81.394263
# INFO:__main__:
#
# INFO:__main__:iteration 146
# INFO:__main__:score: 81.443750
# INFO:__main__:
#
# INFO:__main__:iteration 147
# INFO:__main__:score: 81.394141
# INFO:__main__:
#
# INFO:__main__:iteration 148
# INFO:__main__:score: 81.458521
# INFO:__main__:
#
# INFO:__main__:iteration 149
# INFO:__main__:score: 81.400513
# INFO:__main__:
#
# INFO:__main__:iteration 150
# INFO:__main__:score: 81.449243
# INFO:__main__:
#
# INFO:__main__:iteration 151
# INFO:__main__:score: 81.420044
# INFO:__main__:
#
# INFO:__main__:iteration 152
# INFO:__main__:score: 81.468408
# INFO:__main__:
#
# INFO:__main__:iteration 153
# INFO:__main__:score: 81.419312
# INFO:__main__:
#
# INFO:__main__:iteration 154
# INFO:__main__:score: 81.448022
# INFO:__main__:
#
# INFO:__main__:iteration 155
# INFO:__main__:score: 81.403931
# INFO:__main__:
#
# INFO:__main__:iteration 156
# INFO:__main__:score: 81.466089
# INFO:__main__:
#
# INFO:__main__:iteration 157
# INFO:__main__:score: 81.401855
# INFO:__main__:
#
# INFO:__main__:iteration 158
# INFO:__main__:score: 81.453857
# INFO:__main__:
#
# INFO:__main__:iteration 159
# INFO:__main__:score: 81.406763
# INFO:__main__:
#
# INFO:__main__:iteration 160
# INFO:__main__:score: 81.450562
# INFO:__main__:
#
# INFO:__main__:iteration 161
# INFO:__main__:score: 81.413843
# INFO:__main__:
#
# INFO:__main__:iteration 162
# INFO:__main__:score: 81.470435
# INFO:__main__:
#
# INFO:__main__:iteration 163
# INFO:__main__:score: 81.398340
# INFO:__main__:
#
# INFO:__main__:iteration 164
# INFO:__main__:score: 81.469604
# INFO:__main__:
#
# INFO:__main__:iteration 165
# INFO:__main__:score: 81.396387
# INFO:__main__:
#
# INFO:__main__:iteration 166
# INFO:__main__:score: 81.460815
# INFO:__main__:
#
# INFO:__main__:iteration 167
# INFO:__main__:score: 81.400537
# INFO:__main__:
#
# INFO:__main__:iteration 168
# INFO:__main__:score: 81.477173
# INFO:__main__:
#
# INFO:__main__:iteration 169
# INFO:__main__:score: 81.409204
# INFO:__main__:
#
# INFO:__main__:iteration 170
# INFO:__main__:score: 81.474609
# INFO:__main__:
#
# INFO:__main__:iteration 171
# INFO:__main__:score: 81.396875
# INFO:__main__:
#
# INFO:__main__:iteration 172
# INFO:__main__:score: 81.475098
# INFO:__main__:
#
# INFO:__main__:iteration 173
# INFO:__main__:score: 81.425439
# INFO:__main__:
#
# INFO:__main__:iteration 174
# INFO:__main__:score: 81.478760
# INFO:__main__:
#
# INFO:__main__:iteration 175
# INFO:__main__:score: 81.408960
# INFO:__main__:
#
# INFO:__main__:iteration 176
# INFO:__main__:score: 81.467529
# INFO:__main__:
#
# INFO:__main__:iteration 177
# INFO:__main__:score: 81.410181
# INFO:__main__:
#
# INFO:__main__:iteration 178
# INFO:__main__:score: 81.444482
# INFO:__main__:
#
# INFO:__main__:iteration 179
# INFO:__main__:score: 81.415552
# INFO:__main__:
#
# INFO:__main__:iteration 180
# INFO:__main__:score: 81.455322
# INFO:__main__:
#
# INFO:__main__:iteration 181
# INFO:__main__:score: 81.429956
# INFO:__main__:
#
# INFO:__main__:iteration 182
# INFO:__main__:score: 81.447876
# INFO:__main__:
#
# INFO:__main__:iteration 183
# INFO:__main__:score: 81.401538
# INFO:__main__:
#
# INFO:__main__:iteration 184
# INFO:__main__:score: 81.457031
# INFO:__main__:
#
# INFO:__main__:iteration 185
# INFO:__main__:score: 81.404687
# INFO:__main__:
#
# INFO:__main__:iteration 186
# INFO:__main__:score: 81.455713
# INFO:__main__:
#
# INFO:__main__:iteration 187
# INFO:__main__:score: 81.399927
# INFO:__main__:
#
# INFO:__main__:iteration 188
# INFO:__main__:score: 81.449707
# INFO:__main__:
#
# INFO:__main__:iteration 189
# INFO:__main__:score: 81.391016
# INFO:__main__:
#
# INFO:__main__:iteration 190
# INFO:__main__:score: 81.473022
# INFO:__main__:
#
# INFO:__main__:iteration 191
# INFO:__main__:score: 81.400415
# INFO:__main__:
#
# INFO:__main__:iteration 192
# INFO:__main__:score: 81.460205
# INFO:__main__:
#
# INFO:__main__:iteration 193
# INFO:__main__:score: 81.422876
# INFO:__main__:
#
# INFO:__main__:iteration 194
# INFO:__main__:score: 81.455811
# INFO:__main__:
#
# INFO:__main__:iteration 195
# INFO:__main__:score: 81.401660
# INFO:__main__:
#
# INFO:__main__:iteration 196
# INFO:__main__:score: 81.459717
# INFO:__main__:
#
# INFO:__main__:iteration 197
# INFO:__main__:score: 81.413477
# INFO:__main__:
#
# INFO:__main__:iteration 198
# INFO:__main__:score: 81.460962
# INFO:__main__:
#
# INFO:__main__:iteration 199
# INFO:__main__:score: 81.422534
# INFO:__main__:
#
# INFO:__main__:iteration 200
# INFO:__main__:score: 81.468237
# INFO:__main__:
#
# INFO:__main__:iteration 201
# INFO:__main__:score: 81.408960
# INFO:__main__:
#
# INFO:__main__:iteration 202
# INFO:__main__:score: 81.469702
# INFO:__main__:
#
# INFO:__main__:iteration 203
# INFO:__main__:score: 81.388843
# INFO:__main__:
#
# INFO:__main__:iteration 204
# INFO:__main__:score: 81.457275
# INFO:__main__:
#
# INFO:__main__:iteration 205
# INFO:__main__:score: 81.415308
# INFO:__main__:
#
# INFO:__main__:iteration 206
# INFO:__main__:score: 81.472510
# INFO:__main__:
#
# INFO:__main__:iteration 207
# INFO:__main__:score: 81.392847
# INFO:__main__:
#
# INFO:__main__:iteration 208
# INFO:__main__:score: 81.467163
# INFO:__main__:
#
# INFO:__main__:iteration 209
# INFO:__main__:score: 81.395313
# INFO:__main__:
#
# INFO:__main__:iteration 210
# INFO:__main__:score: 81.444434
# INFO:__main__:
#
# INFO:__main__:iteration 211
# INFO:__main__:score: 81.393213
# INFO:__main__:
#
# INFO:__main__:iteration 212
# INFO:__main__:score: 81.445410
# INFO:__main__:
#
# INFO:__main__:iteration 213
# INFO:__main__:score: 81.404590
# INFO:__main__:
#
# INFO:__main__:iteration 214
# INFO:__main__:score: 81.458838
# INFO:__main__:
#
# INFO:__main__:iteration 215
# INFO:__main__:score: 81.405811
# INFO:__main__:
#
# INFO:__main__:iteration 216
# INFO:__main__:score: 81.463721
# INFO:__main__:
#
# INFO:__main__:iteration 217
# INFO:__main__:score: 81.407031
# INFO:__main__:
#
# INFO:__main__:iteration 218
# INFO:__main__:score: 81.462012
# INFO:__main__:
#
# INFO:__main__:iteration 219
# INFO:__main__:score: 81.409229
# INFO:__main__:
#
# INFO:__main__:iteration 220
# INFO:__main__:score: 81.475317
# INFO:__main__:
#
# INFO:__main__:iteration 221
# INFO:__main__:score: 81.395435
# INFO:__main__:
#
# INFO:__main__:iteration 222
# INFO:__main__:score: 81.486670
# INFO:__main__:
#
# INFO:__main__:iteration 223
# INFO:__main__:score: 81.398730
# INFO:__main__:
#
# INFO:__main__:iteration 224
# INFO:__main__:score: 81.469458
# INFO:__main__:

# %%
with open(atlasAlignParams_dir + '/%(stack)s/%(stack)s_3dAlignParams.txt' % {'stack': stack}, 'r') as f:
    lines = f.readlines()
T_final = np.array(map(float, lines[1].strip().split()))

# %%
T_final
# Out:
# array([  9.89331000e-01,   2.79640000e-01,  -1.02790000e-02,
#          4.27320680e+01,  -2.13326000e-01,   9.15999000e-01,
#          8.35500000e-02,  -3.21320860e+01,   6.00710000e-02,
#         -9.62790000e-02,   9.48397000e-01,   1.48596170e+01])

# %%
import numdifftools as nd
# https://media.readthedocs.org/pdf/numdifftools/latest/numdifftools.pdf

# %%
g = nd.Gradient(compute_score, step=np.r_[1e-1, 1e-1, 1e-1, 5,
                                          1e-1, 1e-1, 1e-1, 5,
                                          1e-1, 1e-1, 1e-1, 5])
g(T_final).reshape((3,4))
# Out:
# array([[  6.00927734,  -3.41088867,  -8.94720459,  -0.04060059],
#        [  2.46795654,   6.37304688,  13.78807068,   0.11897095],
#        [ 26.5664978 ,  11.76049805,   4.54318309,  -0.18624512]])

# %%
g = nd.Gradient(compute_score, step=np.r_[1e-2, 1e-2, 1e-2, 5,
                                          1e-2, 1e-2, 1e-2, 5,
                                          1e-2, 1e-2, 1e-2, 5])
g(T_final).reshape((3,4))
# Out:
# array([[  6.40136719e+00,  -1.84082031e+00,  -4.86450195e+00,
#          -4.06005859e-02],
#        [ -1.78344727e+01,   9.51049805e+00,   4.89379883e+00,
#           1.18970947e-01],
#        [  4.16870117e+01,   3.95385742e+00,  -2.40734863e+01,
#          -1.86245117e-01]])

# %%
compute_score_and_gradient(T_final)[1] / 1e4 * 7
# Out:
# array([ 21.61148478,  -5.18398775,  -8.78326591,  -0.11946889,
#        -41.65740612,  19.84589307,  11.66668153,   0.2068148 ,
#         36.87631868,   0.40260411, -27.92260616,  -0.1375492 ])

# %%
h = nd.Hessdiag(compute_score, step=np.r_[1e-1, 1e-1, 1e-1, 5,
                                          1e-1, 1e-1, 1e-1, 5,
                                          1e-1, 1e-1, 1e-1, 5])
h(T_final).reshape((3,4))
# Out:
# array([[ -3.90701172e+03,  -8.38144531e+02,  -2.65509399e+03,
#          -1.59375000e-01],
#        [ -5.51532593e+03,  -2.22789551e+03,  -3.02422333e+03,
#          -2.86456543e-01],
#        [ -5.67038879e+03,  -2.03737305e+03,  -4.39688902e+03,
#          -3.18267578e-01]])

# %%
h = nd.Hessdiag(compute_score, step=np.r_[1e-2, 1e-2, 1e-2, 5,
                                          1e-2, 1e-2, 1e-2, 5,
                                          1e-2, 1e-2, 1e-2, 5])
h(T_final).reshape((3,4))
# Out:
# array([[ -6.06542969e+03,  -1.24853516e+03,  -3.79125977e+03,
#          -1.59375000e-01],
#        [ -9.91210937e+03,  -3.15698242e+03,  -3.87182617e+03,
#          -2.86456543e-01],
#        [ -1.20551758e+04,  -3.13647461e+03,  -7.52709961e+03,
#          -3.18267578e-01]])
